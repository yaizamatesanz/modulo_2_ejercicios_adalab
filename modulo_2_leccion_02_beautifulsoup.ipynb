# %% [markdown]
# <h1>Tabla de Contenidos<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#¿Qué-es-el-Web-Scrapping?" data-toc-modified-id="¿Qué-es-el-Web-Scrapping?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>¿Qué es el <strong>Web Scrapping</strong>?</a></span></li><li><span><a href="#¿Qué-es-HTML?" data-toc-modified-id="¿Qué-es-HTML?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>¿Qué es HTML?</a></span></li><li><span><a href="#¿Qué-es-Beautiful-Soup?" data-toc-modified-id="¿Qué-es-Beautiful-Soup?-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>¿Qué es <em>Beautiful Soup</em>?</a></span></li><li><span><a href="#Métodos-importantes-de-Beautiful-Soup" data-toc-modified-id="Métodos-importantes-de-Beautiful-Soup-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Métodos importantes de <em>Beautiful Soup</em></a></span></li><li><span><a href="#Datos-de-moviles-de-Ebay" data-toc-modified-id="Datos-de-moviles-de-Ebay-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Datos de moviles de Ebay</a></span><ul class="toc-item"><li><span><a href="#Pandas" data-toc-modified-id="Pandas-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Pandas</a></span></li></ul></li><li><span><a href="#Sacando-datos-de-una-tabla" data-toc-modified-id="Sacando-datos-de-una-tabla-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Sacando datos de una tabla</a></span></li><li><span><a href="#Resumen-de-los-métodos-aprendidos-de-Pandas" data-toc-modified-id="Resumen-de-los-métodos-aprendidos-de-Pandas-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Resumen de los métodos aprendidos de Pandas</a></span></li><li><span><a href="#Ejercicios" data-toc-modified-id="Ejercicios-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Ejercicios</a></span></li></ul></div>

# %% [markdown]
# # ¿Qué es el **Web Scrapping**?
#
# El *web scraping* es una técnica utilizada para extraer información de sitios web de forma automática. Consiste en escribir un programa o utilizar herramientas para recorrer y analizar el código HTML o XML de una página web, y luego extraer los datos relevantes de manera estructurada.
#
# El objetivo del *web scraping* es obtener datos específicos de una página web de manera eficiente y automatizada, en lugar de realizar la extracción manualmente. Esta técnica puede ser utilizada para diversas finalidades, como recopilar datos para análisis, realizar comparaciones de precios, monitorizar contenido, obtener información de noticias, entre otras aplicaciones.
#
# Existen varias bibliotecas en Python que son ampliamente utilizadas para realizar *web scraping*. Algunas de las bibliotecas más populares y útiles son:
#
# 1. **Beautiful Soup**: Es una biblioteca muy utilizada para el análisis y extracción de datos de páginas web. Proporciona una interfaz fácil de usar para analizar y manipular el HTML y XML de una página web. Beautiful Soup permite buscar elementos utilizando etiquetas, atributos y contenido, lo que facilita la extracción de datos específicos.
#
# 2. **Selenium**: Es una biblioteca que se utiliza para automatizar el navegador web. Selenium es útil cuando el contenido que se desea extraer está generado dinámicamente a través de JavaScript u otras interacciones del lado del cliente. Proporciona funciones para interactuar con elementos de la página, hacer clic en botones, enviar formularios y más.
#
# 3. **Scrapy**: Es un framework de scraping web de alto nivel que ofrece una arquitectura completa y flexible para realizar tareas de web scraping de manera eficiente. Scrapy facilita la extracción de datos estructurados a gran escala y ofrece funcionalidades avanzadas como gestión de sesiones, almacenamiento de datos, manejo de errores y más.
#
# 4. **lxml**: Es una biblioteca de procesamiento de XML y HTML en Python. Proporciona una interfaz rápida y eficiente para analizar y extraer datos de documentos XML/HTML utilizando XPath y selectores CSS.
#
# 5. **PyQuery**: Es una biblioteca inspirada en jQuery que permite utilizar expresiones jQuery para analizar y manipular documentos HTML/XML. PyQuery es útil para seleccionar y extraer elementos específicos de una página web de manera similar a como se haría con jQuery en JavaScript.
#
#
# Estas son solo algunas de las bibliotecas más populares para realizar **web scraping** en Python. Cada una tiene sus propias fortalezas y características, y la elección de la biblioteca dependerá de los requisitos y la complejidad de la tarea de *scraping*. En las próximas lecciones nos centraremos en dos de las librerías más utilizadas para extraer datos de una página web, las cuales son **Beautiful Soup** y **Selenium**.
#
# [Video de la lección de hoy](https://www.youtube.com/watch?v=LcaKKRXYX2U&list=PLhQe2VhfFLJ2pWfdeaAuX0pfhzokrEpuV&index=5)

# %% [markdown]
# # ¿Qué es HTML?
#
# **HTML**, siglas de *Hypertext Markup Language* (Lenguaje de Marcado de Hipertexto), es utilizado para crear páginas web. Se utiliza para estructurar y presentar el contenido de una página web, como texto, imágenes, enlaces, formularios y otros elementos interactivos.
#
# El HTML se basa en una estructura jerárquica de etiquetas, también conocidas como elementos, que definen la estructura y el significado del contenido en una página web. Cada etiqueta tiene un propósito específico y se coloca dentro del código HTML para darle formato y proporcionar información adicional sobre los elementos de la página.
#
# Aquí hay un ejemplo básico de código HTML:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Título de la página</title>
# </head>
# <body>
#     <h1>Título principal</h1>
#     <p>Este es un párrafo de ejemplo.</p>
#     <a href="https://www.ejemplo.com">Enlace a Ejemplo.com</a>
#     <img src="imagen.jpg" alt="Descripción de la imagen">
# </body>
# </html>
# ```
#
# En este ejemplo, puedes ver algunas etiquetas HTML comunes:
#
# - `<!DOCTYPE html>`: Declara que el documento es un archivo HTML.
# - `<html>`: Es el elemento raíz que envuelve todo el contenido de la página.
# - `<head>`: Contiene información meta y enlaces a archivos externos, como hojas de estilo CSS o scripts JavaScript.
# - `<title>`: Define el título de la página, que se muestra en la pestaña del navegador.
# - `<body>`: Contiene el contenido visible de la página web.
# - `<h1>`: Define un encabezado de nivel 1.
# - `<p>`: Define un párrafo de texto.
# - `<a>`: Define un enlace a otra página web.
# - `<img>`: Inserta una imagen en la página web.
#
# El HTML es la base fundamental para crear páginas web y entender su estructura es importante para analizar y extraer datos de sitios web durante el proceso de análisis de datos.

# %% [markdown]
# # ¿Qué es *Beautiful Soup*?
#
# *Beautiful Soup* es una biblioteca de Python diseñada para facilitar el análisis y la extracción de datos de archivos HTML y XML. Proporciona una interfaz sencilla y legible que simplifica el proceso de navegación y manipulación de la estructura de estos documentos.
#
# Algunas características y ventajas de *Beautiful Soup*:
#
# 1. **Análisis de documentos HTML/XML**: Beautiful Soup facilita la tarea de analizar documentos HTML/XML y extraer datos específicos de manera eficiente. Proporciona métodos y funciones que permiten acceder a elementos, atributos y contenido dentro de la estructura del documento.
#
# 2. **Interfaz sencilla**: tiene una interfaz fácil de usar y comprender. No requiere conocimientos profundos de programación ni de lenguajes de marcado como HTML o XML. Con solo unas pocas líneas de código, puedes acceder y manipular los datos deseados.
#
# 3. **Soporte para analizadores**: es compatible con varios analizadores HTML/XML, como `html.parser`, `lxml`, `html5lib`, entre otros. Esto significa que puedes elegir el analizador más adecuado según tus necesidades y la complejidad del documento que estás analizando.
#
# 4. **Navegación basada en árbol**: utiliza una estructura de árbol para representar la jerarquía de los elementos en el documento HTML/XML. Esto permite realizar búsquedas y selecciones basadas en etiquetas, atributos, contenido y estructura del documento.
#
# 5. **Filtrado y extracción de datos**: uedes utilizar *Beautiful Soup* para filtrar y extraer datos específicos de una página web. Puedes buscar elementos por su nombre de etiqueta, atributos, clases, contenido y más. Esto te permite extraer información relevante para su posterior análisis.
#
# 6. **Ampliamente utilizado**:  es una de las bibliotecas más populares y ampliamente utilizadas para *web scraping* y análisis de datos en Python. Cuenta con una comunidad activa que brinda soporte y continúa desarrollando la biblioteca.
#
#
# Antes de empezar tendremos que instalar las siguientes librerías en nuestro ordernador, para eso tendremos que abrir la terminal y escribir las siguientes líneas de una en una:
#
# ```
# !pip install beautifulsoup4
# ```
#
# A lo largo de este jupyter veremos varios ejemplos de extracción de datos usando *Beautiful Soup*, en concreto sacaremos información de:
#
# - La página web de Ebay, para sacar información sobre teléfonos móviles.
#
# - Una página de la Bolsa, para sacar un histórico del Ibex 35.

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.5)

# %%
# antes de empezar importamos las librerías que vamos a usar. 
# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# Importar librerías para procesamiento de texto
# -----------------------------------------------------------------------
import re

# %% [markdown]
# # Métodos importantes de *Beautiful Soup*
#
# Algunos de los métodos principales de Beautiful Soup:
#
# 1. **BeautifulSoup**: Es el constructor principal de Beautiful Soup. Toma el código HTML o XML como entrada y lo analiza para crear un objeto BeautifulSoup. Su sintaxis básica es:
#    ```python
#    from bs4 import BeautifulSoup
#
#    # Crear un objeto BeautifulSoup
#    soup = BeautifulSoup(html_doc, 'html.parser')
#    ```
#
# 2. **find() y find_all()**: Estos métodos son fundamentales para buscar elementos en un documento analizado con Beautiful Soup.
#    - `find()` **devuelve el primer elemento** que coincide con los criterios de búsqueda.
#
#    - `find_all()` **devuelve una lista de todos los elementos** que coinciden con los criterios de búsqueda.
#
#       ```python
#       # Buscar un elemento por su etiqueta
#       soup.find('a')
#
#       # Buscar todos los elementos <a> en una lista
#       soup.find_all('a')
#       ```
#
# 3.  **select()**: devuelve una lista de objetos Tag que coinciden con el selector CSS especificado. Su sintaxis básica es:
#       ```python
#       # Buscar todos los elementos <a> dentro de elementos <li>
#       enlaces = soup.select('li a')
#       ```
#
# 4. **text** o **getText()**: El atributo `text` devuelve el texto contenido dentro de una etiqueta. Ambos métodos hacen exactamente lo mismo. Accederemos a él de la siguiente manera:
#       ```python
#       # Obtener el texto de un elemento
#       elemento.text
#       ```
#
# 5. **get()**: El método `get()` se utiliza para obtener el valor de un atributo de una etiqueta. Aquí tienes un ejemplo:
#       ```python
#       # Obtener el valor de un atributo
#       elemento.get('href')
#       ```

# %% [markdown]
# # Datos de moviles de Ebay
#
# En este caso, utilizaremos técnicas de web scraping para extraer información específica de la página web de Ebay. En lugar de recopilar manualmente la información, utilizaremos Python y la biblioteca Beautiful Soup para analizar el código fuente de la página web de Ebay y extraer los datos que nos interesan.
#
# El objetivo específico de nuestro proyecto de *web scraping* es obtener datos sobre el total de teléfonos móviles disponibles en el sitio web de Ebay. Para lograr esto, realizaremos los siguientes pasos:
#
# 1. En primer lugar, utilizaremos Python para hacer una solicitud HTTP a la página web de Ebay y obtener su código fuente. Usaremos la biblioteca `requests`.
#
# 2. Una vez que tengamos el código fuente de la página web, crearemos un objeto BeautifulSoup utilizando la biblioteca Beautiful Soup. Este objeto nos permitirá analizar y manipular el código HTML de la página de manera sencilla.
#
# 3. Utilizaremos técnicas de selección de elementos, como selectores CSS o métodos como `find()` y `find_all()`, para localizar los elementos que contienen información sobre los teléfonos móviles en la página web de Ebay. Podemos inspeccionar el código fuente de la página para identificar las etiquetas HTML y los atributos que nos ayudarán a encontrar estos elementos específicos.
#
# 4. Una vez que hayamos localizado los elementos relevantes, extraeremos la información que necesitamos, como el título del producto, el precio o cualquier otro dato que sea relevante para nuestro objetivo.
#
# 5. A medida que extraemos los datos de cada elemento, los almacenaremos en una estructura de datos adecuada, como una lista o un diccionario.
#
#
#
# **Antes de empezar algunas notas importantes que debes recordar**
#
# Cuando realizas una solicitud HTTP utilizando la biblioteca `requests`(como aprendiste en la lección anterior),vamos a obtener una respuesta del servidor. Esta respuesta contiene información sobre el resultado de la solicitud. Una de las propiedades más comunes de la respuesta es `status_code`, que es un código numérico que indica el estado de la respuesta. Recordemos que, cuando usamos la librería `requests` en realidad lo que estamos haciendo es pedir información a un servidor (en este caso es una página web), el método `status_code` nos dice si hemos pedido los datos correctamente o no. Algunos de los códigos más comunes son:
#
# - **200**: Esta respuesta indica que la solicitud fue exitosa. El servidor ha respondido correctamente y ha devuelto los datos solicitados. Esto es generalmente lo que esperamos obtener cuando hacemos una solicitud HTTP exitosa.
#
# - **404**: Este código indica que el recurso solicitado no se encontró en el servidor. Puede ocurrir cuando se accede a una URL incorrecta o cuando el recurso ha sido eliminado o no está disponible.
#
# - **500**: Un código de estado 500 indica un error interno del servidor. Esto puede deberse a un problema en el servidor que impide que se procese correctamente la solicitud. Es posible que necesites comunicarte con el administrador del servidor en este caso.
#
# - **302**: Este código es una redirección temporal. Indica que la URL solicitada ha sido redirigida a otra ubicación.
#
# - **401**: Este código indica que la solicitud requiere autenticación. Significa que no tienes acceso a los recursos solicitados sin proporcionar credenciales válidas, como un nombre de usuario y una contraseña.
#
#
# Al utilizar el método `status_code` en `requests`, podremos verificar el código de estado de la respuesta para determinar si la solicitud fue exitosa o si hubo algún tipo de error. Por ejemplo, si el código de estado es 200, sabremos que la solicitud se completó correctamente y podemos procesar los datos de la respuesta. Si el código de estado es diferente de 200, temdremos que tomar medidas adicionales según el tipo de código de estado. **Es importante verificar el código de estado de la respuesta para asegurarnos de que la solicitud fue exitosa y manejar cualquier error o condición especial según sea necesario.**

# %%
# definimos la url de la página de la vamos a sacar datos
url_moviles = "https://www.ebay.es/e/campanas/moviles-y-smartphones-reacondicionados"

# hacemos la request a la página de la que queremos sacar la info
res_moviles = requests.get(url_moviles)

# vemos si todo ha ido bien
print("La respuesta de la petición es:", res_moviles.status_code)
# Out:
# La respuesta de la petición es: 200

# %%
# creamos el objeto BeautifulSoup para poder acceder al contenido solicitado
sopa_moviles = BeautifulSoup(res_moviles.content, 'html.parser')

# mostramos por pantalla los resultados del objeto de Beautiful Soup. El método ".prettify()" nos ayuda a visualizar los resultados de una forma más amigable
print(sopa_moviles.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="ie9" lang="es"><![endif]-->
# <!--[if gt IE 9]><!-->
# <html lang="es">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Smartphones reacondicionados | eBay. ¡Ahorra dales una segunda vida!" name="twitter:title">
#    <meta content="@eBay" name="twitter:site"/>
#    <meta content="https://ir.ebaystatic.com/cr/v/c1/ebay-logo-1-1200x1200-margin.png" name="twitter:image"/>
#    <meta content="website" property="og:type"/>
#    <meta content="¡Ahorra dales una segunda vida!" name="description"/>
#    <meta content="https://www.ebay.es/e/campanas/moviles-y-smartphones-reacondicionados" property="og:url"/>
#    <meta content="noindex" name="robots"/>
#    <meta content="¡Ahorra dales una segunda vida!" property="og:description"/>
#    <meta content="https://ir.ebaystatic.com/cr/v/c1/ebay-logo-1-1200x630-margin.png" property="og:image"/>
#    <meta content="¡Ahorra dales una segunda vida!" name="twitter:description"/>
#    <meta content="102628213125203" property="fb:app_id"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="eBay" property="og:site_name"/>
#    <link href="https://i.ebayimg.com" rel="preconnect"/>
#    <meta content="unsafe-url" name="referrer"/>
#    <link href="https://ir.ebaystatic.com" rel="preconnect"/>
#    <meta content="34E98E6F27109BE1A9DCF19658EEEE33" name="msvalidate.01"/>
#    <meta content="Smartphones reacondicionados | eBay. ¡Ahorra dales una segunda vida!" property="og:title"/>
#    <meta content="060ab5e38d266c06" name="y_key"/>
#    <title>
#     Smartphones reacondicionados | eBay. ¡Ahorra dales una segunda vida!
#    </title>
#    <meta content="446Tr7oW9IID7WVwfkU3Nqp8Qb3BaYdlfyaVl4_nng8" name="google-site-verification"/>
#    <!-- NGMARS SIGNATURE -->
#    <link href="//i1.ebayimg.com" rel="dns-prefetch"/>
#    <link crossorigin="" href="//i.ebayimg.com" rel="preconnect"/>
#    <link crossorigin="" href="//i1.ebayimg.com" rel="preconnect"/>
#    <link crossorigin="" href="//ir.ebaystatic.com" rel="preconnect"/>
#    <link crossorigin="" href="//secureir.ebaystatic.com" rel="preconnect"/>
#    <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#    <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
#    <link href="//secureir.ebaystatic.com" rel="dns-prefetch"/>
#    <link href="//i.ebayimg.com" rel="dns-prefetch"/>
#    <link href="//rover.ebay.com" rel="dns-prefetch"/>
#    <script>
#     $ssgST=new Date().getTime();
#    </script>
#    <link href="https://ir.ebaystatic.com/rs/c/browse-page-desktop-pr-JyMVnQmG.css" rel="stylesheet"/>
#    <link href="https://ir.ebaystatic.com/rs/v/e3ikji01hy42nhlpc1w1xuxkfii.css?proc=DU:N" rel="stylesheet" type="text/css"/>
#    <!--M#s0-4-->
#    <noscript data-marko-key="@_wbind s0-4" id="s0-4">
#    </noscript>
#    <!--M/-->
#   </meta>
#  </head>
#  <body class="no-touch skin-large root-category-id-0 high-reso-images flex-lg">
#   <!--M#s0-8-0-->
#   <!--M/-->
#   <div class="x-header">
#    <script type="text/javascript">
#     var GHpre = {"userAuth":false,"userId":"","fn":""}
#    </script>
#    <style>
#     .gh-hide-if-nocss{display:none;}.gh-ar-hdn{color:#fff}
#    </style>
#    <div class="gh-acc-exp-div gh-hide-if-nocss">
#     <a class="gh-acc-a" href="#mainContent" id="gh-hdn-stm
#           <i class="gh-sprRetina" id="gh-shop-ei">
#           </i>
#          </button>
#          <div id="gh-sbc-o">
#           <h2 class="gh-ar-hdn">
#            Comprar por categoría
#           </h2>
#          </div>
#         </div>
#        </td>
#        <td class="gh-td-s">
#         <form action="https://www.ebay.es/sch/i.html" id="gh-f" method="get">
#          <input name="_from" type="hidden" value="R40"/>
#          <input name="_trksid" type="hidden" value="m570.l1313"/>
#          <table class="gh-tbl2" id="gh-search-wrap" role="presentation">
#           <tbody>
#            <tr>
#             <td class="gh-td-s">
#              <div id="gh-ac-box">
#               <div id="gh-ac-box2">
#                <label class="gh-ar-hdn" for="gh-ac">
#                 Introduce la palabra clave de búsqueda
#                </label>
#                <input aria-autocomplete="list" aria-expanded="false" aria-label="Buscar cualquier artículo" autocapitalize="off" autocomplete="off" autocorrect="off" class="gh-tb ui-autocomplete-input" id="gh-ac" maxlength="300" name="_nkw" placeholder="Buscar cualquier artículo" size="50" spellcheck="false" type="text"/>
#                <input style="display:none"/>
#                <script>
#                 if(document.getElementById('gh-ac').value.length !== 0) { document.getElementById('gh-ac-box').classList.add('gh-ac-box-focus'); document.getElementById('gh').classList.add('gh-sch-focus'); }
#                </script>
#                <svg aria-hidden="true" class="icon icon--search gh-search__icon" focusable="false" height="16" width="16">
#                 <use xlink:href="#gh-icon-search-evo">
#                 </use>
#                </svg>
#               </div>
#              </div>
#             </td>
#             <td class="gh-td" id="gh-cat-td">
#              <div id="gh-cat-box">
#               <select aria-label="Selecciona una categoría para limitar la búsqueda" class="gh-sb" id="gh-cat" name="_sacat" size="1">
#                <option value="0">
#                 Todas las categorías
#                </option>
#                <optgroup label="----------------------------------------">
#                </optgroup>
#                <option value="353">
#                 Arte y antigüedades
#                </option>
#                <option value="14339">
#                 Artesanía y manualidades
#                </option>
#                <option value="2984">
#                 Bebés
#                </option>
#                <option value="26395">
#                 Belleza y salud
#                </option>
#                <option value="625">
#                 Cámaras y fotografía
#                </option>
#                <option value="11700">
#                 Casa, jardín y bricolaje
#                </option>
#                <option value="11232">
#                 Cine, DVD y películas
#                </option>
#                <option value="1">
#                 Coleccionismo
#                </option>
#                <option value="1249">
#                 Consolas y videojuegos
#                </option>
#                <option value="888">
#                 Deportes
#                </option>
#                <option value="20710">
#                 Electrodomésticos
#                </option>
#                <option value="1305">
#                 Entradas y eventos
#                </option>
#                <option value="12576">
#                 Equipamiento y maquinaria
#                </option>
#                <option value="14308">
#                 Gastronomía y bebidas
#                </option>
#                <option value="293">
#                 Imagen y sonido
#                </option>
#                <option value="58058">
#                 Informática y tablets
#                </option>
#                <option value="619">
#                 Instrumentos musicales
#                </option>
#                <option value="220">
#                 Juguetes
#                </option>
#                <option value="267">
#                 Libros, revistas y cómics
#                </option>
#                <option value="11116">
#                 Monedas y billetes
#                </option>
#                <option value=" vehículos">
#                 Motor
#                </option>
#                <option value=" piezas y accesorios">
#                 Motor
#                </option>
#                <option value="15032">
#                 Móviles y telefonía
#                </option>
#                <option value="11233">
#                 Música, CDs y vinilos
#                </option>
#                <option value="281">
#                 Relojes y joyas
#                </option>
#                <option value="11450">
#                 Ropa, calzado y complementos
#                </option>
#                <option value="260">
#                 Sellos
#                </option>
#                <option value="3252">
#                 Viajes
#                </option>
#                <option value="99">
#                 Otras categorías
#                </option>
#               </select>
#              </div>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <td class="gh-td gh-sch-btn">
#           <input class="btn btn-prim gh-spr" form="gh-f" id="gh-btn" type="submit" value="Buscar"/>
#           <svg aria-hidden="true" class="icon icon--search gh-search-btn__icon" focusable="false" height="22" width="22">
#            <use xlink:href="#icon-search">
#            </use>
#           </svg>
#          </td>
#          <td class="gh-td" id="gh-as-td">
#           <a _sp="m570.l2614" aria-label="Advanced Search" href="https://www.ebay.es/sch/ebayadvsearch" id="gh-as-a" title="Búsqueda avanzada">
#            Avanzada
#           </a>
#          </td>
#         </form>
#        </td>
#        <td class="sticky_placeholder">
#         <ul>
#         </ul>
#        </td>
#       </tr>
#      </tbody>
#     </table>
#     <div aria-label="Cuenta" class="gh-hide-if-nocss" id="gh-top" role="navigation">
#      <ul id="gh-topl">
#       <li class="gh-t" id="gh-eb-u">
#        <noscript class="gh-t gh-spr">
#         ¡Hola! (
#         <a href="https://signin.ebay.es/ws/eBayISAPI.dll?SignIn&amp;_trksid=m570.l3348">
#          Identifícate
#         </a>
#         para pujar o comprar)
#        </noscript>
#        <script>
#         var supressUserGreeting = true; (function(){try{ var sup = !!(supressUserGreeting && typeof window.GHpre !== 'undefined' && !window.GHpre.userAuth); var d=document.cookie,a=((a=d.match(/u1f[^a-zA-Z0-9]([^^]*)[0-9a-z]{8}/))?a[1].replace(/\+/g," "):"").replace(/(.{12}).*/,"$1...");if(/[<>%&'\/]/.test(a)){throw(1)}document.write("<span id=gh-ug"+(!a||/u1p.QEBfX/.test(d)?' class=gh-ug-guest>¡Bienvenido! <a href="https://signin.ebay.es/ws/eBayISAPI.dll?SignIn&sgfl=gh&_trksid=m570.l1524" rel="nofollow" _sp="m570.l1524">Identifícate</a> <span id="gh-ug-flex">o <a href="https://signup.ebay.es/pa/crte?_trksid=m570.l2621" rel="nofollow" _sp="m570.l2621">regístrate</a></span>':' style="margin-right:3px">¡Hola, <b>-User-</b>!'.replace(/-User-/,sup ? '' : decodeURIComponent(escape(a))))+"</span>")}catch(b){document.write("<style>#gh-topl{display:none}</style>")}})();
#        </script>
#       </li>
#       <li class="gh-t gh-divider-l" id="gh-p-1">
#        <a _sp="m570.l3188" class="gh-p" data-sp="m570.l3188" href="https://www.ebay.es/deals">
#         Ofertas de eBay
#        </a>
#       </li>
#       <li class="gh-t gh-divider-l" id="gh-p-3">
#        <a _sp="m570.l1545" data-sp="m570.l1545" href="https://www.ebay.es/help/home">
#         Ayuda
#        </a>
#       </li>
#      </ul>
#      <ul id="gh-eb">
#       <li class="gh-eb-li gh-t-rt gh--link__divider" id="gh-p-2">
#        <a _sp="m570.l1528" class="gh-p" data-sp="m570.l1528" href="https://www.ebay.es/sl/sell">
#         Vender
#        </a>
#       </li>
#       <li class="gh-eb-li gh-margin rt" id="gh-wl-click">
#        <div class="gh-menu gh--link__divider">
#         <a _sp="m570.l47137" class="gh-eb-li-a gh-rvi-menu watchlist-menu" href="https://www.ebay.es/mye/myebay/watchlist" title="Lista de seguimiento">
#          Lista de seguimiento
#          <i class="gh-sprRetina gh-eb-arw gh-rvi-chevron" data-sp="m570.l47137">
#          </i>
#         </a>
#         <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-wl-click-o" href="#gh-wl-click" role="button">
#          Ampliar Lista de seguimiento
#         </a>
#         <div aria-label="Lista de seguimiento" class="gh-sublayer gh-flyout__menu" id="gh-wl-click-flyout" role="dialog">
#          <button aria-label="Cerrar diálogo" class="gh_flyout__close" id="gh-wl-click-close">
#           <svg aria-hidden="true" focusable="false" height="17" width="17">
#            <use xlink:href="#icon-close">
#            </use>
#           </svg>
#          </button>
#          <div id="gh-wl-click-body">
#           <div class="gh-loading">
#            <span aria-label="Cargando" class="gh-spinner" role="img">
#            </span>
#            <span class="gh-state">
#             Cargando...
#            </span>
#           </div>
#           <div class="gh-wl-click-gen-error">
#            <span>
#             <a href="https://signin.ebay.es/ws/eBayISAPI.dll?SignIn&amp;sgfl=gh&amp;ru=ru">
#              Identifícate
#             </a>
#             para ver tu información de usuario
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="gh-eb-li gh-hvr gh-dd rt" data-imp="10" id="gh-eb-My">
#        <div class="gh-menu">
#         <a _sp="m570.l2919" class="gh-eb-li-a gh-rvi-menu" href="https://www.ebay.es/mys/home?source=GBH" title="Mi eBay">
#          Mi eBay
#          <i class="gh-sprRetina gh-eb-arw gh-rvi-chevron" data-sp="m570.l2919">
#          </i>
#         </a>
#         <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-eb-My-o" href="#gh-eb-My" role="button">
#          Ampliar Mi eBay
#         </a>
#         <div class="gh-submenu gh-eb-o" id="gh-eb-My-o">
#          <ul id="gh-ul-nav" role="navigation">
#           <li>
#            <a _sp="m570.l1533" class="gh-eb-oa thrd" data-sp="m570.l1533" href="https://www.ebay.es/mye/myebay/summary">
#             Resumen
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l9225" class="gh-eb-oa thrd" data-sp="m570.l9225" href="https://www.ebay.es/mye/myebay/rvi">
#             Vistos recientemente
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1535" class="gh-eb-oa thrd" data-sp="m570.l1535" href="https://www.ebay.es/mye/myebay/bidsoffers">
#             Pujas/ofertas
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1534" class="gh-eb-oa thrd" data-sp="m570.l1534" href="https://www.ebay.es/mye/myebay/watchlist">
#             Lista de seguimiento
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1536" class="gh-eb-oa thrd" data-sp="m570.l1536" href="https://www.ebay.es/mye/myebay/purchase">
#             Historial de compras
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1537" class="gh-eb-oa thrd" data-sp="m570.l1537" href="https://www.ebay.es/mys/home?CurrentPage=MyeBayAllSelling&amp;ssPageName=STRK:ME:LNLK:MESX&amp;source=GBH">
#             En venta
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l9503" class="gh-eb-oa thrd" data-sp="m570.l9503" href="https://www.ebay.es/myb/SavedSearches">
#             Búsquedas guardadas
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l9505" class="gh-eb-oa thrd" data-sp="m570.l9505" href="https://www.ebay.es/myb/SavedSellers">
#             Vendedores guardados
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l143039" class="gh-eb-oa thrd" data-sp="m570.l143039" href="https://www.ebay.es/g/mygarage">
#             Mi garaje
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1539" class="gh-eb-oa thrd" data-sp="m570.l1539" href="https://mesg.ebay.es/mesgweb/ViewMessages/0">
#             Mensajes
#            </a>
#           </li>
#           <li id="gh-eb-sub-li-cpn">
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#       <li class="gh-eb-li gh-hvr gh-layer rt" id="gh-eb-Alerts">
#        <div class="gh-menu">
#         <button aria-controls="gh-eb-Alerts-o" aria-expanded="false" class="gh-control ghn-b gh-eb-li-a" title="Notifications">
#          <svg aria-hidden="true" class="gh-cart-icon" focusable="false">
#           <use xlink:href="#gh-icon-notification-evo">
#           </use>
#          </svg>
#         </button>
#         <div class="gh-sublayer">
#          <div class="gh-eb-o" id="gh-eb-Alerts-o" style="display: none;">
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="gh-eb-li gh-margin rt" id="gh-minicart-hover">
#        <div class="gh-menu">
#         <a _sp="m570.l2633" aria-label="Tu carro de la compra" class="gh-eb-li-a gh-rvi-menu" data-sp="m570.l2633" href="https://cart.payments.ebay.es/sc/view">
#          <svg aria-hidden="true" class="gh-cart-icon" focusable="false">
#           <use xlink:href="#gh-icon-cart-evo">
#           </use>
#          </svg>
#         </a>
#         <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-minicart-hover-o" href="#gh-minicart-hover" role="button">
#          Ampliar Cesta
#         </a>
#         <div aria-label="Tu carro de la compra" class="gh-sublayer gh-flyout__menu" id="gh-minicart-hover-flyout" role="dialog">
#          <button aria-label="Cerrar diálogo" class="gh_flyout__close" id="gh-minicart-hover-close">
#           <svg aria-hidden="true" focusable="false" height="17" width="17">
#            <use xlink:href="#icon-close">
#            </use>
#           </svg>
#          </button>
#          <div id="gh-minicart-hover-body">
#           <div class="gh-loading">
#            <span aria-label="Cargando" class="gh-spinner" role="img">
#            </span>
#            <span class="gh-state">
#             Cargando...
#            </span>
#           </div>
#           <div class="gh-minicart-hover-gen-error">
#            <span>
#             Se ha producido un error. Ve a la cesta para obtener más información.
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <link href="https://www.ebay.es/manifest.json" rel="manifest"/>
#     <div id="gh-ihelp" style="display:none;">
#      {"delay":300}
#     </div>
#     <!--[if lt IE 9]></div><![endif]-->
#    </header>
#    <div class="widgets-placeholder" id="widgets-placeholder">
#    </div>
#    <svg hidden="" style="display: none">
#     <svg height="100%" id="icon-search" viewbox="0 0 20 20" width="100%">
#      <path d="M19.786 18.557l-5.093-5.093a8.1 8.1 0 0 0 1.873-5.21C16.507 3.747 12.82 0 8.254 0 3.688 0 0 3.746 0 8.254c0 4.508 3.688 8.312 8.254 8.312 2.049 0 3.863-.761 5.327-1.932l5.093 5.093a.714.714 0 0 0 .527.234c.176 0 .41-.059.527-.234.351-.351.351-.878.059-1.171l-.001.001zM1.581 8.254a6.67 6.67 0 0 1 6.673-6.673 6.67 6.67 0 0 1 6.673 6.673c0 3.688-2.985 6.732-6.673 6.732s-6.673-2.985-6.673-6.732z">
#      </path>
#     </svg>
#     <symbol id="icon-close" viewbox="1.5 1.5 21 21">
#      <path d="M22.182 3.856c.522-.554.306-1.394-.234-1.938-.54-.543-1.433-.523-1.826-.135C19.73 2.17 11.955 10 11.955 10S4.225 2.154 3.79 1.783c-.438-.371-1.277-.4-1.81.135-.533.537-.628 1.513-.25 1.938.377.424 8.166 8.218 8.166 8.218s-7.85 7.864-8.166 8.219c-.317.354-.34 1.335.25 1.805.59.47 1.24.455 1.81 0 .568-.456 8.166-7.951 8.166-7.951l8.167 7.86c.747.72 1.504.563 1.96.09.456-.471.609-1.268.1-1.804-.508-.537-8.167-8.219-8.167-8.219s7.645-7.665 8.167-8.218z">
#      </path>
#     </svg>
#     <symbol id="icon-check" viewbox="0 0 30 30">
#      <circle cx="14.5" cy="14.5" fill="#82187c" r="14.5">
#      </circle>
#      <path d="M5.548 15.01l5.773 6.286L21.522 9.824" fill="#82187c" stroke="#ffffff" stroke-width="2">
#      </path>
#     </symbol>
#     <symbol id="icon-cart-new" viewbox="0 0 23 22">
#      <path d="M22 4a.999.999 0 01.97 1.242l-2 8A1 1 0 0120 14H7a1 1 0 01-.97-.758L3.22 2H1a1 1 0 110-2h3a1 1 0 01.97.758L5.78 4H22zm-1.277 2H6.28l1.5 6h11.442l1.5-6zm-4.539 12A2.995 2.995 0 0119 16a2.995 2.995 0 11-2.816 4h-5.368a3 3 0 110-2h5.368zM7 19a1 1 0 102 0 1 1 0 00-2 0zm12 1a1 1 0 110-2 1 1 0 010 2z" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="gh-icon-cart-evo" viewbox="0 0 20 20">
#      <path clip-rule="evenodd" d="M2.23628 3.99999H1C0.447715 3.99999 0 3.55228 0 2.99999C0 2.44771 0.447715 1.99999 1 1.99999H2.96947C3.42767 1.98561 3.85407 2.29636 3.96967 2.75462L4.85471 5.99975H17C17.6537 5.99975 18.1411 6.64595 17.9615 7.27447L16.376 12.8239C16.008 14.1118 14.8308 14.9998 13.4914 14.9998H7.5276C6.17475 14.9998 4.98927 14.0943 4.63331 12.7891L2.23628 3.99999ZM6.56284 12.2629L5.40017 7.99975H15.6743L14.4529 12.2745C14.3303 12.7038 13.9379 12.9998 13.4914 12.9998H7.5276C7.07665 12.9998 6.68149 12.6979 6.56284 12.2629Z" fill="#191919" fill-rule="evenodd">
#      </path>
#      <path d="M8 18.5C8 19.3284 7.32843 20 6.5 20C5.67157 20 5 19.3284 5 18.5C5 17.6716 5.67157 17 6.5 17C7.32843 17 8 17.6716 8 18.5Z" fill="#191919">
#      </path>
#      <path d="M14.5 20C15.3284 20 16 19.3284 16 18.5C16 17.6716 15.3284 17 14.5 17C13.6716 17 13 17.6716 13 18.5C13 19.3284 13.6716 20 14.5 20Z" fill="#191919">
#      </path>
#     </symbol>
#     <symbol id="gh-icon-notification-evo" viewbox="0 0 18 20">
#      <path clip-rule="evenodd" d="M5.99993 6.98212C6.00956 4.78121 7.79671 3 9.99989 3C12.2031 3 13.9902 4.78121 13.9999 6.98213C13.9997 6.98808 13.9997 6.99403 13.9997 7V9.66154C13.9997 10.0605 14.1058 10.4523 14.3071 10.7968L15.9593 13.6241C16.0567 13.7908 15.9365 14.0002 15.7434 14.0002L10.0003 14H10H9.99974H9.99957L4.25633 14.0002C4.0633 14.0002 3.94308 13.7908 4.04048 13.6241L5.69271 10.7968C5.894 10.4523 6.00009 10.0605 6.00009 9.66154V7C6.00009 6.99403 6.00003 6.98807 5.99993 6.98212ZM4.00009 7H3.99989C3.99989 3.68629 6.68618 1 9.99989 1C13.3136 1 15

#      </g>
#     </symbol>
#     <symbol id="svg-icon-qshop-blue-success" viewbox="0 0 30 30">
#      <g fill="none" fill-rule="evenodd">
#       <path d="M15.05 30A15.03 15.03 0 0 1 0 14.95C0 6.722 6.722 0 15.05 0S30 6.722 30 14.95C30 23.278 23.278 30 15.05 30zM15 3C8.333 3 3 8.333 3 15s5.333 12 12 12 12-5.444 12-12S21.667 3 15 3z" fill="#006EFC" fill-rule="nonzero">
#       </path>
#       <path d="M0 0h30v30H0z">
#       </path>
#      </g>
#     </symbol>
#     <symbol id="svg-icon-qshop-white-spinner" viewbox="0 0 30 30">
#      <g fill="none" fill-rule="evenodd">
#       <path d="M15.05 30A15.03 15.03 0 0 1 0 14.95C0 6.722 6.722 0 15.05 0S30 6.722 30 14.95C30 23.278 23.278 30 15.05 30zM15 3C8.333 3 3 8.333 3 15s5.333 12 12 12 12-5.444 12-12S21.667 3 15 3z" fill="#FFF" fill-opacity="0.3" fill-rule="nonzero">
#       </path>
#       <path d="M15.04 1.505v.038a1.521 1.521 0 0 0 1.362 1.533c4.584.528 8.35 3.647 9.877 7.804.293.796 1.131 1.247 1.943 1a1.456 1.456 0 0 0 .953-1.865C27.313 4.665 22.513.684 16.638.078a1.455 1.455 0 0 0-1.598 1.427" fill="#FFF">
#       </path>
#       <path d="M0 0h30v30H0z">
#       </path>
#      </g>
#     </symbol>
#     <symbol id="svg-icon-qshop-white-tick" viewbox="0 0 15 11">
#      <defs>
#       <path d="M10.236 15.047c-.397-.4-1.04-.4-1.436 0-.396.4-.396 1.05 0 1.45l4.057 3.924c.397.4 1.04.4 1.436 0l8.118-8.203c.397-.4.397-1.05 0-1.45-.396-.4-1.038-.4-1.435 0l-7.401 7.478-3.34-3.199z" id="qshop-white-tick-path">
#       </path>
#      </defs>
#      <g fill="none" fill-rule="evenodd">
#       <g transform="translate(-109 -138)">
#        <g transform="translate(13 123)">
#         <g transform="translate(88 5)">
#          <g>
#           <path d="M0 0h30v30H0z">
#           </path>
#           <mask fill="#fff">
#            <use xlink:href="#qshop-white-tick-path">
#            </use>
#           </mask>
#           <use fill="#FFF" xlink:href="#qshop-white-tick-path">
#           </use>
#          </g>
#         </g>
#        </g>
#       </g>
#      </g>
#     </symbol>
#     <symbol id="svg-icon-qshop-white-success" viewbox="0 0 30 30">
#      <g fill="none" fill-rule="evenodd">
#       <path d="M15.05 30A15.03 15.03 0 0 1 0 14.95C0 6.722 6.722 0 15.05 0S30 6.722 30 14.95C30 23.278 23.278 30 15.05 30zM15 3C8.333 3 3 8.333 3 15s5.333 12 12 12 12-5.444 12-12S21.667 3 15 3z" fill="#FFF" fill-rule="nonzero">
#       </path>
#       <path d="M0 0h30v30H0z">
#       </path>
#      </g>
#     </symbol>
#     <symbol id="svg-icon-qshop-all-categories" viewbox="0 0 17 17">
#      <g fill="none" fill-rule="evenodd">
#       <g stroke="#000" stroke-width="1.5">
#        <path d="M1.104 1.104h5.5v5.583h-5.5zM10.313 1.104h5.5v5.583h-5.5zM1.104 10.313h5.5v5.5h-5.5zM10.313 10.313h5.5v5.5h-5.5z">
#        </path>
#       </g>
#       <path d="M0 0h17v17H0z">
#       </path>
#      </g>
#     </symbol>
#     <symbol id="svg-icon-qshop-location" viewbox="0 0 15 21">
#      <g fill="none" fill-rule="evenodd">
#       <g stroke="#000" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.
126012 8.84366739,5.67581963 L7.966,7.555 Z M10.3756674,6.31698037 L11.4398536,8.56437398 C11.5450685,8.7865712 11.7525019,8.94309432 11.9950409,8.98330184 L14.4320409,9.38730184 C14.5294777,9.4022368 14.5773926,9.5557676 14.494235,9.64023735 L12.9112242,11.3570945 C12.7681106,11.5123628 12.6970818,11.7207678 12.7155848,11.9311185 L12.9435848,14.5231185 C12.9711284,14.7032277 12.87796,14.7738013 12.8124545,14.737862 L10.6650817,13.4872619 C10.4318234,13.351446 10.1435766,13.351446 9.91031828,13.4872619 L7.74631828,14.7472619 C7.69716562,14.7739518 7.60331957,14.702937 7.62368711,14.5795437 L7.86466228,11.9328341 C7.88373963,11.7215157 7.81241664,11.5120048 7.66836747,11.356219 L6.09736747,9.65721895 C5.998017,9.55577732 6.0459125,9.40210463 6.13302655,9.38878863 L8.60628857,8.96881024 C8.84920091,8.92755167 9.05635404,8.76961394 9.16046174,8.54629743 L10.2014617,6.31329743 C10.2420209,6.22753988 10.3333791,6.22753988 10.3756674,6.31698037 Z" fill="#FFFFFF">
#      </path>
#     </symbol>
#    </svg>
#    <script>
#     !function(){"use strict";function t(t,e){e=e||{bubbles:!1,cancelable:!1,detail:void 0};var n=document.createEvent("CustomEvent");return n.initCustomEvent(t,e.bubbles,e.cancelable,e.detail),n}Date.now=Date.now||function(){return+new Date},t.prototype=window.Event.prototype,"function"!=typeof window.CustomEvent&&(window.CustomEvent=t)}();
# "use strict";var SITE_SPEED=SITE_SPEED||{};SITE_SPEED.ATF_TIMER={measure:function(t){t.setAttribute("data-atftimer",Date.now())}};
#    </script>
#   </div>
#   <script>
#    window.SRP = window.SRP || {};
# window.SRP.ATF_IMGS = 10;
#   </script>
#   <div class="pagecontainer srp-main--isLarge" role="main">
#    <div class="pr_error_status pr_error_status--hide">
#     <div class="s-error">
#      <div class="srp-message srp-message--isLarge page-notice page-notice--priority" role="alert">
#       <p class="page-notice__cell">
#        <span aria-hidden="true" class="page-notice__status">
#         <svg>
#          <use xlink:href="#svg-icon-priority">
#          </use>
#         </svg>
#        </span>
#        <!--F#f_0-->
#        <!--F#f_0-->
#        <!--F#f_2[0]-->
#        Parece que hay un problema al procesar la solicitud en este momento.
#        <!--F/-->
#        <!--F/-->
#        <!--F/-->
#       </p>
#      </div>
#     </div>
#    </div>
#    <div class="pagecontainer__top">
#     <script>
#      (window.$ebay||($ebay = {})).tracking={pageId:'2499337',pageName:'rppevents'}
#     </script>
#     <!--M#s0-16-6-0-1[0]-1-->
#     <nav aria-labelledby="b-breadcrumb__heading" class="b-breadcrumb" data-view="mi:4340|iid:1|dur:">
#      <h2 class="clipped" id="b-breadcrumb__heading">
#       Estás aquí
#      </h2>
#      <ol>
#       <li>
#        <a _sp="p2493618.m4340.l8964" class="b-breadcrumb__text b-link--tertiary truncate" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","operationId":"2493618","flushImmediately":false,"eventProperty":{"parentrq":"7bb3a0a81910aab2efe39e23ffffec88","pageci":"f26ed942-624a-4511-bdbd-c84b9cff79e4","moduledtl":"mi:4340|iid:1|li:8964|luid:2"}}' href="https://www.ebay.es">
#         <!--F#1-->
#         eBay
#         <svg aria-hidden="true" class="svg-icon icon icon--16" focusable="false">
#          <defs>
#           <symbol id="icon-chevron-right-16" viewbox="0 0 16 16">
#            <path d="m12.707 8.707-6 6a1 1 0 0 1-1.414-1.414L10.586 8 5.293 2.707a1 1 0 0 1 1.414-1.414l6 6a1 1 0 0 1 0 1.414Z">
#            </path>
#           </symbol>
#          </defs>
#          <use href="#icon-chevron-right-16">
#          </use>
#         </svg>
#         <!--F/-->
#        </a>
#       </li>
#       <li>
#        <span class="b-breadcrumb__text b-link--tertiary truncate">
#         Smartphones reacondicionados
#        </span>
#       </li>
#      </ol>
#     </nav>
#     <div class="b-skipnav">
#      <a class="b-skipnav__link" href="#leftnav">
#       Ir a la navegación de la página
#      </a>
#     </div>
#     <div class="b-refine-expander">
#      <button class="btn--wide btn" data-ebayui="" data-track='{"_type":"Action","type":"OPERATION","trackingList":[{"eventFamily":"LST","eventAction":"ACTN","actionKind":"SHOWDIALOG","actionKinds":["SHOWDIALOG"],"operationId":"2493618","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cli%3A8171%7Cluid%3A1%7C","pageci":"f26ed942-624a-4511-bdbd-c84b9cff79e4","parentrq":"7bb3a0a81910aab2efe39e23ffffec88"}}],"moduleGroup":{},"subGroup":{}}' type="button">
#       <!--F#7-->
#       Filtrar
#       <!--F/-->
#      </button>
#     </div>
#     <!--M/-->
#     <!--M#s0-16-6-0-1[1]-1-->
#     <style>
#      .title-banner--bgcolorimg .title-banner__layer {color:#07522C;}.title-banner--bgcolorimg .title-banner__layer-leftbg, .title-banner--bgcolor {background-color:#5EE471;}.title-banner--bgcolorimg .title-banner__layer-leftbg {opacity:1;}.title-banner--bgcolorimg .title-banner__right .title-banner__right-image {background-image: url(https://i.ebayimg.com/images/g/v5QAAOSwtkdkpUn1/s-l1600.jpg);}
#     </style>
#     <style>
#      .e-title-banner .e-title-banner__content {border-bottom: 0} .e-title-banner {color:#07522C;background-color:#5EE471}
#     </style>
#     <section class="clearfix title-banner title-banner--bgcolorimg title-banner--events" data-view="mi:4326|iid:1">
#      <div class="title-banner__layer">
#       <div class="title-banner__layer-leftbg">
#       </div>
#       <div class="title-banner__layer__info">
#        <h1 class="title-banner__title">
#         Smartphones reacondicionados
#        </h1>
#        <h2 class="title-banner__subtitle">
#         ¡Ahorra dales una segunda vida!
#        </h2>
#       </div>
#      </div>
#      <div class="title-banner__right">
#       <div class="title-banner__right-image">
#       </div>
#      </div>
#     </section>
#     <!--M/-->
#    </div>
#    <!--M#s0-17-->
#    <nav aria-labelledby="b-sidenav__title" class="pagecontainer__leftnav b-sidenav" data-marko-key="@_wbind s0-17" id="s0-17">
#     <div class="container" id="leftnav" tabindex="-1">
#      <div>
#       <header>
#        <button aria-label="Close dialog" class="dialog__close" data-marko='{"onclick":"handleClick s0-17 false"}' type="button">
#         <!--M#s0-17-5-0-->
#         <svg aria-hidden="true" class="icon icon--24" data-marko-key="@svg s0-17-5-0" focusable="false">
#          <defs data-marko-key="@defs s0-17-5-0">
#           <symbol id="icon-close-24" viewbox="0 0 24 24">
#            <path d="m13.41 12 7.3-7.29a1.004 1.004 0 0 0-1.42-1.42L12 10.59l-7.29-7.3a1.003 1.003 0 1 0-1.42 1.42l7.3 7.29-7.3 7.29a1.001 1.001 0 0 0 0 1.42 1.001 1.001 0 0 0 1.42 0l7.29-7.3 7.29 7.3a1.001 1.001 0 0 0 1.42 0 1.001 1.001 0 0 0 0-1.42L13.41 12Z">
#            </path>
#           </symbol>
#          </defs>
#          <use href="#icon-close-24">
#          </use>
#         </svg>
#         <!--M/-->
#        </button>
#        <h2 class="clipped" id="b-sidenav__title">
#         Side Refine Panel
#        </h2>
#       </header>
#       <div>
#        <div class="dialog__cell">
#         <ul class="x-refine__body">
#          <div class="x-refine__left__nav">
#           <li class="x-refine__main__list">
#            <div>
#             <h3 class="x-refine__item">
#              <!--F#f_0-->
#              <!--F#f_2[0]-->
#              Categoría
#              <!--F/-->
#              <!--F/-->
#             </h3>
#             <!--M#s0-17-12_2-0-1[0]-0-3-3-->
#             <!--M/-->
#            </div>
# ...
#     </div>
#     <script type="text/javascript">
#      (function(win){
# 		win.GH_ABD = {};
# 		win.GH_ABD.cfg = {"ckbit":82,"externalJsUrl":"https://secureir.ebaystatic.com/cr/v/c1/gh_show_ads.js"};
# 		var abElement = document.getElementById("gh-bulletin-det");
# 		if(abElement && win.getComputedStyle && typeof(win.getComputedStyle) === 'function'){
# 			var styleMap = win.getComputedStyle(abElement);
# 			if(styleMap['display'] === 'none' || abElement.offsetHeight<1){
# 				win.GH_ABD.bannerCollapsed = true;
# 				win.GH_ABD.detectionCompleted = true;
# 			}else{
# 				win.GH_ABD.bannerCollapsed = false;
# 				if(win.GH_ABD.cfg && win.GH_ABD.cfg.externalJsUrl){
# 					var scriptEl = document.createElement('script');
# 					scriptEl.onload = function(){
# 						win.GH_ABD.externaJs = true;
# 						win.GH_ABD.detectionCompleted = true;
# 					};
# 					scriptEl.onerror = function(){
# 						win.GH_ABD.externaJs = false;
# 						win.GH_ABD.detectionCompleted = true;
# 					};
# 					scriptEl.src = win.GH_ABD.cfg.externalJsUrl;
# 					scriptEl.defer = true;
# 					document.body.appendChild(scriptEl);
# 				}
# 			}
# 		}
# 	})(window);
#     </script>
#     <!--[if lt IE 9]></div><![endif]-->
#    </footer>
#    <div id="widget-platform">
#     <script type="application/javascript">
#      window.widget_platform = {"renderType":1,"renderDelay":500,"triggerFallBack":true,"status":4,"queryParam":null,"widgets":[{"html":"","css":null,"js":null,"jsInline":null,"init":""}],"showdiag":[]};
#     </script>
#     <div id="gh_user" style="display:none;">
#     </div>
#    </div>
#   </div>
#   <script>
#    !function(t){"use strict";var e=0,n=[],i="data-src";const r="data-high-res-src";var o,a,u,l=[],c=[],s=[],f=!1,d=0,m=4,g="MutationObserver"in t,h=[{eventName:"DOMContentLoaded",listener:N},{eventName:"load",listener:N},{eventName:"scroll",listener:q},{eventName:"resize",listener:q}];let v=!1;const b=[];var w=window.requestAnimationFrame||window.webkitRequestAnimationFrame||window.mozRequestAnimationFrame||window.oRequestAnimationFrame||window.msRequestAnimationFrame||function(t){window.setTimeout(t,1e3/60)};function E(){a=t.innerHeight||document.documentElement.clientHeight,u=t.innerWidth||document.documentElement.clientWidth}function A(t,e,n,i,r){t&&t.length&&(t.forEach(function(r,o){n&&n(r)||i.push(e.bind(t,r,o))}),p(r,i))}function p(t,e){f||(f=!0,w(function(){!function(t,e){d=0!==e.length?0:d+1;for(;0!==e.length;)e.shift()();f=!1,n.length&&d<m?w(function(){"postMutate"===t?p("mutate",c):p("postMutate",l)}):d=0}(t,e)}))}function F(t){var e=function(t){var i=t.target;i.dispatchEvent(new CustomEvent("lazyload")),i.removeEventListener("load",e,!1),n.splice(n.indexOf(i),1),0===n.length&&(o&&o.disconnect(),h.forEach(function(t){removeEventListener(t.eventName,t.listener,!1)}))};t.addEventListener("load",e,!1)}function L(t){t.length>0&&A(t,function(t){if(t&&t.target&&t.oldValue){F(t.target);const e=t.target.getAttribute(r),n=v&&e||t.oldValue;v?t.target.removeAttribute(r):e&&b.push(t.target),t.target.setAttribute("src",n)}},null,f?l:s,"postMutate")}function N(t){"load"===t.type&&(v=!0,b.length&&b.forEach(t=>{t.setAttribute("src",t.getAttribute(r)),t.removeAttribute(r)})),A(n,function(t){t.removeAttribute(i)},function(t){return null===t.getAttribute(i)||(n=t.parentElement.getBoundingClientRect(),r=n.top<=a+e&&n.top+n.height>0,o=n.left<=u+e&&n.left+n.width>0,!(r&&o));var n,r,o},c,"mutate")}function q(t){f||("resize"===t.type&&E(),w(N))}function y(t){o||(o=new MutationObserver(L)),function(t){t&&t.length>0&&(t.forEach(function(t){o.observe(t,{attributes:!0,attributeOldValue:!0,attributeFilter:[i]})}),n=n.concat(t))}(t)}function z(t){if(t){var e=t.querySelectorAll("img["+i+"]");if(e.length)return e=[].slice.call(e),n.length?function(t){var e;t.length&&(e=t.filter(function(t){return-1===n.indexOf(t)}));return e||[]}(e):e}}t.SFE=t.ebayUtils||{},t.SFE.LazyLoading={initialize:function(t){E();var n=z(document);n&&n.length&&(g?(t&&(e=t),y(n),h.forEach(function(t){addEventListener(t.eventName,t.listener,!1)})):L(n.map(function(t){return{target:t,oldValue:t.getAttribute(i)}})))},register:function(t,e){var n=z(e);n&&n.length&&(g?y(n):L(n.map(function(t){return{target:t,oldValue:t.getAttribute(i)}}))),g&&(h.push({eventName:t,listener:N}),addEventListener(t,N,!1))}}}(window);
#   </script>
#   <script>
#    window.SFE && window.SFE.LazyLoading && window.SFE.LazyLoading.initialize(300);
#   </script>
#   <script src="https://ir.ebaystatic.com/rs/c/browse-page-desktop-pr-dMU7qTrF.js">
#   </script>
#   <script>
#    $_mod.ready();
#   </script>
#   <script src="https://ir.ebaystatic.com/rs/v/caujo4kolm3x1k4ylpujl31h12h.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    (function($){ if(typeof(GHFlyout) === 'function') { new GHFlyout("/gh/watchlist?modules=WATCH_LIST", "gh-wl-click", ""); } })(GH && GH.jQ); (function($){ if(typeof(GHFlyout) === 'function') { new GHFlyout("/gh/cart?modules=MINI_CART", "", "gh-minicart-hover"); } })(GH && GH.jQ); if(typeof GH!="undefined"&&GH){GH.urls={ autocomplete_js:0,fnet_js:"https://c.paypal.com/da/r/efbv3.js",ie8_js:"https://ir.ebaystatic.com/f/rbezfuzpu20wfd2kvejeb5adxyg.js",scandal_js:"https://ir.ebaystatic.com/cr/v/c1/ScandalJS-1.2.0-v4.min.js",widget_delivery_platform:"https://ir.ebaystatic.com/cr/v/c1/globalheader_widget_platform__v2-b70676194b.js",auto_tracking_widget:"https://ir.ebaystatic.com/cr/v/c01/78cd5f76-beb8-486a-ae47-cbb49ea19309.min.js",web_resource_tracker:"https://ir.ebaystatic.com/rs/v/mjgerh5fmy51nnbwjoml1g1juqs.js",behavior_js_collection:"https://ir.ebaystatic.com/cr/v/c01/aW5ob3VzZWpzMTcxNTg5MDQ4OTMyMA==-1.0.0.min.js" }; GH.GHSW={ raptor:0,sandbox:0,emp:0,ac1:0,ac2:0,ac3:0,ac4:0,ac5:0,ac6:0,hideMobile:0,langSwitch:0,pool:0,ALERT_POPUPOFF:0,NEWALERT_POPUPOFF:0,newprofile:0,desktop_new_profile_service:"true",UNLOAD_Firefox:0,UNLOAD_Chrome:0,UNLOAD_IE:0,UNLOAD_Safari:0,ENABLE_HTTPS:"true",SEARCH_PROM:"true",MINICART:0,STICKY_HEADER:0 }; } (function(){ try { if (window && window.GH) { const rx = /[\W_]/g; window.GH.ghx = [ ...(window.GHpre?.ghxc || []).map((ghxc) => ghxc.replace(rx, ""), ), ...(window.GHpre?.ghxs || []).map((ghxs) => ghxs.replace(rx, ""), ), ]; if (window.GH.ghx?.length) { document.body.classList.add( ...window.GH.ghx.map((ghx) => 'ghx-' + ghx), ); } } } catch (e) { console.error(e); } })(); if(typeof GH!="undefined" && GH){GH_config={"lng":"es-ES","geoLang":"[]","suppressGeoUserUpdateInfo":"false","siteId":"186","xhrBaseUrl":"https://www.ebay.es","env":"production","risk_behavior_collection_interval":"{\"default\":15000,\"2507978\":5000,\"2500857\":5000}","sin":0,"pageId":2499337,"fn":"","id":""};GH.init();}
#   </script>
#   <script>
#    /* ssgST: excluded from sampling */
#   </script>
#   <!--M#s0-36-10-->
#   <script id="b-inflow-help">
#    window.$$BROWSE_INFLOW_HELP = {"baseUrl":"ebay.es","fauxPageId":"","siteId":186,"browseNodeId":""};
#   </script>
#   <!--M/-->
#   <!--M#s0-38-1-->
#   <div class="hide" id="s0-38-1">
#   </div>
#   <!--M/-->
#   <script>
#    if(document.querySelector(".pagecontainer .spinner_"+"right")){
#                 document.querySelector(".pagecontainer .spinner_"+"right").className="spinner_right spinner--hide";
#             }
#   </script>
#   <script>
#    if(document.querySelector(".pagecontainer .spinner_"+"left")){
#                 document.querySelector(".pagecontainer .spinner_"+"left").className="spinner_left spinner--hide";
#             }
#   </script>
#   <script src="https://ir.ebaystatic.com/cr/v/c1/ebay-cookies/2.js">
#   </script>
#   <script type="text/javascript">
#    (function(scope) {var trackingInfo = {"X_EBAY_C_CORRELATION_SESSION":"si=7bb3a0a91910aab2efee7e49ffff9e8c,c=1,operationId=2493618,trk-gflgs=wA**"};scope.trkCorrelationSessionInfo={};scope.trkCorrelationSessionInfo.getTrackingInfo=function(){return trackingInfo;};scope.trkCorrelationSessionInfo.getTrackingCorrelationSessionInfo=function(){return trackingInfo.X_EBAY_C_CORRELATION_SESSION};})(window)
#   </script>
#   <script type="text/javascript">
#    if(typeof raptor !== "undefined" && raptor.require){var Uri=raptor.require("ebay/legacy/utils/Uri");$uri=function(href){return new Uri(href);};window.raptor.extend(window.raptor, require("ebay/legacy/adaptor-utils"));}
#   </script>
#   <script crossorigin="" id="taasHeaderRes" src="https://ir.ebaystatic.com/cr/v/c01/nh24070265b74ffae1964cce828.js" type="text/javascript">
#   </script>
#   <script id="taasContent" type="text/javascript">
#    try {new window.TaaSTrackingCore({"psi":"As6DHIVg*","rover":{"imp":"/roverimp/0/0/9","clk":"/roverclk/0/0/9","uri":"https://rover.ebay.es"},"pid":"p2493618"});
# var _plsubtInp={"eventFamily":"DFLT","samplingRate":100, "pageLoadTime": new Date().getTime(), "pageId":2493618, "app":"Testapp", "disableImp":true};var _plsUBTTQ=[];var TaaSIdMapTrackerObj = new TaaSIdMapTracker();TaaSIdMapTrackerObj.roverService("https://rover.ebay.es/idmap/0?footer");} catch (err) { console && console.log && console.log(err); }
#   </script>
#   <script crossorigin="" id="taasFooterRes" src="https://ir.ebaystatic.com/cr/v/c01/ubt24070236dd1e675d8f4e7497.js" type="text/javascript">
#   </script>
#   <!--M#s0-41-->
#   <noscript data-marko-key="@_wbind s0-41" id="s0-41">
#   </noscript>
#   <!--M/-->
#   <!--M#s0-42-->
#   <div class="srp-mask" id="s0-42">
#   </div>
#   <!--M/-->
#   <!--M#s0-43-->
#   <div class="b-lightbox-dialog">
#    <div aria-labelledby="s0-43-1-dialog-dialog-title" aria-modal="true" class="lightbox-dialog lightbox-dialog--mask-fade" hidden="" role="dialog">
#     <div class="lightbox-dialog__window lightbox-dialog__window--animate">
#      <!--F#7-->
#      <button aria-label="Maximize Lightbox Dialog" class="lightbox-dialog__handle" type="button">
#      </button>
#      <!--F/-->
#      <div class="lightbox-dialog__header">
#       <!--F#16-->
#       <h2 class="lightbox-dialog__title" id="s0-43-1-dialog-dialog-title">
#        <!--F#1-->
#        <!--F/-->
#       </h2>
#       <!--F/-->
#       <!--F#17-->
#       <button aria-label="Close dialog" class="icon-btn lightbox-dialog__close" type="button">
#        <svg aria-hidden="true" class="icon icon--16" focusable="false">
#         <defs>
#          <symbol id="icon-close-16" viewbox="0 0 16 16">
#           <path d="M2.293 2.293a1 1 0 0 1 1.414 0L8 6.586l4.293-4.293a1 1 0 1 1 1.414 1.414L9.414 8l4.293 4.293a1 1 0 0 1-1.414 1.414L8 9.414l-4.293 4.293a1 1 0 0 1-1.414-1.414L6.586 8 2.293 3.707a1 1 0 0 1 0-1.414Z">
#           </path>
#          </symbol>
#         </defs>
#         <use href="#icon-close-16">
#         </use>
#        </svg>
#       </button>
#       <!--F/-->
#      </div>
#      <div class="lightbox-dialog__main">
#       <!--F#11-->
#       <!--F#3-->
#       <div class="content">
#       </div>
#       <!--F/-->
#       <!--F/-->
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--M/-->
#   <script>
#    $MC=(window.$MC||[]).concat({"o":{"l":1,"g":{"marketplaceId":"EBAY-ES","isBrowseV1":true,"featureFlags":{"enableHighResSwap":true},"isSignedIn":false,"isSmall":false},"w":[["s0-4",0,0,{"f":4,"w":{"siteId":186,"pageCode":"2","isMobile":"false"}}],["s0-8-0",1,{"usecase":"ads-stream"},{}],["s0-17",2,0,{"f":4}],["s0-17-5-0",3,null],["s0-20-3-0",3,null],["s0-22-3-0",3,null],["s0-23",4,{},{"f":1,"s":{"isMessageVisible":false,"model":{}}}],["s0-36-10",5,{"model":"{\"baseUrl\":\"ebay.es\",\"fauxPageId\":\"\",\"siteId\":186,\"browseNodeId\":\"\"}"}],["s0-41",6,0,{"f":4}],["s0-42",7,0,{"f":5,"s":{"hasModal":false,"className":"srp-mask"}}],["s0-43",8,{},{"f":1,"s":{"open":false,"className":"","heading":"","a11yCloseText":"Close dialog"}}],["s0-16-6-0-1[0]-1",9,{"model":{"_type":"BREADCRUMBS","meta":{"name":"BREADCRUMB","trackingList":[{"eventAction":"VIEWDTLS","operationId":"2493618","flushImmediately":false,"eventProperty":{"moduledtl":"mi:4340|iid:1|dur:"}}]},"containers":[{"_type":"CardContainer","title":{"_type":"TextualDisplay","accessibilityText":"Estás aquí"},"subTitle":{"_type":"TextualDisplay","accessibilityText":"Ir a la navegación de la página"},"cards":[{"_type":"NavigationCard","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"eBay"}],"action":{"_type":"Action","type":"NAV","trackingList":[{"actionKind":"NAV","operationId":"2493618","flushImmediately":false,"eventProperty":{"trkp":"pageci%3Af26ed942-624a-4511-bdbd-c84b9cff79e4%7Cparentrq%3A7bb3a0a81910aab2efe39e23ffffec88%7Ciid%3A1","sid":"p2493618.m4340.l8964"}},{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","operationId":"2493618","flushImmediately":false,"eventProperty":{"parentrq":"7bb3a0a81910aab2efe39e23ffffec88","pageci":"f26ed942-624a-4511-bdbd-c84b9cff79e4","moduledtl":"mi:4340|iid:1|li:8964|luid:2"}}],"URL":"https://www.ebay.es"}}},{"_type":"NavigationCard","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Smartphones reacondicionados"}]}}],"isSmall":false,"className":"b-breadcrumb__text b-link--tertiary truncate","moduleGroupTracking":{"data-view":"mi:4340|iid:1|dur:"}},{"_type":"CardContainer","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Filtrar","action":{"_type":"Action","type":"OPERATION","trackingList":[{"eventFamily":"LST","eventAction":"ACTN","actionKind":"SHOWDIALOG","actionKinds":["SHOWDIALOG"],"operationId":"2493618","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cli%3A8171%7Cluid%3A1%7C","pageci":"f26ed942-624a-4511-bdbd-c84b9cff79e4","parentrq":"7bb3a0a81910aab2efe39e23ffffec88"}}],"moduleGroup":{},"subGroup":{}}}]}}],"trackingInfo":{"moduleInstance":"mi:4340|iid:1","parentrq":"7bb3a0a81910aab2efe39e23ffffec88","trackViews":true,"trackPerf":true},"aboveTheFold":true},"extra":{}},{"f":1}],["s0-16-6-0-1[1]-1",10,{"model":{"_type":"PAGE_TITLE","title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Smartphones reacondicionados"}]},"subTitle":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"¡Ahorra dales una segunda vida!"}]},"cards":[{"title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Smartphones reacondicionados"}]},"subTitle":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"¡Ahorra dales una segunda vida!"}]},"image":{"_type":"Image","title":"Smartphones reacondicionados","imageId":"v5QAAOSwtkdkpUn1","imageIdType":"ZOOM_GUID","originalSize":{"height":376,"width":1600},"URL":"https://i.ebayimg.com/images/g/v5QAAOSwtkdkpUn1/s-l1600.jpg"},"instanceId":1,"textColor":"#07522C","backgroundColor":"#5EE471","pageTitleTemplate":"WIDE"}],"trackingInfo":{"moduleInstance":"mi:4326|iid:1","parentrq":"7bb3a0a81910aab2efe39e23ffffec88","trackViews":true,"trackPerf":true},"aboveTheFold":true,"meta":{"name":"PAGE_TITLE_BANNER"}},"timer":false,"inlineStyles":".title-banner--bgcolorimg .title-banner__layer {color:#07522C;}.title-banner--bgcolorimg .title-banner__layer ...
#   </script>
#  </body>
# </html>
# <!-- RcmdId rppevents,RlogId t6o%60~eqr%60b77%3C%3Dosukf%7Ddutcc31(1%3Eemj*w%60ut351%3E-1917bb3a0a8-0x1102 -->
# <!-- SiteId: 186, Environment: production, AppName: lexbrwfe, PageId: 2499337 -->
# <script type="text/javascript">
#  (function(scope){var CosHeaders={"X_EBAY_C_TRACKING":"guid=7bb3a0a91910aab2efee7e49ffff9e8c,pageid=2499337,cobrandId=0","X_EBAY_C_ENDUSERCTX":"clientId=urn%3Aebay-marketplace-consumerid%3A8f9a8c9f-f450-424e-9373-267ce75cd28c,userAgentAccept=*%2F*,userAgentAcceptEncoding=gzip,userAgent=python-requests%2F2.31.0,uri=%2Fe%2Fcampanas%2Fmoviles-y-smartphones-reacondicionados,applicationURL=https%3A%2F%2Fwww.ebay.es%2Fe%2Fcampanas%2Fmoviles-y-smartphones-reacondicionados,xff=212.231.126.225%2C%2092.123.116.39%2C2.17.112.4%2C10.104.158.78,isPiggybacked=false,expectSecureURL=true,physicalLocation=country%3DES%2Czip%3D35010,contextualLocation=country%3DES,origClientId=urn%3Aebay-marketplace-consumerid%3A8f9a8c9f-f450-424e-9373-267ce75cd28c"};scope.cosHeadersInfo={getCosHeaders:function(){return CosHeaders;},getTrackingHeaders:function(){return CosHeaders.X_EBAY_C_TRACKING;},getEndUserContext:function(){return CosHeaders.X_EBAY_C_ENDUSERCTX;}};})(window)
# </script>

# %% [markdown]
# Lo primero que vamos a hacer es extraer el nombre de todos los teléfonos móviles que tenemos en la página web.

# %%
# sacamos los nombres de los moviles
lista_nombre_producto = sopa_moviles.find_all("h3", {"class": "s-item__title"})

# mostramos los resultados del método ".find_all()". Como dijimos al inicio este método nos va a devolver una lista
# Si lo exploramos un poco veremos que tenemos una lista de elemento y que tiene muchas cosas, pero si nos fijamos bien tenemos todos los nombres de los teléfonos que tenemos en la página web
print("El resultado del método '.find_all()' es: \n",   lista_nombre_producto)

# es el momento de sacar la información útil del método que hemos usado previamente. Para eso lo primero que vamos a hacer es crearnos una lista donde iremos almacenado los resultados que queremos
nombres_productos = []

# dado que es una lista lo que vamos a hacer es iterar por la lista para poder acceder a cada uno de los elementos
for i in lista_nombre_producto:
    # utilizamos el método ".getText()" para sacar el texto de cada uno de los elementos y lo apendeamos a la lista que hemos creado previamente. 
    nombres_productos.append(i.getText())

print("\n--------------------------\n")

print("Los resultados de extraer el texto de cada uno de los elementos es:\n
#
# --------------------------
#
# Los resultados de extraer el texto de cada uno de los elementos es:
#  ['Móvil - Huawei Nova 9 SE, Azul, 128 GB, 8 GB, 6.78" Full HD+ 90Hz, ', 'Google Pixel 7 128GB Black Ricondizionato Grado A++', 'LG K30 Aurora Negro 2GB RAM Android 9.0 16GB Memoria Dual SIM Estado Zertifizi', 'Xiaomi Redmi Note 12 5G-Reacondicionado-Excelente', 'Google Pixel 8 Pro Obsidiana 512GB 12GB RAM, 6.7 " OLED LTPO a 489 ppp, 5050 mAh', 'Xiaomi 11T PRO 5G 8GB+256GB-Reacondicionado- Excelente', 'Xiaomi Poco F4 5G 6GB+ 128GB Negro - Reacondicionado - Excelente', 'Smartphone Oneplus Nord N100 64GB/4GB Ram Dual sim Midnight Frost Garanzia', 'XIAOMI MI 11 5G WHITE 256GB ANDROID 8GB RAM DUAL SIM DISPLAY 6.81"- DIMOSTRATIVO', 'Móvil - Huawei P40, Plata, 128 GB, 8 GB, 6.1" Full HD+, Kirin 990, 3800 ', 'XIAOMI REDMI 9C 6,53” 3GB 64GB 5000mAh 13MP TRIPLA CAM MIDNIGHT GREY DUAL SIM', 'Móvil OPPO Find X5 5G, Negro, 256GB, 8GB RAM, 6.55" FHD+, 4800mAh, Android 12', 'Xiaomi Mi Note 10 Lite 6+128gb NEBULA PURPLE display nuovo con garanzia 15 mesi', 'Huawei P40 Pro 5G Dual Sim 256GB ELS-NX9 Silver Frost  USATO', 'Xiaomi 12T 5G 8+ 256GB - Reacondicionado - Excelente', 'OnePlus 5 128 GB 8GB RAM BLACK GRADO A++ NO SCATOLA GARANZIA 12 MESI ', 'OnePlus 7T Pro Dual sim Glacier Blue 256GB/8 di RAM Android Smartphone GSM ', 'Xiaomi Redmi 9a 6,53" Dual Sim 2gb 32gb Nero Smartphone Cellulare Ricondizionato', 'XIAOMI REDMI 9A 6,53" DUAL SIM 2GB 32GB NERO SMARTPHONE CELLULARE 5000MAH 13MP-', 'XIAOMI Redmi 9c 6,53" 3gb 64gb 5000mah 13mp Triple Cam Midnight G Reformado', 'ONEPLUS 5T A5010 DUAL SIM LTE 8GB + 128GB Midnight Black Stock ITALIA GRADE AAA+', 'Xiaomi Redmi 9c 6,53" 3gb 64gb 5000mah 13mp Tripla Cam Midnight G Ricondizionato', 'HUAWEI P30 PRO GRADO A++ LTE 128GB DUALROSSO RED PARI A NUOVO RICONDIZIONATO', 'Teléfono Móvil LG Ku950 Reacondicionados Puede B', 'Smartphone Oneplus 8 pro 12/256GB\xa0 Ultramarine Blue (sbloccato) 12 gb 256 IN2023', 'Teléfono Móvil LG GU230 Nuevo Recuperado', 'Teléfono Móvil Teléfono LG G7030 Original', 'Teléfono Móvil Teléfono LG C360 Original', 'Smartphone Oneplus Nord N10 5G 128GB/6GB Ram Dual sim Midnight Frost Garanzia']

# %% [markdown]
# Seguimos extrayendo más información, ahora es el momento de sacar los precios.

# %%
# sacamos los precios usando el método ".find_all()"
lista_precios_moviles = sopa_moviles.find_all("span", {"class": "s-item__price"})
print("El resultado del método '.find_all()' es: \n",   lista_nombre_producto)

# creamos una lista vacía donde almacenaremos todos los precios que hemos extraído de la página web
precios_productos = []

# de la misma forma que con los nombres de productos, vamos a iterar por la lista para sacar todos los precios
for i in lista_precios_moviles:
    # usando el método ".getText()" sacamos el precio
    precios_productos.append(i.getText())

print("\n--------------------------\n")

print("Los resultados de extraer el texto de cada uno de los elementos es:\n
#
# --------------------------
#
# Los resultados de extraer el texto de cada uno de los elementos es:
#  ['159,00 EUR', '398,00 EUR', '61,00 EUR', '153,91 EUR a 169,94 EUR', '875,99 EUR', '244,76 EUR', '174,39 EUR', '149,00 EUR', '270,00 EUR', '349,00 EUR', '170,99 EUR', '549,00 EUR', '229,00 EUR', '385,00 EUR', '276,83 EUR a 287,52 EUR', '230,00 EUR', '399,00 EUR', '127,00 EUR', '123,63 EUR', '195,94 EUR', '269,00 EUR', '176,00 EUR', '419,00 EUR', '149,90 EUR', '489,00 EUR', '119,90 EUR', '99,90 EUR', '69,90 EUR', '239,00 EUR']

# %% [markdown]
# Si nos fijamos ya tenemos los precios de todos los teléfonos móviles, pero vemos que estos datos están en formato *string* y en realidad nos interesa que estén en formato de número por lo que tendremos que:
#
# - Eliminar la palabra "EUR"
#
# - Reemplazar las "," por ".", ya que en Python los números decimales deben ir con "."
#
# Pongamonos manos a la obra, para eso lo vamos a hacer con una *list comprehension* para recordarlas.

# %%
# creamos una list comprehension para tener los datos en el formato correcto
precios_productos = [float(precio.split()[0].replace(".", "").replace(",", ".")) for precio in precios_productos]
print("Los resultados después de limpiar la información contenida en la lista 'precios_productos' es:\n", precios_productos)
# Out:
# Los resultados después de limpiar la información contenida en la lista 'precios_productos' es:
#  [159.0, 398.0, 61.0, 153.91, 875.99, 244.76, 174.39, 149.0, 270.0, 349.0, 170.99, 549.0, 229.0, 385.0, 276.83, 230.0, 399.0, 127.0, 123.63, 195.94, 269.0, 176.0, 419.0, 149.9, 489.0, 119.9, 99.9, 69.9, 239.0]

# %%
# seguimos la misma lógica para sacar la url de la imagen del producto.
lista_imagenes_moviles = sopa_moviles.find_all("div", {"class": "s-item__image-helper"})
print("El resultado del método '.find_all()' es: \n",   lista_imagenes_moviles)

imagenes_productos = []
# iteramos por la lista para extraer todas las imagenes
for indice, imagen in enumerate(lista_imagenes_moviles):
    imagenes_productos.append(imagen.find_all("img")[0]["src"])


print("\n--------------------------\n")

print("Los resultados de extraer el texto de cada uno de los elementos es:\n", imagenes_productos)
# Out:
# El resultado del método '.find_all()' es:
#  [<div class="s-item__image-helper"><img alt='Móvil - Huawei Nova 9 SE, Azul, 128 GB, 8 GB, 6.78" Full HD+ 90Hz, ' class="s-item__image-img" data-high-res-src="https://i.ebayimg.com/thumbs/images/g/3KsAAOSw7-xlbb~W/s-l960.jpg" src="https://i.ebayimg.com/thumbs/images/g/3KsAAOSw7-xlbb~W/s-l300.jpg"/></div>, <div class="s-item__image-helper"><img alt="Google Pixel 7 128GB Black Ricondizionato Grado A++" class="s-item__image-img" data-high-res-src="https://i.ebayimg.com/thumbs/images/g/PVoAAOSw1M5mZwIY/s-l960.jpg" src="https://i.ebayimg.com/thumbs/images/g/PVoAAOSw1M5mZwIY/s-l300.jpg"/></div>, <div class="s-item__image-helper"><img alt="LG K30 Aurora Negro 2GB RAM Android 9.0 16GB Memoria Dual SIM Estado Zertifizi" class="s-item__image-img" data-high-res-src="https://i.ebayimg.com/thumbs/images/g/WpUAAOSwSpRjM-wE/s-l960.jpg" src="https://i.ebayimg.com/thumbs/images/g/WpUAAOSwSpRjM-wE/s-l300.jpg"/></div>, <div class="s-item__image-helper"><img alt="Xiaomi Redmi Note 12 5G-Reacondicionado-Excelente" class="s-item__image-img" data-high-res-src="https://i.ebayimg.com/thumbs/images/g/qVQAAOSwi-tmMK1X/s-l960.jpg" src="https://i.ebayimg.com/thumbs/images/g/qVQAAOSwi-tmMK1X/s-l300.jpg"/></div>, <div class="s-item__image-helper"><img alt='Google Pixel 8 Pro Obsidiana 512GB 12GB RAM, 6.7 " OLED LTPO a 489 ppp, 5050 mAh' class="s-item__image-img" data-high-res-src="https://i.ebayimg.com/thumbs/images/g
 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif']

# %%
# vamos a crearnos una función donde almacenemos todo este código y lo podamos hacer todo del tirón, sin necesidad de tener que estar repitiendo código todo el rato. 
def sacar_moviles_ebay(url):
    
    """
    Extrae información de teléfonos móviles en venta desde una página web de eBay.

    Parameters:
        url (str): La URL de la página web de eBay que contiene la información de los teléfonos móviles.

    Returns:
        dict: Un diccionario con la información de los teléfonos móviles, que incluye nombres, precios,
              tipos de envío e imágenes.
    """
    
    res_moviles_ebay = requests.get(url_moviles)

    # vemos si todo ha ido bien
    print("La respuesta de la petición es:", res_moviles_ebay.status_code)
    
    sopa_moviles_ebay = BeautifulSoup(res_moviles_ebay.content, 'html.parser')
    
    # sacamos los nombres de los teléfonos móviles
    lista_nombre_producto_ebay = sopa_moviles_ebay.find_all("h3", {"class": "s-item__title"})

    # sacamos los precios de los teléfonos móviles
    lista_precios_moviles_ebay = sopa_moviles_ebay.find_all("span", {"class": "s-item__price"})
    

    # sacamos las url de las imagenes de los móviles
    lista_imagenes_moviles_ebay = sopa_moviles_ebay.find_all("div", {"class": "s-item__image-helper"})

    # vamos a juntar todas las listas que han sido tratadas de la misma forma, es decir, todas menos la última (en esta recordad que usamos el método enumerate())
    
    lista_elementos = [lista_nombre_producto_ebay, lista_precios_moviles_ebay]#, lista_envio_moviles_ebay]
    # keys = ["nombre", "precio"]
    
    diccionario = {"nombre": [], "precio": [], "imagen":[]}
    
    for key, lista in zip(diccionario.keys(), lista_elementos):
        textos = [i.getText() for i in lista]
        
        if key == "precio":
            textos = [float(precio.split()[0].replace(".", "").replace(",", ".")) for precio in textos]

        diccionario[key] = textos
    
    # solo nos falta sacar la información de las imagenes, que recordemos lo habíamos sacado usando el método enumerate()
    imagenes_productos_ebay = []
    # iteramos por la lista para extraer todas las imagenes
    # for indice, imagen in enumerate(lista_imagenes_moviles_ebay):
    #     imagenes_productos_ebay.append(imagen.find_all("img")[0]["src"])
    for imagen in lista_imagenes_moviles_ebay:
        imagenes_productos_ebay.append(imagen.find_all("img")[0]["src"])
    diccionario["imagen"] = imagenes_productos_ebay
    return diccionario

# %%
datos_ebay = sacar_moviles_ebay(url_moviles)
print("el resultado de nuestra función es:", datos_ebay)
# Out:
# La respuesta de la petición es: 200
# el resultado de nuestra función es: {'nombre': ['Móvil - Huawei Nova 9 SE, Azul, 128 GB, 8 GB, 6.78" Full HD+ 90Hz, ', 'Google Pixel 7 128GB Black Ricondizionato Grado A++', 'LG K30 Aurora Negro 2GB RAM Android 9.0 16GB Memoria Dual SIM Estado Zertifizi', 'Xiaomi Redmi Note 12 5G-Reacondicionado-Excelente', 'Google Pixel 8 Pro Obsidiana 512GB 12GB RAM, 6.7 " OLED LTPO a 489 ppp, 5050 mAh', 'Xiaomi 11T PRO 5G 8GB+256GB-Reacondicionado- Excelente', 'Xiaomi Poco F4 5G 6GB+ 128GB Negro - Reacondicionado - Excelente', 'Smartphone Oneplus Nord N100 64GB/4GB Ram Dual sim Midnight Frost Garanzia', 'XIAOMI MI 11 5G WHITE 256GB ANDROID 8GB RAM DUAL SIM DISPLAY 6.81"- DIMOSTRATIVO', 'Móvil - Huawei P40, Plata, 128 GB, 8 GB, 6.1" Full HD+, Kirin 990, 3800 ', 'XIAOMI REDMI 9C 6,53” 3GB 64GB 5000mAh 13MP TRIPLA CAM MIDNIGHT GREY DUAL SIM', 'Móvil OPPO Find X5 5G, Negro, 256GB, 8GB RAM, 6.55" FHD+, 4800mAh, Android 12', 'Xiaomi Mi Note 10 Lite 6+128gb NEBULA PURPLE display nuovo con garanzia 15 mesi', 'Huawei P40 Pro 5G Dual Sim 256GB ELS-NX9 Silver Frost  USATO', 'Xiaomi 12T 5G 8+ 256GB - Reacondicionado - Excelente', 'OnePlus 5 128 GB 8GB RAM BLACK GRADO A++ NO SCATOLA GARANZIA 12 MESI ', 'OnePlus 7T Pro Dual sim Glacier Blue 256GB/8 di RAM Android Smartphone GSM ', 'Xiaomi Redmi 9a 6,53" Dual Sim 2gb 32gb Nero Smartphone Cellulare Ricondizionato', 'XIAOMI REDMI 9A 6,53" DUAL SIM 2GB 32GB NERO SMARTPHONE CELLULARE 5000MAH 13MP-', 'XIAOMI Redmi 9c 6,53" 3gb 64gb 5000mah 13mp Triple Cam Midnight G Reformado', 'ONEPLUS 5T A5010 DUAL SIM LTE 8GB + 128GB Midnight Black Stock ITALIA GRADE AAA+', 'Xiaomi Redmi 9c 6,53" 3gb 64gb 5000mah 13mp Tripla Cam Midnight G Ricondizionato', 'HUAWEI P30 PRO GRADO A++ LTE 128GB DUALROSSO RED PARI A NUOVO RICONDIZIONATO', 'Teléfono Móvil LG Ku950 Reacondicionados Puede B', 'Smartphone Oneplus 8 pro 12/256GB\xa0 Ultramarine Blue (sbloccato) 12 gb 256 IN2023', 'Teléfono Móvil LG GU230 Nuevo Recuperado', 'Teléfono Móvil Teléfono LG G7030 Original', 'Teléfono Móvil Teléfono LG C360 Original', 'Smartphone Oneplus Nord N10 5G 128GB/6GB Ram Dual sim Midnight Frost Garanzia'], 'precio': [159.0, 398.0, 61.0, 153.91, 875.99, 244.76, 174.39, 149.0, 270.0, 349.0, 170.99, 549.0, 229.0, 385.0, 276.83, 230.0, 399.0, 127.0, 123.63, 195.94, 269.0, 176.0, 419.0, 149.9, 489.0, 119.9, 99.9, 69.9, 239.0], 'imagen': ['https://i.ebayimg.com/thumbs/images/g/3KsAAOSw7-xlbb~W/s-l300.jpg', 'https://i.ebayimg.com/thumbs/images/g/PVoAAOSw1M5mZwIY/s-l300.jpg', 'https://i.ebayimg.com/thumbs/images/g/WpUAAOSwSpRjM-wE/s-l300.jpg', 'https://i.ebayimg.com/thumbs/images/g/qVQAAOSwi-tmMK1X/s-l300.jpg', 'https://i.ebayimg.com/thumbs/images/g/6tYAAOSwmpVmZ0Bk/s-l300.jpg', 'https://i.ebayimg.com/thumbs/images/g/V9cAAOSwkn1lfFll/s-l300.jpg', 'https://i.ebayimg.com/thumbs/images/g/I4AAAOSwPnxmRdLJ/s-l300.jpg', 'https://i.ebayimg.com/thumbs/images/g/pUAAAOSwWc1iF0rW/s-l300.jpg', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif', 'https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif']}

# %% [markdown]
# Esto lo hemos hecho solo para una página, pero si nos fijamos en la página web hay muchas más páginas y veamos en que se difererian las unas de las otras:

# %%
# Inicializamos un bucle que recorrerá 6 páginas de resultados en eBay
for pagina in range(1,3):
    # Construimos la URL de la página actual con el número de página
    url_moviles_todos = f"https://www.ebay.es/e/campanas/moviles-y-smartphones-reacondicionados?_pgn={pagina}"
    
    # Llamamos a la función 'sacar_moviles_ebay' para extraer información de los móviles en la página actual
    todos_resultados_moviles = sacar_moviles_ebay(url_moviles_todos)

# Al final del bucle, 'todos_resultados_moviles' contendrá la información de la última página procesada.
# Out:
# La respuesta de la petición es: 200
# La respuesta de la petición es: 200

# %% [markdown]
# ## Pandas
#
# **Pandas** es una de las librerías más populares de Python utilizada en el análisis de datos y la manipulación de estructuras de datos. Proporciona estructuras de datos y herramientas de manipulación de alto rendimiento, diseñadas específicamente para facilitar el trabajo con datos estructurados o tabulares.
#
# La estructura de datos principal en **Pandas** se llama *DataFrame*, que es esencialmente una tabla de datos bidimensional con columnas etiquetadas y filas indexadas (como un Excel con el que puede que si estés más familiarizada). Los *DataFrames* en Pandas permiten almacenar y manipular datos de manera eficiente, ofreciendo una amplia gama de funciones para filtrar, seleccionar, agregar y transformar datos.
#
# La librería Pandas proporciona numerosas funciones y métodos para realizar operaciones comunes de análisis de datos, como la limpieza y preparación de datos, la agregación y resumen de datos, el filtrado y selección de datos, la manipulación de fechas y mucho más. También permite leer y escribir datos en varios formatos, como archivos CSV, Excel, SQL, entre otros.
#
# Como analistas de datos utilizaremos Pandas por varias razones. Algunas de las más importantes son:
#
# 1. **Manipulación y limpieza de datos**:  ofrece una amplia gama de funciones y métodos que facilitan la manipulación y limpieza de datos. Permite cargar datos desde diferentes fuentes, como archivos CSV, Excel, SQL, etc., y ofrece herramientas para filtrar y seleccionar datos, eliminar valores nulos, cambiar el formato de datos, etc. Estas capacidades son esenciales para preparar y transformar los datos antes de realizar el análisis.
#
# 2. **Análisis exploratorio de datos**: proporciona herramientas eficientes para realizar un análisis exploratorio de datos. Permite realizar operaciones estadísticas básicas, calcular medidas de resumen, explorar correlaciones entre variables y crear visualizaciones para comprender mejor los datos. Esto ayuda a los analistas de datos a obtener información rápida sobre la distribución de los datos, las tendencias y las relaciones entre las variables.
#
# 3. **Indexación y selección de datos**: facilita la indexación y selección de datos en un DataFrame. Permite acceder a columnas y filas específicas, filtrar datos según condiciones específicas y realizar operaciones avanzadas de indexación y selección. Estas capacidades son cruciales para extraer los datos relevantes necesarios para un análisis específico.
#
# 4. **Combinación y agregación de datos**: Los analistas de datos a menudo necesitan combinar y agregar datos de diferentes fuentes. Pandas ofrece funcionalidades para fusionar, unir y concatenar DataFrames, lo que permite combinar datos de diferentes tablas y realizar operaciones de agregación, como sumarización de datos, agrupación y cálculo de estadísticas descriptivas.

# %%
# convertir el diccionario en DataFrame
# usar el método pd.DataFrame(), que es uno de los métodos que más usaremos más a menudo durante estas lecciones
# esta tabla la almacenaremos en una variable llamada "df"

df = pd.DataFrame(todos_resultados_moviles)

# utilizaremos el método .head() para mostrar las 5 primeras filas del dataframe generado en el paso anterior
df.head()
# Out:
#                                               nombre  precio  \
# 0  Móvil - Huawei Nova 9 SE, Azul, 128 GB, 8 GB, ...  159.00
# 1  Google Pixel 7 128GB Black Ricondizionato Grad...  398.00
# 2  LG K30 Aurora Negro 2GB RAM Android 9.0 16GB M...   61.00
# 3  Xiaomi Redmi Note 12 5G-Reacondicionado-Excelente  153.91
# 4  Google Pixel 8 Pro Obsidiana 512GB 12GB RAM, 6...  875.99
#
#                                               imagen
# 0  https://i.ebayimg.com/thumbs/images/g/3KsAAOSw...
# 1  https://i.ebayimg.com/thumbs/images/g/PVoAAOSw...
# 2  https://i.ebayimg.com/thumbs/images/g/WpUAAOSw...
# 3  https://i.ebayimg.com/thumbs/images/g/qVQAAOSw...
# 4  https://i.ebayimg.com/thumbs/images/g/6tYAAOSw...

# %%
# si queremos sacar las últimas filas del dataframe usaremos el método .tail()
df.tail()
# Out:
#                                                nombre  precio  \
# 24  Smartphone Oneplus 8 pro 12/256GB  Ultramarine...   489.0
# 25           Teléfono Móvil LG GU230 Nuevo Recuperado   119.9
# 26          Teléfono Móvil Teléfono LG G7030 Original    99.9
# 27           Teléfono Móvil Teléfono LG C360 Original    69.9
# 28  Smartphone Oneplus Nord N10 5G 128GB/6GB Ram D...   239.0
#
#                                          imagen
# 24  https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif
# 25  https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif
# 26  https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif
# 27  https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif
# 28  https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif

# %%
# ¿cuántas filas y columnas tenemos en el dataframe? usaremos el método .shape
# fijaos que este método nos devuelve una tupla con dos elementos. 
# el PRIMERO de los elementos hace referencia al número de FILAS
# el SEGUNDO de los elementos hace referencia al número de COLUMNAS
df.shape
# Out:
# (29, 3)

# %%
# ¿cuáles son los tipos de datos que tenemos en cada columna?
# para eso usaremos el método .dtypes
# 📌 NOTA: en Pandas los strings son mostrados como tipo "object"
df.dtypes
# Out:
# nombre     object
# precio    float64
# imagen     object
# dtype: object

# %%
# en Pandas tenemos un método que aglutina toda la información que hemos visto hasta ahora, 
# ese método es el ".info()"
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nombre  29 non-null     object
#  1   precio  29 non-null     float64
#  2   imagen  29 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 824.0+ bytes

# %%
# Pandas también nos permiten extraer los principales estadísticos de nuestro conjunto de datos. 
# usaremos el método ".describe()"
# es importante destacar que por defecto este método nos va a devolver los principales estadísticos de las variables de tipo numérico
df.describe().T
# Out:
#         count        mean         std   min    25%    50%    75%     max
# precio   29.0  260.449655  172.708028  61.0  149.9  229.0  349.0  875.99

# %%
# si quisieramos saber cuales son los principales estadísticos de las variables categóricas tendremos que incluir un parámetro en el método ".describe()"
# este parámetro es el "include"
df.describe(include = "object").T
# Out:
#        count unique                                                top freq
# nombre    29     29  Móvil - Huawei Nova 9 SE, Azul, 128 GB, 8 GB, ...    1
# imagen    29      9        https://ir.ebaystatic.com/cr/v/c1/s_1x2.gif   21

# %%
# nos puede interesar saber si tenemos valores nulos en nuestro conjunto de datos. 
# para eso tendremos que usar el método ".isnull()" 
df.isnull().sum()
# Out:
# nombre    0
# precio    0
# imagen    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset = "precio").sum()
# Out:
# 0

# %% [markdown]
# # Sacando datos de una tabla
#
# En ocasiones, como analistas de datos, nos puede interesar obtener información específica de una tabla que se encuentra en una página web. La extracción de datos de una tabla en una página web implica un proceso un poco diferente en comparación con la extracción de información de texto plano. Como en el ejemplo anterio, utilizaremos la biblioteca Pandas en combinación con otras bibliotecas como `requests` y `BeautifulSoup` para lograr esto.
#
# El escenario particular que abordaremos es la extracción de datos del histórico de los precios del IBEX-35. El IBEX-35 es un índice bursátil compuesto por las 35 empresas con mayor capitalización en la Bolsa de Madrid. Estos datos históricos de precios nos brindan información valiosa para el análisis y seguimiento de los mercados financieros.
#
#
# Algunas de las preguntas que podríamos contestar con estos datos son:
#
# 1. **¿Cuál ha sido la tendencia general del IBEX-35 en un período de tiempo específico?** Podemos analizar los precios de cierre del IBEX-35 a lo largo del tiempo y determinar si ha habido una tendencia alcista, bajista o lateral. Podemos identificar períodos de crecimiento sostenido, caídas significativas o momentos de estabilidad.
#
# 2. **¿Cuáles han sido los máximos y mínimos históricos del IBEX-35?** Podemos identificar los puntos más altos y más bajos alcanzados por el índice a lo largo de su historia. Esto puede ser útil para evaluar el rendimiento general y la volatilidad del mercado.
#
# 3. **¿Cuáles han sido los cambios porcentuales diarios o mensuales del IBEX-35?** Podemos calcular los cambios porcentuales diarios o mensuales en el valor del índice para identificar períodos de alta volatilidad o estabilidad. Esto puede proporcionar información sobre la magnitud y la frecuencia de los movimientos del mercado.
#
# 4. **¿Cuáles son los patrones estacionales o cíclicos en el comportamiento del IBEX-35?** Podemos analizar los datos históricos para identificar patrones estacionales o cíclicos en el rendimiento del índice. Por ejemplo, podríamos examinar si hay tendencias específicas asociadas con ciertos meses del año o días de la semana.
#
# Estas son solo algunas preguntas que podríamos responder utilizando los datos históricos del IBEX-35. Dependiendo de los objetivos de análisis y las necesidades específicas, podremos formular preguntas adicionales y realizar análisis más detallados para comprender mejor el comportamiento y las tendencias del mercado.

# %%
# al igual que en el ejemplo anterior lo primero que haremos será definir la url de la página de la vamos a sacar datos
url_bolsa = "https://www.bolsamania.com/indice/IBEX-35/historico-precios"

# hacemos la request a la página de la que queremos sacar la info
res_bolsa = requests.get(url_bolsa)

# vemos si todo ha ido bien
print("La respuesta de la petición es:", res_bolsa.status_code)
# Out:
# La respuesta de la petición es: 200

# %%
# creamos el objeto BeautifulSoup para poder acceder al contenido solicitado
sopa_bolsa = BeautifulSoup(res_bolsa.content, 'html.parser')

# recordemos que el método .prettify nos permite mostrar de una forma más amigable los resultados obtenidos de la sopa
print(sopa_bolsa.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es" xml:lang="es">
#  <head>
#   <title>
#    Precios históricos de IBEX 35  - Bolsamania.com
#   </title>
#   <link href="https://www.bolsamania.com/rss/generarRss2.php" rel="alternate" title="RSS de bolsamania" type="application/rss+xml"/>
#   <meta content="Precios históricos de IBEX 35  - Bolsamania.com" name="title"/>
#   <meta content="Precios históricos de IBEX 35" name="description"/>
#   <meta content="bolsa,portal,financiero,cotizaciones,madrid,actualidad,bursatil,noticias,cartera,recomendaciones,mercado,continuo,ibex,divisas,finanzas,mercados, IBEX 35,fsSector:fs_" name="keywords"/>
#   <meta content="vQvvK3aWyocxI4jZrUYY1wlUpVGsOTMHg2qPFieRTUA" name="google-site-verification"/>
#   <meta content="1436008526699345" property="fb:pages"/>
#   <meta content="6wdyrqwezubh8d1ltqd7vnmi6tyusa" name="facebook-domain-verification"/>
#   <meta content="Madrid, Spain" name="locality"/>
#   <meta content="Web Financial Group, S.A." name="author"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <meta content="es-es" http-equiv="language"/>
#    <script type="text/javascript">
#     var rfrsh = setTimeout(function() { window.location = location.href; }, eval(180 * 1000));
#    </script>
#    <noscript>
#     <meta content="180" http-equiv="refresh"/>
#    </noscript>
#    <meta content="app-id=1251409805" name="apple-itunes-app"/>
#    <meta content="app-id=com.web.financialgroup.webfg" name="google-play-app"/>
#    <meta content="ads" name="wfg"/>
#    <script>
#     (function(){
#         window.$vortex=window.$vortex||[];
#         $vortex.push(function(){
#             var vortexConfig=[
#                 {
#                   type:"cmp",
#                   enabled:false
#                 },
#                 {
#                     type:"adserver",
#                     setup:"full",
#                     adUnit:"ES_BOLSAMANIA/HOME/INDICE/HISTORICO_PRECIOS"
#                 },
#                 {
#                     type:"page",
#                     keywords:["bolsa","portal","financiero","cotizaciones","madrid","actualidad","bursatil","noticias","cartera","recomendaciones","mercado","continuo","ibex","divisas","finanzas","mercados","_ibex_35","fs_"],
#                     taxonomies:["1","1-1","1-1-12","1-1-7"],
#                     entities:["ibex_35"]
#                 },
#                 {
#                     type:"adSlots",
#                     positions:"skin,sky,ldb,mpu,itx"
#                 }
#             ];
#             $vortex.setConf(vortexConfig);
#         });
#         var vortex_script=document.createElement('script');
#         vortex_script.setAttribute("async","async");
#         vortex_script.setAttribute("src","https://vm.s3wfg.com/js/vortexloader.js?v=20240624");
#         (document.body||document.head).appendChild(vortex_script);
#
#         document.addEventListener('DOMContentLoaded', function(){
#             var closable=document.getElementsByClassName('__adclose');
#             for (var i = 0; i < closable.length; i++) {
#                 closable[i].onclick = function(){
#                     var ad_parent = this.closest('.ads-parent');
#                     ad_parent.removeChild(ad_parent.childNodes[0]);
#                 }
#             }
#         }, false);
#     })();
#    </script>
#    <link href="//rsrc.s3wfg.com/web/faviconBMSv2.ico" rel="Shortcut Icon"/>
#    <link href="//rsrc.s3wfg.com/web/img/icons/iconnApp_small.jpg" rel="apple-touch-icon"/>
#    <link href="//rsrc.s3wfg.com/web/img/icons/iconnApp_small.jpg" rel="android-touch-icon"/>
#    <!--
# <script type="text/javascript">
# var css_bundle = document.createElement('link');
# css_bundle.rel = 'stylesheet';
# css_bundle.href = '';
# css_bundle.type = 'text/css';
# var godefer = document.getElementsByTagName('link')[0];
# godefer.parentNode.insertBefore(css_bundle, godefer);
# </script>
# <noscript>
#   <link rel="stylesheet" type="text/css" href="" />
# </noscript>
# -->
#    <link href="https://rsrc.s3wfg.com/web/webpack/build/css/bolsamania.bundle.css?v=e4f7630fa08424916c090ab71f638fdc_20240624" media="all" rel="stylesheet" type="text/css"/>
#    <!-- Google Tag Manager -->
#    <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NGNRZVQ9');
#    </script>
#    <!-- End Google Tag Manager -->
#    <!--[if lt IE 10]>
#     <script type="text/javascript" src="http://cdnjs.cloudflare.com/ajax/libs/jquery-ajaxtransport-xdomainrequest/1.0.3/jquery.xdomainrequest.min.js"></script>
# <![endif]-->
#    <script async="" src="https://cdn.gravitec.net/storage/2b08c84d123b20fdb770c2ac73dd8e37/client.js">
#    </script>
#    <!--Flipboard button-->
#    <script async="" src="//cdn.flipboard.com/web/buttons/js/flbuttons.min.js" type="text/javascript">
#    </script>
#    <!--[if lt IE 8]><script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script><![endif]-->
#    <!--[if lt IE 9]>
# 	<script type="text/javascript">
# 		document.createElement("nav");
# 		document.createElement("header");
# 		document.createElement("footer");
# 		document.createElement("section");
# 		document.createElement("article");
# 		document.createElement("aside");
# 		document.createElement("hgroup");
# 		document.createElement('video');
# 		document.createElement('audio');
# 		document.createElement('track');
# 	</script>
# <![endif]-->
#    <script>
#     var WFG = WFG || {
#         'LS': {
#             'loadTableConf': function() {},
#             'addLsTable': function() {},
#             'removeLsTable': function() {},
#             'checkLsEngine': function() {},
#             'loadItemConf': function() {}
#         },
#         'testServer': {
#             'init': function() {}
#         }
#     };
#
#     var _site = '';
#     var _domain = 'https://www.bolsamania.com/';
#    </script>
#    <!-- Custom tags -->
#    <meta content="https://www.bolsamania.com/indice/IBEX-35/historico-precios" name="canonical"/>
#    <link as="html" crossorigin="use-credentials" href="https://www.bolsamania.com/scroll_2/indice/IBEX-35/historico-precios" rel="prefetch"/>
#    <link as="html" crossorigin="use-credentials" href="https://www.bolsamania.com/scroll_3/indice/IBEX-35/warrants" rel="prefetch"/>
#    <link as="html" crossorigin="use-credentials" href="https://www.bolsamania.com/scroll_4/indice/IBEX-35/ficha" rel="prefetch"/>
#    <link as="html" crossorigin="use-credentials" href="https://www.bolsamania.com/scroll_5/indice/IBEX-35/noticias" rel="prefetch"/>
#    <meta content="Mon, 24 Jun 2024 12:07:36 +0200" name="last-modified"/>
#    <script defer="" type="module">
#     import { start } from 'https://adgage.adkaora.space/vortexmedia/generic/prod/adk-init.js'
#    </script>
#    <!-- End Custom tags -->
#   </meta>
#  </head>
#  <body class="section_fact_sheet_v2" id="section_mediav1.0|bolsamania_fact_sheet_v2_38d974fc78818d0797deab2892acf957_es_s">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NGNRZVQ9" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!-- Begin google-analytics Tag BMS-->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-Y9XKHVSX71">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'G-Y9XKHVSX71');
#   </script>
#   <!-- End google-analytics Tag BMS-->
#   <!-- Begin Bing Tag BMS-->
#   <script>
#    (function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"5564975"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");
#   </script>
#   <noscript>
#    <img alt="tag bing" height="0" src="//bat.bing.com/action/0?ti=5564975&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/>
#   </noscript>
#   <!-- End Bing Tag BMS-->
#   <ins vtx-conf="{}" vtx-position="skin">
#   </ins>
#   <div class="adk-slot interstitial">
#    <div id="adk_interstitial0">
#    </div>
#    <div id="adk_interstitial">
#    </div>
#   </div>
#   <div id="bmsapp">
#    <div class="clearfix ads-parent">
#     <div class="banner">
#      <ins vtx-conf='{"onDemand":true,"label":"leftTower","minWidth":"1700","top":"50px","relative":".container"}' vtx-position="sky">
#      </ins>
#     </div>
#    </div>
#    <div class="clearfix ads-parent">
#     <div class="banner">
#      <ins vtx-conf='{"onDemand":true,"label":"rightTower","minWidth":"1700","top":"50px","relative":".container"}' vtx-position="sky">
#      </ins>
#     </div>
#    </div>
#    <div class="cabecera-rail">
#     <div class="container max-width-md">
#      <div class="header-banner">
#       <div class="clearfix ads-parent">
#        <div class="fixed-height-banner">
#         <ins vtx-conf="{}" vtx-position="ldb">
#         </ins>
#        </div>
#       </div>
#      </div>
#     </div>
#     <header class="main-header" ref="mainHeader">
#      <div class="container max-width-md">
#       <div class="flex items-center justify-between">
#        <div class="menu-display">
#         <div class="menuNavButton hamburger hamburger--elastic" v-on:click="showHideMenus('bolsamania')">
#          <div class="hamburger-box">
#           <div class="hamburger-inner">
#           </div>
#          </div>
#         </div>
#         <a class="small-logo" href="https://www.bolsamania.com/">
#          <img alt="Bolsamania.com" class="logo" src="//rsrc.s3wfg.com/web/img/logos/svg/small-logo-bm.svg" style="width: 100px"/>
#         </a>
#        </div>
#        <div class="center-box">
#         <a class="main-logo" href="https://www.bolsamania.com/">
#          <strong class="is-hidden">
#           Bolsamania
#          </strong>
#          <span class="logoBM">
#           <img alt="Bolsamania.com" class="logo" src="//rsrc.s3wfg.com/web/img/logos/svg/bolsamania-mainlogo.svg"/>
#          </span>
#         </a>
#         <time class="date-home display@lg">
#          24 jun, 2024                        |
#                         Actualizado a las                        12:00
#         </time>
#        </div>
#        <div class="flex flex-column button-group">
#         <a aria-label="modal buscar" class="btn btn-header display@sm search-btn" data-params='{"modal":true}' data-target="#headerModal" data-toggle="modal" data-uri="/busqueda.html" href="#" role="button" v-on:click="loadModal">
#          <i class="icon">
#           <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10,18c1.846,0,3.543-0.635,4.897-1.688l4.396,4.396l1.414-1.414l-4.396-4.396C17.365,13.543,18,11.846,18,10 c0-4.411-3.589-8-8-8s-8,3.589-8,8S5.589,18,10,18z M10,4c3.309,0,6,2.691,6,6s-2.691,6-6,6s-6-2.691-6-6S6.691,4,10,4z">
#            </path>
#           </svg>
#          </i>
#          <span>
#           Buscar
#          </span>
#         </a>
#         <template v-if="menus.user">
#          <div class="user-menu">
#           <span class="btn btn-header user-menu-btn margin-top-xs" v-expand-user-menu="">
#            <i class="icon">
#             <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M7.5 6.5C7.5 8.981 9.519 11 12 11s4.5-2.019 4.5-4.5S14.481 2 12 2 7.5 4.019 7.5 6.5zM20 21h1v-1c0-3.859-3.141-7-7-7h-4c-3.86 0-7 3.141-7 7v1h1 1 14H20z">
#              </path>
#             </svg>
#            </i>
#            <span>
#             Mi perfil
#            </span>
#           </span>
#           <div class="hide" v-fold-user-menu="">
#            <ul aria-labelledby="dropdownMenuUser" class="dropdown-menu">
#             <div class="user-whois">
#              <i v-bind:class="'user-profile-pic user-' + menus.user.letter">
#              </i>
#              <h3>
#               {{ menus.user.data_crypt.username }}
#              </h3>
#             </div>
#             <template v-for="item in menus.user.menu">
#              <li v-if="item.link">
#               <a v-bind:href="item.link">
#                <i class="icon" v-bind:class="item.icon">
#                </i>
#                {{item.text}}
#               </a>
#              </li>
#              <li v-bind:class="item.icon" v-bind:role="item.text" v-else="">
#              </li>
#             </template>
#            </ul>
#           </div>
#          </div>
#         </template>
#         <template v-else="">
#          <a aria-label="modal login" class="btn btn-header user-menu-btn margin-top-xs" data-params='{"modal":true}' data-target="#headerModal" data-toggle="modal" data-uri="/login.html" href="#" role="button" v-on:click="loadModal">
#           <i class="icon">
#            <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M10.998 16L15.998 12 10.998 8 10.998 11 1.998 11 1.998 13 10.998 13z">
#             </path>
#             <path d="M12.999,2.999c-2.405,0-4.665,0.937-6.364,2.637L8.049,7.05c1.322-1.322,3.08-2.051,4.95-2.051s3.628,0.729,4.95,2.051 S20,10.13,20,12s-0.729,3.628-2.051,4.95s-3.08,2.051-4.95,2.051s-3.628-0.729-4.95-2.051l-1.414,1.414 c1.699,1.7,3.959,2.637,6.364,2.637s4.665-0.937,6.364-2.637C21.063,16.665,22,14.405,22,12s-0.937-4.665-2.637-6.364 C17.664,3.936,15.404,2.999,12.999,2.999z">
#             </path>
#            </svg>
#           </i>
#           <span>
#            Acceder
#           </span>
#          </a>
#         </template>
#        </div>
#       </div>
#       <div class="main-section-header">
#        <div class="mask">
#         <div>
#          <nav class="main-quick-navbar flex items-center justify-between">
#           <ul>
#            <li>
#             <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#              Cotizaciones
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/ultimas/index.html">
#              Noticias
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/analisis-de-bolsa.html">
#              Análisis
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/criptodivisas/index.html">
#              Criptodivisas
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/mi-cartera">
#              Mi Cartera
#              <sup style="color:#000;font-size: 0.7em;">
#               Nuevo
#              </sup>
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a href="https://www.bolsamania.com/tiempo-real.html">
#              Tiempo Real
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/trader_watch.html">
#              Trader Watch
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <div class="card card-market margin-left-xs ibex-quick-rewiew">
#           <div>
#            <div class="flex justify-between">
#             <h2 class="card-name">
#              <a href="https://www.bolsamania.com/indice/IBEX-35" target="_self" title="IBEX 35">
#               IBEX 35
#              </a>
#             </h2>
#            </div>
#            <div class="">
#             <ul class="flex justify-between">
#              <li class="card-list">
#               11.095,600
#              </li>
#              <li class="card-list">
#               <span class="greenarrowleft">
#                0,57%
#               </span>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="is-hidden" v-ls-conf="[]">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </header>
#    </div>
#    <nav class="main-header-navbar">
#     <ul class="follow-us">
#      <li>
#       <a aria-label="button ir a bolsamania twitter" href="https://twitter.com/bolsamania" rel="noopener" role="button" target="_blank">
#        <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <title>
#          Ir a Twitter de Bolsamania
#         </title>
#         <path d="M19.633,7.997c0.013,0.175,0.013,0.349,0.013,0.523c0,5.325-4.053,11.461-11.46,11.461c-2.282,0-4.402-0.661-6.186-1.809	c0.324,0.037,0.636,0.05,0.973,0.05c1.883,0,3.616-0.636,5.001-1.721c-1.771-0.037-3.255-1.197-3.767-2.793	c0.249,0.037,0.499,0.062,0.761,0.062c0.361,0,0.724-0.05,1.061-0.137c-1.847-0.374-3.23-1.995-3.23-3.953v-0.05	c0.537,0.299,1.16,0.486,1.82,0.511C3.534,9.419,2.823,8.184,2.823,6.787c0-0.748,0.199-1.434,0.548-2.032	c1.983,2.443,4.964,4.04,8.306,4.215c-0.062-0.3-0.1-0.611-0.1-0.923c0-2.22,1.796-4.028,4.028-4.028	c1.16,0,2.207,0.486,2.943,1.272c0.91-0.175,1.782-0.512,2.556-0.973c-0.299,0.935-0.936,1.721-1.771,2.22	c0.811-0.088,1.597-0.312,2.319-0.624C21.104,6.712,20.419,7.423,19.633,7.997z">
#         </path>
#        </svg>
#       </a>
#      </li>
#      <li>
#       <a aria-label="button ir a bolsamania facebook" href="https://www.facebook.com/Bolsamania" rel="noopener" role="button" target="_blank">
#        <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <title>
#          Ir a Facebook de Bolsamania
#         </title>
#         <path d="M13.397,20.997v-8.196h2.765l0.411-3.209h-3.176V7.548c0-0.926,0.258-1.56,1.587-1.56h1.684V3.127	C15.849,3.039,15.025,2.997,14.201,3c-2.444,0-4.122,1.492-4.122,4.231v2.355H7.332v3.209h2.753v8.202H13.397z">
#         </path>
#        </svg>
#       </a>
#      </li>
#      <li>
#       <a aria-label="button ir a bolsamania flipboard" href="https://flipboard.com/@Bolsamania?utm_campaign=tools&amp;utm_medium=follow&amp;action=follow&amp;utm_source=www.bolsamania.com" rel="noopener" role="button" target="_blank">
#        <svg aria-hidden="true" height="24" viewbox="0 0 448 512" width="24">
#         <title>
#          Ir a Flipboard de Bolsamania
#         </title>
#         <path d="M0 32v448h448V32H0zm358.4 179.2h-89.6v89.6h-89.6v89.6H89.6V121.6h268.8v89.6z">
#         </path>
#        </svg>
#       </a>
#      </li>
#      <li>
#       <a aria-label="button ir a bolsamania youtube" href="https://www.youtube.com/user/bolsamaniaTV" rel="noopener" role="button" target="_blank">
#        <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <title>
#          Ir a Bolsamania TV
#         </title>
#         <path d="M21.593,7.203c-0.23-0.858-0.905-1.535-1.762-1.766C18.265,5.007,12,5,12,5S5.736,4.993,4.169,5.404	c-0.84,0.229-1.534,0.921-1.766,1.778c-0.413,1.566-0.417,4.814-0.417,4.814s-0.004,3.264,0.406,4.814	c0.23,0.857,0.905,1.534,1.763,1.765c1.582,0.43,7.83,0.437,7.83,0.437s6.265,0.007,7.831-0.403c0.856-0.23,1.534-0.906,1.767-1.763	C21.997,15.281,22,12.034,22,12.034S22.02,8.769,21.593,7.203z M9.996,15.005l0.005-6l5.207,3.005L9.996,15.005z">
#         </path>
#        </svg>
#       </a>
#      </li>
#     </ul>
#     <div class="hamburger hamburger--elastic is-active" v-on:click="showHideMenus('bolsamania')">
#      <div class="hamburger-box">
#       <div class="hamburger-inner">
#       </div>
#      </div>
#     </div>
#     <a aria-label="modal buscar" class="btn btn-header visible-xs search-btn" data-params='{"modal":true}' data-target="#headerModal" data-toggle="modal" data-uri="/busqueda.html" href="#" role="button" v-on:click="loadModal">
#      <i class="icon">
#       <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#        <title>
#         Buscar
#        </title>
#        <path d="M10,18c1.846,0,3.543-0.635,4.897-1.688l4.396,4.396l1.414-1.414l-4.396-4.396C17.365,13.543,18,11.846,18,10 c0-4.411-3.589-8-8-8s-8,3.589-8,8S5.589,18,10,18z M10,4c3.309,0,6,2.691,6,6s-2.691,6-6,6s-6-2.691-6-6S6.691,4,10,4z">
#        </path>
#       </svg>
#      </i>
#      <span>
#       Buscar
#      </span>
#     </a>
#     <template v-if="menus.show">
#      <div class="clearfix ads-parent">
#       <div class="banner">
#        <div class="publicidad">
#         Publicidad
#        </div>
#        <ins v-ads-display-async="" vtx-conf='{"reservePosition":"menu","bannedSizes":["300x600"],"onDemand":true,"refreshable":false,"label":"enmenu","disableArf":true}' vtx-position="mpu">
#        </ins>
#       </div>
#      </div>
#     </template>
#     <ul>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html" v-on:click="toggleSubMenu">
#        Cotizaciones
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#          Portada De Cotizaciones
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html">
#          Índices
#         </a>
#        </li>
#        <li class="adirecto">
#         <a href="https://www.bolsamania.com/indice/IBEX-35">
#          Ibex 35
#         </a>
#        </li>
#        <li class="adirecto">
#         <a href="https://www.bolsamania.com/mercado/MERCADO-CONTINUO">
#          Mercado Continuo
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/divisa">
#          Divisas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/materias-primas.html">
#          Materias Primas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/criptodivisas/index.html">
#          Criptodivisas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/derivados-warrants.html">
#          Warrants
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/renta-fija.html">
#          Renta Fija
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/etfs.html">
#          ETF
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/prima-riesgo/">
#          Prima De Riesgo
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/tiempo-real.html">
#          Tiempo Real
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/favoritos">
#          Favoritos
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/mi-cartera" v-on:click="toggleSubMenu">
#        Mi Cartera
#        <sup style="color:#000;font-size: 0.7em;">
#         Nuevo
#        </sup>
#       </a>
#      </li>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/ultimas/index.html" v-on:click="toggleSubMenu">
#        Noticias
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/ultimas/index.html">
#          Últimas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/pulsos/index.html">
#          Pulsos
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/mercados/index.html">
#          Mercados
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/noticias/ultima-hora">
#          Última Hora
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/empresas/index.html">
#          Empresas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/economia/index.html">
#          Economía
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/finanzas-personales/index.html">
#          Finanzas Personales
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/declaracion-impuestos-renta/">
#          Impuestos Y Fiscalidad
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/politica/index.html">
#          Política
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/internacional/index.html">
#          Internacional
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/tecnologia/index.html">
#          Tecnología
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/deportes/index.html">
#          Deportes
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/promocionado/ultimas">
#          Promocionadas
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/analisis-de-bolsa.html" v-on:click="toggleSubMenu">
#        Análisis
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/analisis-de-bolsa.html">
#          Portada De Análisis
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/analisis-tecnico/index.html">
#          Análisis Técnico
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/analisis-fundamental/index.html">
#          Análisis Fundamental
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/expertos/index.html">
#          Expertos
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/analisis-de-bolsa/ratingsEspana.html">
#          Cambios De Recomendación
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/analistas.html">
#          Analistas
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/fundsnews" v-on:click="toggleSubMenu">
#        Fundsnews
#       </a>
#      </li>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/finanzas-personales/index.html" v-on:click="toggleSubMenu">
#        F. Personales
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/finanzas-personales/index.html">
#          Portada
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/declaracion-impuestos-renta/">
#          Impuestos Y Fiscalidad
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/entidades-de-credito.html">
#          Oficinas Bancarias
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/buscartrabajo">
#          Buscar Trabajo
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/mejorescreditos">
#          Mejores Créditos
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/mejoresprestamos">
#          Mejores Préstamos
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/herramientas-de-bolsa.html" v-on:click="toggleSubMenu">
#        Herramientas
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/herramientas-de-bolsa.html">
#          Portada De Herramientas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/trader_watch.html">
#          Trader Watch
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/formacion-de-bolsa.html">
#          Formación De Bolsa
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/fiscalidad.html">
#          Fiscalidad
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/cartera">
#          Cartera
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/favoritos">
#          Favoritos
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/agenda" v-on:click="toggleSubMenu">
#        Agenda
#       </a>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/tv.html" v-on:click="toggleSubMenu">
#        TV
#       </a>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/trader_watch.html" v-on:click="toggleSubMenu">
#        Trader Watch
#       </a>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/tiempo-real.html" v-on:click="toggleSubMenu">
#        Tiempo Real
#       </a>
#      </li>
#     </ul>
#    </nav>
#    <div class="modal fade" id="headerModal" no-reload="" ref="vueModalHeader" role="dialog">
#    </div>
#    <div class="container max-width-md">
#     <nav class="breadcrumb" ref="breadcrumb">
#      <ol itemscope="" itemtype="https://schema.org/BreadcrumbList">
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/" itemprop="item">
#         <span itemprop="name">
#          Portada
#         </span>
#        </a>
#        <meta content="1" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html" itemprop="item" v-expand-breadcrumb="629">
#         <span it="3" itemprop="name">
#          Cotizaciones
#         </span>
#        </a>
#        <meta content="2" itemprop="position"/>
#        <span class="down" ref="drop" v-expand-breadcrumb="629">
#        </span>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html" itemprop="item" v-expand-breadcrumb="3">
#         <span it="17" itemprop="name">
#          Índices
#         </span>
#        </a>
#        <meta content="3" itemprop="position"/>
#        <span class="down" ref="drop" v-expand-breadcrumb="3">
#        </span>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/indice/IBEX-35" itemprop="item" v-expand-breadcrumb="17">
#         <span it="77" itemprop="name">
#          España
#         </span>
#        </a>
#        <meta content="4" itemprop="position"/>
#        <span class="down" ref="drop" v-expand-breadcrumb="17">
#        </span>
#       </li>
#       <li class="active" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/indice/IBEX-35" itemprop="item" v-expand-breadcrumb="77">
#         <span it="88" itemprop="name">
#          Ibex 35
#         </span>
#        </a>
#        <meta content="5" itemprop="position"/>
#        <span class="down" ref="drop" v-expand-breadcrumb="77">
#        </span>
#       </li>
#      </ol>
#     </nav>
#     <div class="breadcrumb-child">
#      <div class="hide" id="bread-child-629">
#       <ul>
#        <li class="active" it="3">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#          Cotizaciones
#         </a>
#        </li>
#        <li it="4">
#         <a class="" href="https://www.bolsamania.com/ultimas/index.html">
#          Noticias
#         </a>
#        </li>
#        <li it="5">
#         <a class="" href="https://www.bolsamania.com/analisis-de-bolsa.html">
#          Análisis
#         </a>
#        </li>
#        <li it="665">
#         <a class="" href="https://www.bolsamania.com/criptodivisas/index.html">
#          Criptodivisas
#         </a>
#        </li>
#        <li it="541">
#         <a class="" href="https://www.bolsamania.com/fundsnews">
#          Fundsnews
#         </a>
#        </li>
#        <li it="666">
#         <a class="" href="https://www.bolsamania.com/tiempo-real.html">
#          Tiempo Real
#         </a>
#        </li>
#        <li it="47">
#         <a class="" href="https://www.bolsamania.com/trader_watch.html">
#          Trader Watch
#         </a>
#        </li>
#        <li it="793">
#         <a class="" href="https://www.bolsamania.com/mi-cartera">
#          Mi cartera
#          <sup style="color:#000;font-size: 0.7em;">
#           nuevo
#          </sup>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="hide" id="bread-child-3">
#       <ul>
#        <li it="15">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#          Portada de Cotizaciones
#         </a>
#        </li>
#        <li class="active" it="17">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html">
#          Índices
#         </a>
#        </li>
#        <li it="684">
#         <a class="adirecto" href="https://www.bolsamania.com/indice/IBEX-35">
#          Ibex 35
#         </a>
#        </li>
#        <li it="685">
#         <a class="adirecto" href="https://www.bolsamania.com/mercado/MERCADO-CONTINUO">
#          Mercado Continuo
#         </a>
#        </li>
#        <li it="18">
#         <a class="" href="https://www.bolsamania.com/divisa">
#          Divisas
#         </a>
#        </li>
#        <li it="21">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/materias-primas.html">
#          Materias Primas
#         </a>
#        </li>
#        <li it="523">
#         <a class="" href="https://www.bolsamania.com/criptodivisas/index.html">
#          Criptodivisas
#         </a>
#        </li>
#        <li it="8">
#         <a class="" href="https://www.bolsamania.com/derivados-warrants.html">
#          Warrants
#         </a>
#        </li>
#        <li it="19">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/renta-fija.html">
#          Renta Fija
#         </a>
#        </li>
#        <li it="20">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/etfs.html">
#          ETF
#         </a>
#        </li>
#        <li it="22">
#         <a class="" href="https://www.bolsamania.com/prima-riesgo/">
#          Prima de Riesgo
#         </a>
#        </li>
#        <li it="13">
#         <a class="" href="https://www.bolsamania.com/tiempo-real.html">
#          Tiempo Real
#         </a>
#        </li>
#        <li it="535">
#         <a class="" href="https://www.bolsamania.com/favoritos">
#          Favoritos
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="hide" id="bread-child-17">
#       <ul>
#        <li it="638">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html">
#          Portada Índices
#         </a>
#        </li>
#        <li class="active" it="77">
#         <a class="" href="https://www.bolsamania.com/indice/IBEX-35">
#          España
#         </a>
#        </li>
#        <li it="78">
#         <a class="" href="https://www.bolsamania.com/indice/DOW-JONES">
#          EEUU
#         </a>
#        </li>
#        <li it="79">
#         <a class="" href="https://www.bolsamania.com/indice/DAX">
#          Alemania
#         </a>
#        </li>
#        <li it="81">
#         <a class="" href="https://www.bolsamania.com/indice/CAC-40">
#          Francia
#         </a>
#        </li>
#        <li it="82">
#         <a class="" href="https://www.bolsamania.com/indice/PSI-20">
#          Portugal
#         </a>
#        </li>
#        <li it="83">
#         <a class="" href="https://www.bolsamania.com/indice/EURONEXT-BEL-20">
#          Bélgica
#         </a>
#        </li>
#        <li it="84">
#         <a class="" href="https://www.bolsamania.com/indice/AEX">
#          Holanda
#         </a>
#        </li>
#        <li it="85">
#         <a class="" href="https://www.bolsamania.com/indice/SMI">
#          Suiza
#         </a>
#        </li>
#        <li it="86">
#         <a class="" href="https://www.bolsamania.com/indice/HANG-SENG">
#          Asia
#         </a>
#        </li>
#        <li it="87">
#         <a class="" href="https://www.bolsamania.com/indice/STOXX600">
#          Índices Globales
#         </a>
#        </li>
#        <li it="124">
#         <a class="" href="https://www.bolsamania.com/indice/IPC">
#          Latam
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="show" id="bread-child-77">
#       <ul>
#        <li class="active" it="88">
#         <a class="" href="https://www.bolsamania.com/indice/IBEX-35">
#          Ibex 35
#         </a>
#        </li>
#        <li it="89">
#         <a class="" href="https://www.bolsamania.com/mercado/MERCADO-CONTINUO">
#          MERCADO CONTINUO
#         </a>
#        </li>
#        <li it="90">
#         <a class="" href="https://www.bolsamania.com/indice/LATIBEX">
#          Latibex All
#         </a>
#        </li>
#        <li it="91">
#         <a class="" href="https://www.bolsamania.com/indice/LATIBEX-BRASIL">
#          Latibex Brasil
#         </a>
#        </li>
#        <li it="92">
#         <a class="" href="https://www.bolsamania.com/mercado/MERCADO-ALTERNATIVO-BURSATIL">
#          BME Growth - MAB
#         </a>
#        </li>
#        <li it="141">
#         <a class="" href="https://www.bolsamania.com/mercado/MAB-SICAVS">
#          MAB SICAVS
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="ficha-headline-box">
#      <h1>
#       Cotización IBEX 35
#      </h1>
#      <div class="headline-details-module">
#       <div class="headline-details">
#        <div class="headline-details-primary">
#         <div class="headline-box">
#          <div class="box">
#           <time>
#            <span>
#             <span class="ls" data-field="fecha_hora_cotizacion" data-grid="ls_grid" data-item="item_50107012_55_df" data-source="lightstreamer">
#              11:45 24/06/24
#             </span>
#            </span>
#           </time>
#           <h3>
#            <span class="ls" data-field="precio_ultima_cotizacion" data-grid="ls_grid" data-item="item_50107012_55_df" data-source="lightstreamer">
#             11.095,600
#            </span>
#           </h3>
#          </div>
#          <div class="box-column">
#           <div class="status-arrows">
#            <span>
#             <span class="ls" data-field="variacion_puntos" data-grid="ls_grid" data-item="item_50107012_55_df" data-source="lightstreamer">
#              <span class="cgreen">
#               63,300
#              </span>
#             </span>
#            </span>
#            <span>
#             <span class="ls" data-field="variacion_porcentual" data-grid="ls_grid" data-item="item_50107012_55_df" data-source="lightstreamer">
#              <span class="greenarrowleft">
#               0,57%
#              </span>
#             </span>
#            </span>
#           </div>
#          </div>
#         </div>
#         <!-- Grafico rangos -->
#         <div class="chart-range-container">
#          <div class="chart-range-box margin_left">
#           <div class="chart-range-title">
#            <span class="text_title">
#             RANGO DIARIO
#            </span>
#            <span class="text_low">
#             11.040,100
#            </span>
#            <span class="text_high">
#             11.118,300
#            </span>
#           </div>
#           <div class="chart-range-bar">
#            <span class="close_value l-0">
#             <i class="right" title="CIERRE:11.032,300">
#              CIERRE:11.032,300
#             </i>
#            </span>
#            <div class="chart-range-session green l-15 w-56">
#             <span class="last_value r-0">
#              11.095,600
#             </span>
#             <span class="open_value l-0">
#              <i class="right" title="APERTURA:11.051,500">
#               APERTURA:11.051,500
#              </i>
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="chart-range-box anual">
#           <div class="chart-range-title">
#            <span class="text_title">
#             Rango Anual
#            </span>
#            <span class="text_low">
#             8.879,300
#            </span>
#            <span class="text_high">
#             11.469,900
#            </span>
#           </div>
#           <div class="chart-range-bar">
#            <div class="chart-range-session green l-83 w-3">
#             <span class="text_value left" title="Última Sesión:11.032,300">
#              Última Sesión
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="banner-box">
#         <figure class="fixed-height-image">
#          <img class="lazy" src="//rsrc.s3wfg.com/web/img/headers_bm/indice.jpg"/>
#         </figure>
#        </div>
#       </div>
#      </div>
#      <div v-ls-conf='{"type":"equal","table":"ls_grid","data":{"precio_ultima_cotizacion":{"dec":3},"variacion_puntos":{"fxSet":"color","cssSet":"color","dec":3}}}'>
#      </div>
#      <div class="is-hidden" v-set-factsheet-last-visited-info='{"ins":"262980*IBEX 35*https:\/\/www.bolsamania.com\/indice\/IBEX-35*item_50107012_55_df**11095.6000*0.57377*2024-06-24 11:45:04","site_folder_securities":""}'>
#      </div>
#      <div id="header-factsheet-social-buttons" v-factsheet-social-buttons='{"site_id":"2","twitter_account":"Bolsamania","module":"html\/bms\/v3\/socialButtons","link":"https:\/\/www.bolsamania.com\/indice\/IBEX-35","csi":"262980","type":"indice","name":"IBEX 35","ticker":"","price":"11.095%2C60","title":"Precios hist\u00f3ricos de IBEX 35","img":"https:\/\/www.bolsamania.com\/motorGraficas\/grafica.php?idCliente=bolsamania&amp;idProyecto=cotizaciones&amp;idOrden=10&amp;key=2b08dc2f95028a03e9da21780019809d&amp;numDat=1&amp;dato1=ES0SI0000005%3AIBEX-35%3AI%3A55%3A50107012&amp;periodo=0&amp;stream=1&amp;idGrafica=LIN_001","createSocialMetas":1}'>
#      </div>
#     </div>
#     <div id="lastVisitedCookie" v-factsheet-last-visited-cookie="">
#     </div>
#     <krux-component data="..." id="4474">
#     </krux-component>
#     <div class="bloque container-vertical-navbar menu-scroll-limit">
#      <div class="section75">
#       <aside class="market--first--navegation stickyElement" id="summary" ref="scrollmeContainer" v-infinite-scroll="" v-set-infinite-scroll-items='{"items":{"":{"id":"","headline":"Listado de acciones","launchPageViewEvent":false,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35","urlScroll":"https:\/\/www.bolsamania.com\/scroll_0\/indice\/IBEX-35","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_0\/indice\/IBEX-35","children":{"items":{"":{"id":"","headline":"Vista Normal","launchPageViewEvent":false,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35","urlScroll":"https:\/\/www.bolsamania.com\/scroll_0\/indice\/IBEX-35","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_0\/indice\/IBEX-35","children":null,"title":"Bolsamania \u00b7 Ficha de Instrumento - Bolsamania.com"},"vista-estadistica":{"id":"vista-estadistica","headline":"Vista Estad\u00edstica","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/vista-estadistica","urlScroll":"https:\/\/www.bolsamania.com\/scroll_2\/indice\/IBEX-35\/vista-estadistica","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_2\/indice\/IBEX-35\/vista-estadistica","children":null}}},"title":"Cotizaci\u00f3n de IBEX 35: Acciones e informaci\u00f3n - Bolsamania.com","remove":true},"historico-precios":{"id":"historico-precios","headline":"Hist\u00f3rico","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/historico-precios","urlScroll":"https:\/\/www.bolsamania.com\/scroll_2\/indice\/IBEX-35\/historico-precios","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_2\/indice\/IBEX-35\/historico-precios","children":null,"title":"Precios hist\u00f3ricos de IBEX 35 - Bolsamania.com"},"warrants":{"id":"warrants","headline":"Warrants","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/warrants","urlScroll":"https:\/\/www.bolsamania.com\/scroll_3\/indice\/IBEX-35\/warrants","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_3\/indice\/IBEX-35\/warrants","children":{"items":{"":{"id":"","headline":"Buscador","launchPageViewEvent":false,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/warrants","urlScroll":"https:\/\/www.bolsamania.com\/scroll_0\/indice\/IBEX-35\/warrants","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_0\/indice\/IBEX-35\/warrants","children":null,"title":"Bolsamania \u00b7 Ficha de Instrumento - Bolsamania.com"},"simulador-cobertura":{"id":"simulador-cobertura","headline":"Simulador de cobertura","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/warrants\/simulador-cobertura","urlScroll":"https:\/\/www.bolsamania.com\/scroll_2\/indice\/IBEX-35\/warrants\/simulador-cobertura","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_2\/indice\/IBEX-35\/warrants\/simulador-cobertura","children":null}}},"title":"Warrants del subyacente de IBEX 35 - Bolsamania.com"},"ficha":{"id":"ficha","headline":"Ficha","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/ficha","urlScroll":"https:\/\/www.bolsamania.com\/scroll_4\/indice\/IBEX-35\/ficha","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_4\/indice\/IBEX-35\/ficha","children":null,"title":"Datos de IBEX 35 - Bolsamania.com"},"noticias":{"id":"noticias","headline":"Noticias","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/noticias","urlScroll":"https:\/\/www.bolsamania.com\/scroll_5\/indice\/IBEX-35\/noticias","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_5\/indice\/IBEX-35\/noticias","children":{"items":{"":{"id":"","headline":"\u00daltimas","launchPageViewEvent":false,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/noticias","urlScroll":"https:\/\/www.bolsamania.com\/scroll_0\/indice\/IBEX-35\/noticias","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_0\/indice\/IBEX-35\/noticias","children":null,"title":"Bolsamania \u00b7 Ficha de Instrumento - Bolsamania.com"},"analisis-tecnico":{"id":"analisis-tecnico","headline":"A. T\u00e9cnico","launchPageViewEvent":true,"url":"http ...
#        <div class="sections_container text-uppercase">
#         <ul>
#          <li class="button_sections" id="item-scroll-" ref="item-scroll-">
#           <a href="https://www.bolsamania.com/indice/IBEX-35">
#            <i class="mdi icon icon-list">
#            </i>
#            <span>
#             Listado de acciones
#            </span>
#           </a>
#          </li>
#          <li class="button_sections active" id="item-scroll-historico-precios" ref="item-scroll-historico-precios">
#           <a href="https://www.bolsamania.com/indice/IBEX-35/historico-precios">
#            <i class="mdi icon icon-historic-price">
#            </i>
#            <span>
#             Histórico
#            </span>
#           </a>
#          </li>
#          <li class="button_sections" id="item-scroll-warrants" ref="item-scroll-warrants">
#           <a href="https://www.bolsamania.com/indice/IBEX-35/warrants">
#            <i class="mdi icon icon-warrants">
#            </i>
#            <span>
#             Warrants
#            </span>
#           </a>
#          </li>
#          <li class="button_sections" id="item-scroll-ficha" ref="item-scroll-ficha">
#           <a href="https://www.bolsamania.com/indice/IBEX-35/ficha">
#            <i class="mdi icon icon-file">
#            </i>
#            <span>
#             Ficha
#            </span>
#           </a>
#          </li>
#          <li class="button_sections" id="item-scroll-noticias" ref="item-scroll-noticias">
#           <a href="https://www.bolsamania.com/indice/IBEX-35/noticias">
#            <i class="mdi icon icon-news">
#            </i>
#            <span>
#             Noticias
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a aria-label="button scroll down" class="scrollme" href="javascript:void(0)" ref="scrollme" role="button" v-if="menus.menusEquities &gt; 6" v-more-tabs="">
#         <span class="mdi mdi-chevron-down">
#         </span>
#        </a>
#       </aside>
#       <div class="container-carusel">
#        <div class="height100 d-flex header-carusel">
#         <div class="wrap border-right" ref="scrollCarousel">
#          <ul class="news-guidline-header carousel is-set">
#           <li class="news-guidline-header-story flex items-center carousel-seat" ref="nav-item-scroll-">
#            <span>
#             <div v-bind:style="{width: storiesRelated.scrollNewsPercent + '%'}">
#             </div>
#             <a href="https://www.bolsamania.com/indice/IBEX-35">
#              Listado de acciones
#             </a>
#            </span>
#           </li>
# ...
#         Así es el plan de Trump para fulminar a Powell en la Fed si gana las elecciones
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/empresas/cinco-gangas-wall-street-ideales-inversores-largo-plazo--16966314.html">
#         Cinco "gangas" en Wall Street, ideales para inversores a largo plazo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/mercados/tres-tendencias-seguir-verano-marcaran-2024-mercado--16959521.html">
#         Tres tendencias que seguir en verano y que marcarán el resto de 2024 en el mercado
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/economia/bank-america-oportunidades-chocolate--16946680.html">
#         El cacao está de moda: Bank of America y las "oportunidades para invertir en chocolate"
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/mercados/debemos-esperar-mas-caidas-tecnologicas-ia-hemos-visto-peor--16975810.html">
#         ¿Debemos esperar más caídas en las tecnológicas y en la IA o hemos visto lo peor?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/criptodivisas/mal-comienzo-semana-puede-bitcoin-caer-minimos-2024--16980543.html">
#         Mal comienzo de semana para las criptos: ¿puede el bitcoin caer a mínimos de 2024?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/mercados/le-pen-sigue-liderando-encuestas-francia-danske-bank-preve-parlamento-colgado--16980246.html">
#         Le Pen sigue liderando las encuestas en Francia: Danske Bank prevé un 'Parlamento colgado'
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/empresas/acs-mejora-jefferies---16980466.html">
#         ACS celebra en bolsa la mejora de valoración de Jefferies tras elevar estimaciones
#        </a>
#       </li>
#      </ol>
#     </section>
#     <section class="card most-read most-read--alt most-read--blue col-3@md col-12@xs">
#      <h2 class="module-headline">
#       Lo más leído
#       <span class="text-bold">
#        - Análisis
#       </span>
#      </h2>
#      <ol>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/hasta-donde-podria-caer-el-banco-santander--16974163.html">
#         ¿Hasta dónde podría caer el Banco Santander?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/cinco-valores-que-se-deben-tener-muy-en-cuenta-por-tecnico-este-lunes--16976046.html">
#         Cinco valores que se deben tener muy en cuenta por técnico este lunes
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/las-electricas-del-ibex-entran-a-escena--16974100.html">
#         Las eléctricas del Ibex entran a escena
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/muy-atentos-a-una-figura-de-continuacion-alcista-en-este-valor-del-continuo--16974279.html">
#         Muy atentos a una figura de continuación alcista en este valor del Continuo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/es-importante-que-este-banco-no-pierda-los-120-euros--16974227.html">
#         Es importante que este banco no pierda los 1,20 euros
#        </a>
#       </li>
#      </ol>
#     </section>
#     <section class="card most-read most-read--alt most-read--green col-3@md col-12@xs">
#      <h2 class="module-headline">
#       Lo más leído
#       <span class="text-bold">
#        - Cripto
#       </span>
#      </h2>
#      <ol>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/criptodivisas/mal-comienzo-semana-puede-bitcoin-caer-minimos-2024--16980543.html">
#         Mal comienzo de semana para las criptos: ¿puede el bitcoin caer a mínimos de 2024?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/promocionado/criptodivisas/estas-3-altcoins-estan-al-borde-de-una-brutal-subida-de-precios.html">
#         Estas 3 altcoins están al borde de una brutal subida de precios
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/promocionado/criptodivisas/la-nueva-moneda-meme-ico-recq-llega-a-la-etapa-3-de-preventa-la-mejor-criptomoneda-para-comprar-ahora.html">
#         La nueva moneda meme ICO 'RECQ' llega a la etapa 3 de preventa: ¿la mejor criptomoneda para comprar ahora?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/criptodivisas/caidas-falta-catalizadores-fuerza-wall-street--16973928.html">
#         Las criptos siguen cayendo ante la falta de catalizadores y la fuerza de Wall Street
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/criptodivisas/bitcoin-no-reacciona-alicaido-peligro-6000-dolares--16967183.html">
#         El bitcoin no reacciona y sigue alicaído: ¿están en peligro los 60.000 dólares?
#        </a>
#       </li>
#      </ol>
#     </section>
#    </div>
#    <div class="bk-white margin-top-md">
#     <div class="container max-width-md">
#      <footer>
#       <div class="footer-header flex flex-column flex-row@md items-center justify-between">
#        <div class="center-box">
#         <a class="main-logo" href="/">
#          <strong class="is-hidden">
#           Bolsamania
#          </strong>
#          <span class="logoBM">
#           <img alt="bolsamania" class="lazy logo" data-original="//rsrc.s3wfg.com/web/img/logos/svg/bolsamania-brand.svg" data-src="//rsrc.s3wfg.com/web/img/logos/svg/bolsamania-brand.svg"/>
#          </span>
#         </a>
#         <ul>
#          <li>
#           <a href="/catalunya">
#            CAT
#           </a>
#          </li>
#          <li>
#           <a href="/mexico">
#            MEX
#           </a>
#          </li>
#          <li>
#           <a href="/argentina">
#            AR
#           </a>
#          </li>
#          <li>
#           <a href="/peru">
#            PER
#           </a>
#          </li>
#          <li>
#           <a href="/colombia">
#            COL
#           </a>
#          </li>
#          <li>
#           <a href="/chile">
#            CHL
#           </a>
#          </li>
#         </ul>
#        </div>
#        <ul class="products-list">
#         <li>
#         </li>
#         <li>
#          <a href="https://www.sharecast.com" rel="nofollow">
#           <img alt="sharecast" class="lazy" data-original="//rsrc.s3wfg.com/web/img/logos/sharecast.png" data-src="//rsrc.s3wfg.com/web/img/logos/sharecast.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="/fundsnews" rel="nofollow">
#           <img alt="fundsnews" class="lazy" data-original="//rsrc.s3wfg.com/web/img/logos/logoFund.svg" data-src="//rsrc.s3wfg.com/web/img/logos/logoFund.svg"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.financialred.com" rel="nofollow">
#           <img alt="financialred" class="lazy" data-original="//rsrc.s3wfg.com/web/img/logos/logofinancialred.jpg" data-src="//rsrc.s3wfg.com/web/img/logos/logofinancialred.jpg"/>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="map-list">
#        <ul>
#         <span>
#          <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#           Cotizaciones
#          </a>
#         </span>
#         <li>
#          <a href="https://www.bolsamania.com/indice/IBEX-35">
#           Ibex 35
#          </a>
#         </li>
#         <li>
#          <a href="https://www.bolsamania.com/indice/ibex-35">
#           Acciones
#          </a>
#         </li>
#         <li>
#          <a href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html">
#           Índices
#          </a>
#         </li>
#         <li>
#          <a href="https://www.bolsamania.com/criptodivisas/index.html">
#           Criptodivisas
#          </a>
#         </li>
#         <span>
#          <a href="https://www.bolsamania.com
">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a aria-label="button ir a bolsamania flipboard" href="https://flipboard.com/@Bolsamania?utm_campaign=tools&amp;utm_medium=follow&amp;action=follow&amp;utm_source=www.bolsamania.com" rel="nofollow" role="button" target="_blank">
#           <svg aria-hidden="true" height="24" viewbox="0 0 448 512" width="24">
#            <title>
#             Ir a Flipboard de Bolsamania
#            </title>
#            <path d="M0 32v448h448V32H0zm358.4 179.2h-89.6v89.6h-89.6v89.6H89.6V121.6h268.8v89.6z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a aria-label="button ir a bolsamania youtube" href="https://www.youtube.com/user/bolsamaniaTV" rel="nofollow" role="button" target="_blank">
#           <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             Ir a Bolsamania TV
#            </title>
#            <path d="M21.593,7.203c-0.23-0.858-0.905-1.535-1.762-1.766C18.265,5.007,12,5,12,5S5.736,4.993,4.169,5.404	c-0.84,0.229-1.534,0.921-1.766,1.778c-0.413,1.566-0.417,4.814-0.417,4.814s-0.004,3.264,0.406,4.814	c0.23,0.857,0.905,1.534,1.763,1.765c1.582,0.43,7.83,0.437,7.83,0.437s6.265,0.007,7.831-0.403c0.856-0.23,1.534-0.906,1.767-1.763	C21.997,15.281,22,12.034,22,12.034S22.02,8.769,21.593,7.203z M9.996,15.005l0.005-6l5.207,3.005L9.996,15.005z">
#            </path>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script>
#    var exdate = new Date();
# 	var extime = 300;
# 	exdate.setSeconds(exdate.getSeconds() + extime);
# 	document.cookie = "html5PopupBMS=1; expires=" + exdate.toUTCString() + "; path=/; SameSite=strict";
#   </script>
#   <script>
#    // Vue
# 	                window.vueConf = {
# 	                    id: '#bmsapp',
# 	                    devMode: false,
# 	                    loginCookieName: 'us_media_users_bolsamania_cn_uid',
# 	                    loginEnabled: true,
# 	                    enableInfiniteScroll: false,
# 	                    swipeNavigationEnabled: 1,
# 	                    locale: 'es',
# 	                    manage: false
# 	                }
#   </script>
#   <script defer="" src="https://rsrc.s3wfg.com/web/webpack/build/js/bolsamania.bundle.js?v=0b2e2a85d530d918b97e8bca76ba51bd_20240624" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.ls_dec_sep = ',';
# 		        window.ls_ths_sep = '.';
# 		        window.ls_dec = 2;
# 		        window.ls_symbol_side = 'R';
# 				window.ls_timezone = 'Europe/Madrid';
# 		        window.ls_time_diff = 0;
# 		        window.ls_locale = 'es-ES';
# 		        window.ls_extra_config = {"light":{"up":"#43a047","down":"#c80027","equal":"#000","alert":"#C4E3F3"},"color":{"up":"ls cgreen","down":"ls dred","equal":"ls darkgrey"},"arrow":{"up":"ls greenarrowleft","down":"ls redarrowleft","equal":"ls blackarrowleft"},"image":{"up":"https:\/\/rsrc.s3wfg.com\/web\/img\/whitearrowup.svg","down":"https:\/\/rsrc.s3wfg.com\/web\/img\/whitearrowdown.svg"}};
#   </script>
#   <script data-cfasync="false" src="//rsrc.s3wfg.com/web/js_comun/lightstreamer/ls/lightstreamer-7.0.3.js" type="text/javascript">
#   </script>
#   <script data-cfasync="false" src="//rsrc.s3wfg.com/web/js_comun/lightstreamer/wfgLightstreamer-Media.js" type="text/javascript">
#   </script>
#   <script data-cfasync="false" src="//rsrc.s3wfg.com/web/js_comun/lightstreamer/wfgLightstreamerMediaFunctions-v2.js" type="text/javascript">
#   </script>
#   <script data-cfasync="false" src="//rsrc.s3wfg.com/web/js_comun/lightstreamer/config/bolsamania/ls_bolsamania2020.js" type="text/javascript">
#   </script>
#   <script title="lightstreamer" type="text/javascript">
#    //<![CDATA[
# 					var ls_config = {
# 					    engine: 'bolsamania.com',
# 					    serverlist: ['push.bolsamania.com','push2.bolsamania.com'],
# 					    tables: '\'ls_grid\', \'ls_listado_indices_six\', \'ls_cotation\', \'ls_listado_constituyentes\', \'data_price_fact_sheet_header\''
# 					};
# 					addEvent(window, 'load', addDynamicTables);
# 					addEvent(window, 'load', loadBolsamaniaLS);
#
# 					//]]>
#   </script>
#  </body>
# </html>

# %%
# vamos a seguir usando el metodo ".find_all()", pero en este caso lo que buscaremos son todas las tablas que tenemos en la página web.
tablas = sopa_bolsa.find_all("table")

print("El número de tablas que tenemos en la página web es:", len(tablas))
# Out:
# El número de tablas que tenemos en la página web es: 3

# %%
# veamos que tenemos en cada una de las tablas que hemos extraído de la página web. 
print("En la tabla 1 tenemos: \n ", tablas[0])
print("\n---------------------\n")

print("En la tabla 2 tenemos: \n", tablas[1])
print("\n---------------------\n")

print("En la tabla 3 tenemos: \n", tablas[2])
# Out:
# En la tabla 1 tenemos:
#   <table class="stripped xs-grid-table">
# <tbody>
# <tr>
# <td>Periodo</td>
# <td class="text-right">
#                                     25 may - 24 jun                                </td>
# </tr>
# <tr>
# <td>Máximo</td>
# <td class="text-right">
#                                     11.469,9000  (07-jun-24)                                </td>
# </tr>
# <tr>
# <td>Mínimo</td>
# <td class="text-right">
#                                     10.874,1000  (14-jun-24)                                </td>
# </tr>
# </tbody>
# </table>
#
# ---------------------
#
# En la tabla 2 tenemos:
#  <table class="stripped xs-grid-table">
# <tbody>
# <tr>
# <td>Diferencia</td>
# <td class="text-right">595,8000</td>
# </tr>
# <tr>
# <td>Promedio</td>
# <td class="text-right">11.220,2650</td>
# </tr>
# <tr>
# <td>Variación %</td>
# <td class="text-right"><span class="dred">-1,83%</span></td>
# </tr>
# </tbody>
# </table>
#
# ---------------------
#
# En la tabla 3 tenemos:
#  <table class="table table-hover cator sortable table-bm xs-grid-table stripped" v-table-sorter="{
#                 'orderBy': 'date',
#                 'orderType': 'asc',
#                 'baseUrl': 'https://www.bolsamania.com/indice/IBEX-35/historico-precios',
#                 'queryString': '?startDate=25-05-2024&amp;endDate=24-06-2024',
#                 'defaultBy': 'date',
#                 'reverse': true
#                 }">
# <thead v-if="tableSorter">
# <tr>
# <th class="text-left" v-table-sorter-by="'date'">Fecha<span></span></th>
# <th class="text-right" v-table-sorter-by="'price'">Precio<span></span></th>
# <th class="text-right" v-table-sorter-by="'fallers'">Variación %<span></span></th>
# <th class="text-right" v-table-sorter-by="'high'">Máximo<span></span></th>
# <th class="text-right" v-table-sorter-by="'low'">Mínimo<span></span></th>
# <th class="text-right" v-table-sorter-by="'open'">Apertura<span></span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="text-left">27-may-24</td>
# <td class="text-right">11.325,500</td>
# <td class="text-right"><span class="cgreen">0,71%</span></td>
# <td class="text-right">11.325,500</td>
# <td class="text-right">11.248,900</td>
# <td class="text-right">11.260,100</td>
# </tr>
# <tr>
# <td class="text-left">28-may-24</td>
# <td class="text-right">11.276,000</td>
# <td class="text-right"><span class="dred">-0,44%</span></td>
# <td class="text-right">11.355,100</td>
# <td class="text-right">11.240,000</td>
# <td class="text-right">11.337,600</td>
# </tr>
# <tr>
# <td class="text-left">29-may-24</td>
# <td class="text-right">11.145,100</td>
# <td class="text-right"><span class="dred">-1,16%</span></td>
# <td class="text-right">11.260,900</td>
# <td class="text-right">11.135,000</td>
# <td class="text-right">11.241,000</td>
# </tr>
# <tr>
# <td class="text-left">30-may-24</td>
# <td class="text-right">11.338,200</td>
# <td class="text-right"><span class="cgreen">1,73%</span></td>
# <td class="text-right">11.350,900</td>
# <td class="text-right">11.125,300</td>
# <td class="text-right">11.125,300</td>
# </tr>
# <tr>
# <td class="text-left">31-may-24</td>
# <td class="text-right">11.322,000</td>
# <td class="text-right"><span class="dred">-0,14%</span></td>
# <td class="text-right"><span class="cgreen">0,99%</span></td>
# <td class="text-right">11.071,100</td>
# <td class="text-right">10.955,800</td>
# <td class="text-right">11.009,300</td>
# </tr>
# <tr>
# <td class="text-left">19-jun-24</td>
# <td class="text-right">11.056,400</td>
# <td class="text-right"><span class="dred">-0,10%</span></td>
# <td class="text-right">11.095,400</td>
# <td class="text-right">11.033,200</td>
# <td class="text-right">11.074,600</td>
# </tr>
# <tr>
# <td class="text-left">20-jun-24</td>
# <td class="text-right">11.160,500</td>
# <td class="text-right"><span class="cgreen">0,94%</span></td>
# <td class="text-right">11.166,400</td>
# <td class="text-right">11.041,500</td>
# <td class="text-right">11.068,500</td>
# </tr>
# <tr>
# <td class="text-left">21-jun-24</td>
# <td class="text-right">11.032,300</td>
# <td class="text-right"><span class="dred">-1,15%</span></td>
# <td class="text-right">11.161,600</td>
# <td class="text-right">10.969,200</td>
# <td class="text-right">11.161,600</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# **Cuando estamos trabajando con tablas, es importante tener claro cual es la sintaxis de los distintos elementos HTML que componen la tabla, aquí os dejamos un resumen**:
#
# En HTML, los elementos . Aquí hay algunos elementos relacionados con `<tr>` que se utilizan comúnmente:
#
# 1. `<table>`: Este elemento se utiliza para crear una tabla en HTML y envuelve todas las filas y columnas de la tabla.
#
# 2. `<tr>`: Se utilizan para definir filas dentro de una tabla. Estos elementos hacen referencia a las filas de la tabla y deben estar ubicados dentro del elemento `<table>`
#
# 3. `<td>`: Representa una celda de datos en una tabla. Los elementos `<td>` deben estar ubicados dentro de un elemento `<tr>` para crear una celda en una fila.
#
# 4. `<th>`: Representa una celda de encabezado en una tabla. Al igual que `<td>`, los elementos `<th>` también deben estar ubicados dentro de un elemento `<tr>`, pero se utilizan para resaltar los encabezados de columna o fila.

# %%
# La tabla que nos interesa es la última por lo que vamos a crear una nueva variable donde almacenemos los resultados de la tabla que nos interesa
nuestra_tabla = tablas[2]

# lo primero que nos va a interesar es extraer los encabezados de la tabla, teniendo en cuenta las definiciones que hemos visto antes, 
# seleccionaremos la etiqueta "th" usando el método "th"
lista_ecabezados = nuestra_tabla.find_all("th")

print("La lista que nos devuelve el metodo '.find_all()' es:\n", lista_ecabezados)

# como hemos estado haciendo hasta ahora, tendremos que iterar por la lista obtenida en el paso anterior y extraer el texto de cada elemento
encabezados_ibex = [columna.text for columna in lista_ecabezados]

print("\n-------------------------\n")
print("Los encabezados de la tabla son:", encabezados_ibex)
# Out:
# La lista que nos devuelve el metodo '.find_all()' es:
#  [<th class="text-left" v-table-sorter-by="'date'">Fecha<span></span></th>, <th class="text-right" v-table-sorter-by="'price'">Precio<span></span></th>, <th class="text-right" v-table-sorter-by="'fallers'">Variación %<span></span></th>, <th class="text-right" v-table-sorter-by="'high'">Máximo<span></span></th>, <th class="text-right" v-table-sorter-by="'low'">Mínimo<span></span></th>, <th class="text-right" v-table-sorter-by="'open'">Apertura<span></span></th>]
#
# -------------------------
#
# Los encabezados de la tabla son: ['Fecha', 'Precio', 'Variación %', 'Máximo', 'Mínimo', 'Apertura']

# %% [markdown]
# Vale ... hasta ahora hemos conseguido sacar los encabezados, ahora nos toca sacar la información de las filas, que como hemos dicho antes, tendremos que usar la etiqueta `tr`. Pongamonos manos a la obra:

# %%
# sacamos todas las filas de la variable que nos hemos creado previamente (nuestra tabla), usando el método .find_all()
filas_ibex = nuestra_tabla.find_all("tr")

print("La cantidad de filas que hemos extraido de la tabla es:", len(filas_ibex))

print("\n----------------------\n")
print("El contenido que tenemos en la primera fila es:\n", filas_ibex[0] )

print("\n----------------------\n")
print("El contenido que tenemos en la segunda fila es:\n", filas_ibex[1] )
# Out:
# La cantidad de filas que hemos extraido de la tabla es: 21
#
# ----------------------
#
# El contenido que tenemos en la primera fila es:
#  <tr>
# <th class="text-left" v-table-sorter-by="'date'">Fecha<span></span></th>
# <th class="text-right" v-table-sorter-by="'price'">Precio<span></span></th>
# <th class="text-right" v-table-sorter-by="'fallers'">Variación %<span></span></th>
# <th class="text-right" v-table-sorter-by="'high'">Máximo<span></span></th>
# <th class="text-right" v-table-sorter-by="'low'">Mínimo<span></span></th>
# <th class="text-right" v-table-sorter-by="'open'">Apertura<span></span></th>
# </tr>
#
# ----------------------
#
# El contenido que tenemos en la segunda fila es:
#  <tr>
# <td class="text-left">27-may-24</td>
# <td class="text-right">11.325,500</td>
# <td class="text-right"><span class="cgreen">0,71%</span></td>
# <td class="text-right">11.325,500</td>
# <td class="text-right">11.248,900</td>
# <td class="text-right">11.260,100</td>
# </tr>

# %% [markdown]
# Si nos fijamos el primer elemento de la lista de las filas nos esta dando la información de los encabezados, pero a partir del segundo elemento tenemos todos los valores de la tabla que queremos. Como hasta ahora tendremos que iterar por toda la lista y sacar el texto, pero en este caso empezaremos a interar desde el elemento que esté en segunda posición ya que los encabezados los hemos sacado en el paso anterior.

# %%
# Creamos una lista llamada 'resultados_ibex' para almacenar los resultados obtenidos.
resultados_ibex = []

# Iniciamos un bucle 'for' para iterar a través de la lista 'filas_ibex', pero comenzamos desde el segundo elemento de la lista.
for fila in filas_ibex[1:]:
    # Para cada 'fila', extraemos el texto, lo dividimos en una lista usando '\n' como separador y eliminamos el primer y último elemento de la lista.
    fila_texto = fila.text
    elementos_fila = fila_texto.split("\n")[1:-1]

    # Añadimos la lista de elementos a la lista 'resultados_ibex'.
    resultados_ibex.append(elementos_fila)

# Imprimimos los resultados obtenidos después de iterar por la lista.
print("Los resultados de iterar por la lista son:\n", resultados_ibex)
# Out:
# Los resultados de iterar por la lista son:
#  [['27-may-24', '11.325,500', '0,71%', '11.325,500', '11.248,900', '11.260,100'], ['28-may-24', '11.276,000', '-0,44%', '11.355,100', '11.240,000', '11.337,600'], ['29-may-24', '11.145,100', '-1,16%', '11.260,900', '11.135,000', '11.241,000'], ['30-may-24', '11.338,200', '1,73%', '11.350,900', '11.125,300', '11.125,300'], ['31-may-24', '11.322,000', '-0,14%', '11.361,200', '11.278,600', '11.353,500'], ['03-jun-24', '11.397,200', '0,66%', '11.452,900', '11.378,000', '11.403,200'], ['04-jun-24', '11.286,400', '-0,97%', '11.402,200', '11.213,200', '11.384,000'], ['05-jun-24', '11.353,100', '0,59%', '11.412,400', '11.323,600', '11.378,500'], ['06-jun-24', '11.444,000', '0,80%', '11.450,900', '11.357,700', '11.387,600'], ['07-jun-24', '11.404,900', '-0,34%', '11.469,900', '11.350,700', '11.447,100'], ['10-jun-24', '11.357,200', '-0,42%', '11.375,300', '11.286,900', '11.375,300'], ['11-jun-24', '11.175,500', '-1,60%', '11.378,200', '11.113,600', '11.377,700'], ['12-jun-24', '11.245,400', '0,63%', '11.273,900', '11.167,000', '11.208,400'], ['13-jun-24', '11.066,100', '-1,59%', '11.241,200', '11.049,100', '11.213,300'], ['14-jun-24', '10.992,300', '-0,67%', '11.078,100', '10.874,100', '11.060,400'], ['17-jun-24', '10.959,500', '-0,30%', '11.082,600', '10.881,500', '11.035,900'], ['18-jun-24', '11.067,700', '0,99%', '11.071,100', '10.955,800', '11.009,300'], ['19-jun-24', '11.056,400', '-0,10%', '11.095,400', '11.033,200', '11.074,600'], ['20-jun-24', '11.160,500', '0,94%', '11.166,400', '11.041,500', '11.068,500'], ['21-jun-24', '11.032,300', '-1,15%', '11.161,600', '10.969,200', '11.161,600']]

# %% [markdown]
# Si nos fijamos, al igual que en el ejemplo anterior tenemos los números como *strings*, por lo que lo vamos a cambiar para tener los formatos corretos:
#
# - En concreto cambiaremos las "," por "."
#
# - Quitaremos los % que tenemos en algunos de los valores.

# %%
# Iteramos a través de cada lista en 'resultados_ibex' y sus elementos usando 'enumerate'.
for indice_lista, lista in enumerate(resultados_ibex):
    for indice_elemento, elemento in enumerate(lista):
        try:
            # Intentamos convertir cada elemento de la lista en un número de punto flotante.
            # Para ello, eliminamos caracteres especiales como '%' y reformateamos la puntuación.
            resultados_ibex[indice_lista][indice_elemento] = float(elemento.replace("%", "").replace(".", "").replace(",", "."))
        except:
            # Si se produce una excepción (por ejemplo, si el elemento no es convertible a flotante), 
            # mantenemos el elemento original en la lista.
            resultados_ibex[indice_lista][indice_elemento] = elemento
            
# Imprimimos los resultados después de limpiar los datos.
print("Los resultados después de limpiar los datos son: \n", resultados_ibex)
# Out:
# Los resultados después de limpiar los datos son:
#  [['27-may-24', 11325.5, 0.71, 11325.5, 11248.9, 11260.1], ['28-may-24', 11276.0, -0.44, 11355.1, 11240.0, 11337.6], ['29-may-24', 11145.1, -1.16, 11260.9, 11135.0, 11241.0], ['30-may-24', 11338.2, 1.73, 11350.9, 11125.3, 11125.3], ['31-may-24', 11322.0, -0.14, 11361.2, 11278.6, 11353.5], ['03-jun-24', 11397.2, 0.66, 11452.9, 11378.0, 11403.2], ['04-jun-24', 11286.4, -0.97, 11402.2, 11213.2, 11384.0], ['05-jun-24', 11353.1, 0.59, 11412.4, 11323.6, 11378.5], ['06-jun-24', 11444.0, 0.8, 11450.9, 11357.7, 11387.6], ['07-jun-24', 11404.9, -0.34, 11469.9, 11350.7, 11447.1], ['10-jun-24', 11357.2, -0.42, 11375.3, 11286.9, 11375.3], ['11-jun-24', 11175.5, -1.6, 11378.2, 11113.6, 11377.7], ['12-jun-24', 11245.4, 0.63, 11273.9, 11167.0, 11208.4], ['13-jun-24', 11066.1, -1.59, 11241.2, 11049.1, 11213.3], ['14-jun-24', 10992.3, -0.67, 11078.1, 10874.1, 11060.4], ['17-jun-24', 10959.5, -0.3, 11082.6, 10881.5, 11035.9], ['18-jun-24', 11067.7, 0.99, 11071.1, 10955.8, 11009.3], ['19-jun-24', 11056.4, -0.1, 11095.4, 11033.2, 11074.6], ['20-jun-24', 11160.5, 0.94, 11166.4, 11041.5, 11068.5], ['21-jun-24', 11032.3, -1.15, 11161.6, 10969.2, 11161.6]]

# %% [markdown]
# Igual que en el caso anterior, es el momento de crear una función con todo el código que hemos ido creando hasta ahora, para unificarlo todo.

# %%
def sacar_tabla_ibex(url):
    
    """
    Extrae datos de una tabla en una página web y devuelve los encabezados y los resultados de la tabla.

    Parameters:
    url (str): La URL de la página web de la que se extraerán los datos de la tabla.

    Returns:
    tuple: Una tupla que contiene dos elementos.
        - Una lista de encabezados de columna de la tabla.
        - Una lista de listas que representan los resultados de la tabla.
    """
    # al igual que en el ejemplo anterior lo primero que haremos será definir la url de la página de la vamos a sacar datos
    url_bolsa_ibex = "https://www.bolsamania.com/indice/IBEX-35/historico-precios"

    # hacemos la request a la página de la que queremos sacar la info
    res_bolsa_ibex = requests.get(url_bolsa_ibex)

    # vemos si todo ha ido bien
    print("La respuesta de la petición es:", res_bolsa_ibex.status_code)
    
    # creamos el objeto BeautifulSoup para poder acceder al contenido solicitado
    sopa_bolsa_historico = BeautifulSoup(res_bolsa_ibex.content, 'html.parser')
    
    # vamos a seguir usando el metodo ".find_all()", pero en este caso lo que buscaremos son todas las tablas que tenemos en la página web.
    tablas_historico = sopa_bolsa.find_all("table")
    
    # La tabla que nos interesa es la última por lo que vamos a crear una nueva variable donde almacenemos los resultados de la tabla que nos interesa
    nuestra_tabla_historico = tablas_historico[2]

    # lo primero que nos va a interesar es extraer los encabezados de la tabla, teniendo en cuenta las definiciones que hemos visto antes, 
    # seleccionaremos la etiqueta "th" usando el método "th"
    lista_ecabezados_historico = nuestra_tabla_historico.find_all("th")

    print("La lista que nos devuelve el metodo '.find_all()' es:\n", lista_ecabezados_historico)

    # como hemos estado haciendo hasta ahora, tendremos que iterar por la lista obtenida en el paso anterior y extraer el texto de cada elemento
    encabezados_ibex_historico = [columna.text for columna in lista_ecabezados_historico]
    
    # sacamos todas las filas de la variable que nos hemos creado previamente (nuestra tabla), usando el método .find_all()
    filas_ibex_historico = nuestra_tabla_historico.find_all("tr")
    
    # creamos una lista para almacenar todos los resultados obtenidos de la lista de  "filas_ibex"
    resultados_ibex_historico = []

    # empezamos a iterar por la lista, pero fijaos que en este caso empezamos desde el segundo elemento de la lista
    for fila in filas_ibex_historico[1:]:
        # añadimos cada elemento a la lista que hemos creado previamente. 
        resultados_ibex_historico.append(fila.text.split("\n")[1:-1])
        
    resultados_ibex_limpio_historico = []
    for indice_lista, lista in enumerate(resultados_ibex_historico):
        for indice_elemento, elemento in enumerate(lista):
            try:
                resultados_ibex_historico[indice_lista][indice_elemento] = float(elemento.replace("%", "").replace(".", "").replace(",", "."))
            except:
                resultados_ibex_historico[indice_lista][indice_elemento]  = elemento
                
    return encabezados_ibex_historico, resultados_ibex_historico

# %%
encabezados_ibex_final, datos_ibex_final = sacar_tabla_ibex(url_bolsa)
# Out:
# La respuesta de la petición es: 200
# La lista que nos devuelve el metodo '.find_all()' es:
#  [<th class="text-left" v-table-sorter-by="'date'">Fecha<span></span></th>, <th class="text-right" v-table-sorter-by="'price'">Precio<span></span></th>, <th class="text-right" v-table-sorter-by="'fallers'">Variación %<span></span></th>, <th class="text-right" v-table-sorter-by="'high'">Máximo<span></span></th>, <th class="text-right" v-table-sorter-by="'low'">Mínimo<span></span></th>, <th class="text-right" v-table-sorter-by="'open'">Apertura<span></span></th>]

# %% [markdown]
# Si nos fijamos ahora, lo que tenemos es una lista de listas. Lo siguiente que querremos hacer en convertirlo en tabla (*DataFrame*) con Pandas como hicimos antes con el ejemplo ed Ebay. Pero antes teníamos un diccionario, ¿podremos convertir esta lista de listas a *DataFrame*? La respuesta es sí, de la misma forma que lo hicimos antes, usando el método de Pandas `pd.DataFrame`. Resumiendo, podremos convertir a *DataFrame*:
#
# - Un diccionario
#
# - Una lista de listas

# %%
# convertimos la lista de listas a DataFrame usando el método 'pd.DataFrame()'. 
df_ibex = pd.DataFrame(datos_ibex_final)

# mostramos las 5 primeras filas del DataFrame
# pero si nos fijamos ahora, los nombres de nuestras columnas son números y no los nombres de los encabezados que sacamos de la tabla de la página web
display("Mostramos las 5 primeras filas del DataFrame",df_ibex.head())
print("-------------------------")
# para poder poner nombre a las columnas en Pandas tenemos varios métodos, pero uno de los más comunes es el método '.columns' 
# en este caso le estamos diciendo que las columnas de nuestro DataFrane queremos que correspondan con los valores de la listas de encabezados_index que creamos al inicio
df_ibex.columns = encabezados_ibex_final


# Mostramos las dos primeras filas del DataFrame
# ahora vemos que las columnas ya no son números, si no los encabezamos que sacamos al inicio
display("Mostramos las 2 primeras filas del DataFrame", df_ibex.head(2))
print("-------------------------")

# el número de filas y columnas del DataFrame son
print("El número de filas y columnas es:", df_ibex.shape)
# Out:
# 'Mostramos las 5 primeras filas del DataFrame'
#            0        1     2        3        4        5
# 0  27-may-24  11325.5  0.71  11325.5  11248.9  11260.1
# 1  28-may-24  11276.0 -0.44  11355.1  11240.0  11337.6
# 2  29-may-24  11145.1 -1.16  11260.9  11135.0  11241.0
# 3  30-may-24  11338.2  1.73  11350.9  11125.3  11125.3
# 4  31-may-24  11322.0 -0.14  11361.2  11278.6  11353.5
# -------------------------
# 'Mostramos las 2 primeras filas del DataFrame'
#        Fecha   Precio  Variación %   Máximo   Mínimo  Apertura
# 0  27-may-24  11325.5         0.71  11325.5  11248.9   11260.1
# 1  28-may-24  11276.0        -0.44  11355.1  11240.0   11337.6
# -------------------------
# El número de filas y columnas es: (20, 6)

# %%
# si recordamos teníamos el método '.dtypes' nos permitía saber cuales eran los tipos de los datos de las distintas columnas que tenemos en el DataFrame
df_ibex.dtypes
# Out:
# Fecha           object
# Precio         float64
# Variación %    float64
# Máximo         float64
# Mínimo         float64
# Apertura       float64
# dtype: object

# %%
# sigamos conociendo algunos métodos nuevos, en este caso sacaremos los valores únicos que tenemos en algunas de las columnas
# para eso usaremos el método '.unique()'. Lo que nos va a mostrar esto son las fechas diferentes que tenemos en la columna de Fecha 
print("Los valores únicos que tenemos en la columna de Fecha son:\n", df_ibex["Fecha"].unique())

print("Los valores únicos que tenemos en la columna de Fecha son:\n", df_ibex["Máximo"].unique())
# Out:
# Los valores únicos que tenemos en la columna de Fecha son:
#  ['27-may-24' '28-may-24' '29-may-24' '30-may-24' '31-may-24' '03-jun-24'
#  '04-jun-24' '05-jun-24' '06-jun-24' '07-jun-24' '10-jun-24' '11-jun-24'
#  '12-jun-24' '13-jun-24' '14-jun-24' '17-jun-24' '18-jun-24' '19-jun-24'
#  '20-jun-24' '21-jun-24']
# Los valores únicos que tenemos en la columna de Fecha son:
#  [11325.5 11355.1 11260.9 11350.9 11361.2 11452.9 11402.2 11412.4 11450.9
#  11469.9 11375.3 11378.2 11273.9 11241.2 11078.1 11082.6 11071.1 11095.4
#  11166.4 11161.6]

# %%
# otro de los métodos que más usaremos es el método '.value_counts()' 
# este método lo que va a hacer es contar cuántas veces aparecen cada una de los valores únicos que tenemos en esa columna
# en este caso lo que vemos es que cada una de las fechas que tenemos en la columna aparecen solo una vez. 
df_ibex["Fecha"].value_counts()
# Out:
# 27-may-24    1
# 28-may-24    1
# 20-jun-24    1
# 19-jun-24    1
# 18-jun-24    1
# 17-jun-24    1
# 14-jun-24    1
# 13-jun-24    1
# 12-jun-24    1
# 11-jun-24    1
# 10-jun-24    1
# 07-jun-24    1
# 06-jun-24    1
# 05-jun-24    1
# 04-jun-24    1
# 03-jun-24    1
# 31-may-24    1
# 30-may-24    1
# 29-may-24    1
# 21-jun-24    1
# Name: Fecha, dtype: int64

# %%
# de la misma forma que le hemos preguntado antes a Pandas cuántos valores nulos tenemos por columnas, 
# también le podemos preguntar cuántos valores no nulos tenemos en cada una de ellas usando el método 'notnull()'
df_ibex.notnull().sum()
# Out:
# Fecha          20
# Precio         20
# Variación %    20
# Máximo         20
# Mínimo         20
# Apertura       20
# dtype: int64

# %%
# por último, nos puede interesar guardar estos datos en un csv en nuestro ordenador para utilizarla en otro momento
# para esto tendremos que usar el método "pd.to_csv()"

df_ibex.to_csv("datos_ibex.csv")

# %% [markdown]
# # Resumen de los métodos aprendidos de Pandas
#
# Pandas es una poderosa herramienta para el análisis y manipulación de datos. Aquí os dejamos un resumen de los métodos de Pandas que hemos aprendido durante la lección:
#
# 1. **head() y tail()**: Estos métodos se utilizan para mostrar las primeras filas o las últimas filas de un DataFrame. Son útiles para obtener una vista previa rápida de los datos.
#    ```python
#    # Mostrar las primeras 5 filas del DataFrame
#    df.head()
#
#    # Mostrar las últimas 5 filas del DataFrame
#    df.tail()
#    ```
#
# 2. **info()**: El método `info()` muestra un resumen conciso de un DataFrame, incluyendo el tipo de datos de cada columna y la cantidad de valores no nulos. Es útil para comprender la estructura de tus datos.
#    ```python
#    # Mostrar información resumida del DataFrame
#    df.info()
#    ```
#
# 3. **describe()**: El método `describe()` genera estadísticas descriptivas de las columnas numéricas de un DataFrame, como la cuenta, media, desviación estándar, mínimo, máximo y percentiles. Proporciona información útil sobre la distribución de los datos.
#    ```python
#    # Mostrar estadísticas descriptivas del DataFrame
#    df.describe()
#    ```
#
# 4. **shape**: El atributo `shape` devuelve una tupla que representa las dimensiones del DataFrame, es decir, el número de filas y columnas.
#    ```python
#    # Obtener las dimensiones del DataFrame
#    df.shape
#    ```
#
# 5. **columns**: El atributo `columns` devuelve una lista de las columnas del DataFrame.
#    ```python
#    # Obtener la lista de columnas del DataFrame
#    df.columns
#    ```
#
# 6. **value_counts()**: El método `value_counts()` cuenta los valores únicos en una columna y los muestra en orden descendente. Es útil para realizar un recuento de categorías o valores específicos en una columna.
#    ```python
#    # Contar los valores únicos en una columna
#    df['columna'].value_counts()
#    ```
#
# 7. **unique()**: El método `unique()` devuelve una lista de los valores únicos en una columna. Es útil para obtener una lista de categorías o valores distintos.
#    ```python
#    # Obtener los valores únicos en una columna
#    df['columna'].unique()
#    ```
#
# 8. **isnull() y notnull()**: Estos métodos se utilizan para verificar la presencia de valores nulos en un DataFrame. Devuelven una máscara booleana que indica si cada valor es nulo o no nulo.
#    ```python
#    # Verificar valores nulos en el DataFrame
#    df.isnull()
#
#    # Verificar valores no nulos en el DataFrame
#    df.notnull()
#    ```

# %% [markdown]
# # Ejercicios
#
# 1. Usa la [siguiente](https://es.wikipedia.org/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020) página web.
#
# 2. Extrae la tabla de las medallas olímpicas que tenéis en la página web.
#
# 3. Mete todo el código de la extracción de datos en una función.
#
# 4. Los resultados deben estar en un *DataFrame* y hacer una exploración básica con los métodos aprendidos en la lección.

# %%
url_medallero = "https://es.wikipedia.org/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020"

medallas_olimpicas = requests.get(url_medallero)

medallas_olimpicas.status_code

#Solicitud HTTP GET a la URL de Wikipedia donde está la tabla del medallero.
#La respuesta de la solicitud está almacenada en la variable medallas_olimpicas.
#verificación solicitud. 200 = existosa
# Out:
# 200

# %%
#medallas_olimpicas.content: esto se usa despues de usar BeautifulSoup porque sin no nosdsale
#el cósigo en bytes, no en str

medallas_olimpicas.text

#Contenido HTML de la página web. Esto es lo que vamos a analizar para extraer la tabla.
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="es" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Anexo:Medallero de los Juegos Olímpicos de Tokio 2020 - Wikipedia, la enciclopedia libre</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )eswikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],\n"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"d9a051b9-c315-445e-ab9f-fe0288e3e009","wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":104,"wgPageName":"Anexo:Medallero_de_los_Juegos_Olímpicos_de_Tokio_2020","wgTitle":"Medallero de los Juegos Olímpicos de Tokio 2020","wgCurRevisionId":161824722,"wgRevisionId":161824722,"wgArticleId":9977470,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Anexos:Medalleros de los Juegos Olímpicos de Verano","Juegos Olímpicos de Tokio 2020","Anexos:2021"],"wgPageViewLanguage":"es","wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgRelevantPageName":"Anexo:Medallero_de_los_Juegos_Olímpicos_de_Tokio_2020","wgRelevantArticleId":9977470,"wgIsProbablyEditable":true,\n"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":true,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgULSCurrentAutonym":"español","wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q61440363","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,\n"wgGETopicsMatchModeEnabled":true,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJ ...

# %%
type(medallas_olimpicas.text)
# Out:
# str

# %%
sopa_medallas = BeautifulSoup (medallas_olimpicas.content, "html.parser")
sopa_medallas

#html.parser intrepreta lo que pone en medallas_olimpicas.content.
#Se crea un objeto BeautifulSoup para analizar el contenido HTML.
#Este objeto permite navegar y buscar dentro del documento HTML.
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Anexo:Medallero de los Juegos Olímpicos de Tokio 2020 - Wikipedia, la enciclopedia libre</title>
# <script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )eswikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\t."," \t,"],
# "wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"d9a051b9-c315-445e-ab9f-fe0288e3e009","wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":104,"wgPageName":"Anexo:Medallero_de_los_Juegos_Olímpicos_de_Tokio_2020","wgTitle":"Medallero de los Juegos Olímpicos de Tokio 2020","wgCurRevisionId":161824722,"wgRevisionId":161824722,"wgArticleId":9977470,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Anexos:Medalleros de los Juegos Olímpicos de Verano","Juegos Olímpicos de Tokio 2020","Anexos:2021"],"wgPageViewLanguage":"es","wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgRelevantPageName":"Anexo:Medallero_de_los_Juegos_Olímpicos_de_Tokio_2020","wgRelevantArticleId":9977470,"wgIsProbablyEditable":true,
# "wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":true,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgULSCurrentAutonym":"español","wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q61440363","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,
# "wgGETopicsMatchModeEnabled":true,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.tablesorter.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","mediawiki.page.media","site","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.a-commons-directo","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher",
# "ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","wikibase.sidebar.tracking"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});</script>
# <link href="/w/load.php?lang=es&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cext.wikimediamessages.styles%7Cjquery.tablesorter.styles%7Cskins.vector.icons%2Cstyles%7Cskins.vector.search.codex.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=es&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=es&amp;modules=ext.gadget.imagenesinfobox&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <link href="/w/load.php?lang=es&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <noscript><link href="/w/load.php?lang=es&amp;modules=noscript&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/></noscript>
# <meta content="MediaWiki 1.43.0-wmf.19" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="max-image-preview:standard" name="robots"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=1120" name="viewport"/>
# <meta content="Anexo:Medallero de los Juegos Olímpicos de Tokio 2020 - Wikipedia, la enciclopedia libre" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//es.m.wikipedia.org/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=edit" rel="alternate" title="Editar" type="application/x-wiki"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="icon"/>
# <link href="/w/rest.php/v1/search" rel="search" title="Wikipedia (es)" type="application/opensearchdescription+xml"/>
# <link href="//es.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://es.wikipedia.org/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" rel="canonical"/>
# <link href="https://creativecommons.org/licenses/by-sa/4.0/deed.es" rel="license"/>
# <link href="/w/index.php?title=Especial:CambiosRecientes&amp;feed=atom" rel="alternate" title="Canal Atom de Wikipedia" type="application/atom+xml"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch">
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </link></head>
# <body class="skin--responsive skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-104 ns-subject mw-editable page-Anexo_Medallero_de_los_Juegos_Olímpicos_de_Tokio_2020 rootpage-Anexo_Medallero_de_los_Juegos_Olímpicos_de_Tokio_2020 skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Ir al contenido</a>
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Sitio" class="vector-main-menu-landmark">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Menú principal" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label"><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
# <span class="vector-dropdown-label-text">Menú principal</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-main-menu-unpinned-container">
# <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
# <div class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned" data-feature-name="main-menu-pinned" data-pinnable-element-id="vector-main-menu" data-pinned-container-id="vector-main-menu-pinned-container" data-unpinned-container-id="vector-main-menu-unpinned-container">
# <div class="vector-pinnable-header-label">Menú principal</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">mover a la barra lateral</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">ocultar</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-navigation" id="p-navigation">
# <div class="vector-menu-heading">
# 		Navegación
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Wikipedia:Portada" title="Visitar la página principal [z]"><span>Portada</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Portal:Comunidad" title="Acerca del proyecto, lo que puedes hacer, dónde encontrar información"><span>Portal de la comunidad</span></a></li><li class="mw-list-item" id="n-currentevents"><a href="/wiki/Portal:Actualidad" title="Encuentra información de contexto sobre acontecimientos actuales"><span>Actualidad</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Especial:CambiosRecientes" title="Lista de cambios recientes en la wiki [r]"><span>Cambios recientes</span></a></li><li class="mw-list-item" id="n-newpages"><a href="/wiki/Especial:P%C3%A1ginasNuevas"><span>Páginas nuevas</span></a></li><li class="mw-list-item" id="n-randompage"><a accesskey="x" href="/wiki/Especial:Aleatoria" title="Cargar una página al azar [x]"><span>Página aleatoria</span></a></li><li class="mw-list-item" id="n-help"><a href="/wiki/Ayuda:Contenidos" title="El lugar para aprender"><span>Ayuda</span></a></li><li class="mw-list-item" id="n-sitesupport"><a href="//donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_es.wikipedia.org&amp;uselang=es" title="Apóyanos"><span>Donaciones</span></a></li><li class="mw-list-item" id="n-bug_in_article"><a href="/wiki/Wikipedia:Informes_de_error"><span>Notificar un error</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <a class="mw-logo" href="/wiki/Wikipedia:Portada">
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
# <span class="mw-logo-container skin-invert">
# <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
# <img alt="La enciclopedia libre" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-es.svg" style="width: 7.5em; height: 0.8125em;" width="120"/>
# </span>
# </a>
# </div>
# <div class="vector-header-end">
# <div class="vector-search-box-vue vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box" id="p-search" role="search">
# <a accesskey="f" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" href="/wiki/Especial:Buscar" title="Buscar en este wiki [f]"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></span>
# <span>Buscar</span>
# </a>
# <div class="vector-typeahead-search-container">
# <div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
# <form action="/w/index.php" class="cdx-search-input cdx-search-input--has-end-button" id="searchform">
# <div class="cdx-search-input__input-wrapper" data-search-loc="header-moved" id="simpleSearch">
# <div class="cdx-text-input cdx-text-input--has-start-icon">
# <input accesskey="f" aria-label="Buscar en Wikipedia" autocapitalize="sentences" class="cdx-text-input__input" id="searchInput" name="search" placeholder="Buscar en Wikipedia" title="Buscar en este wiki [f]" type="search"/>
# <span class="cdx-text-input__icon cdx-text-input__start-icon"></span>
# </div>
# <input name="title" type="hidden" value="Especial:Buscar"/>
# </div>
# <button class="cdx-button cdx-search-input__end-button">Buscar</button>
# </form>
# </div>
# </div>
# </div>
# <nav aria-label="Herramientas personales" class="vector-user-links vector-user-links-wide">
# <div class="vector-user-links-main">
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-preferences">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-userpage">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <nav aria-label="Apariencia" class="vector-appearance-landmark">
# <div class="vector-dropdown" id="vector-appearance-dropdown">
# <input aria-haspopup="true" aria-label="Apariencia" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-appearance-dropdown" id="vector-appearance-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-appearance-dropdown-checkbox" id="vector-appearance-dropdown-label"><span class="vector-icon mw-ui-icon-appearance mw-ui-icon-wikimedia-appearance"></span>
# <span class="vector-dropdown-label-text">Apariencia</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-appearance-unpinned-container">
# </div>
# </div>
# </div>
# </nav>
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-notifications">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet" id="p-vector-user-menu-overflow">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-createaccount-2"><a class="" data-mw="interface" href="/w/index.php?title=Especial:Crear_una_cuenta&amp;returnto=Anexo%3AMedallero+de+los+Juegos+Ol%C3%ADmpicos+de+Tokio+2020" title="Te recomendamos crear una cuenta e iniciar sesión; sin embargo, no es obligatorio"><span>Crear una cuenta</span></a>
# </li>
# <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-login-2"><a accesskey="o" class="" data-mw="interface" href="/w/index.php?title=Especial:Entrar&amp;returnto=Anexo%3AMedallero+de+los+Juegos+Ol%C3%ADmpicos+de+Tokio+2020" title="Te recomendamos iniciar sesión, aunque no es obligatorio [o]"><span>Acceder</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="vector-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out" id="vector-user-links-dropdown" title="Más opciones">
# <input aria-haspopup="true" aria-label="Herramientas personales" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-user-links-dropdown" id="vector-user-links-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-user-links-dropdown-checkbox" id="vector-user-links-dropdown-label"><span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis"></span>
# <span class="vector-dropdown-label-text">Herramientas personales</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item" id="p-personal" title="Menú de usuario">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="user-links-collapsible-item mw-list-item" id="pt-createaccount"><a href="/w/index.php?title=Especial:Crear_una_cuenta&amp;returnto=Anexo%3AMedallero+de+los+Juegos+Ol%C3%ADmpicos+de+Tokio+2020" title="Te recomendamos crear una cuenta e iniciar sesión; sin embargo, no es obligatorio"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Crear una cuenta</span></a></li><li class="user-links-collapsible-item mw-list-item" id="pt-login"><a accesskey="o" href="/w/index.php?title=Especial:Entrar&amp;returnto=Anexo%3AMedallero+de+los+Juegos+Ol%C3%ADmpicos+de+Tokio+2020" title="Te recomendamos iniciar sesión, aunque no es obligatorio [o]"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span> <span>Acceder</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor" id="p-user-menu-anon-editor">
# <div class="vector-menu-heading">
# 		Páginas para editores desconectados <a aria-label="Obtenga más información sobre editar" href="/wiki/Ayuda:Introducci%C3%B3n"><span>más información</span></a>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="pt-anoncontribs"><a accesskey="y" href="/wiki/Especial:MisContribuciones" title="Una lista de modificaciones hechas desde esta dirección IP [y]"><span>Contribuciones</span></a></li><li class="mw-list-item" id="pt-anontalk"><a accesskey="n" href="/wiki/Especial:MiDiscusi%C3%B3n" title="Discusión sobre ediciones hechas desde esta dirección IP [n]"><span>Discusión</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# </div>
# <div class="mw-page-container">
# <div class="mw-page-container-inner">
# <div class="vector-sitenotice-container">
# <div class="notheme" id="siteNotice"><!-- CentralNotice --></div>
# </div>
# <div class="vector-column-start">
# <div class="vector-main-menu-container">
# <div id="mw-navigation">
# <nav aria-label="Sitio" class="vector-main-menu-landmark" id="mw-panel">
# <div class="vector-pinned-container" id="vector-main-menu-pinned-container">
# </div>
# </nav>
# </div>
# </div>
# <div class="vector-sticky-pinned-container">
# <nav aria-label="Contenidos" class="mw-table-of-contents-container vector-toc-landmark" data-event-name="ui.sidebar-toc" id="mw-panel-toc">
# <div class="vector-pinned-container" id="vector-toc-pinned-container">
# <div class="vector-toc vector-pinnable-element" id="vector-toc">
# <div class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned" data-feature-name="toc-pinned" data-pinnable-element-id="vector-toc">
# <h2 class="vector-pinnable-header-label">Contenidos</h2>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">mover a la barra lateral</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">ocultar</button>
# </div>
# <ul class="vector-toc-contents" id="mw-panel-toc-list">
# <li class="vector-toc-list-item vector-toc-level-1" id="toc-mw-content-text">
# <a class="vector-toc-link" href="#">
# <div class="vector-toc-text">Inicio</div>
# </a>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Medallas">
# <a class="vector-toc-link" href="#Medallas">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1</span>
# <span>Medallas</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Medallas-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Medallero">
# <a class="vector-toc-link" href="#Medallero">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2</span>
# <span>Medallero</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Medallero-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Cambios_y_particularidades_en_el_medallero">
# <a class="vector-toc-link" href="#Cambios_y_particularidades_en_el_medallero">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3</span>
# <span>Cambios y particularidades en el medallero</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Cambios_y_particularidades_en_el_medallero-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Véase_también">
# <a class="vector-toc-link" href="#Véase_también">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4</span>
# <span>Véase también</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Véase_también-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Referencias">
# <a class="vector-toc-link" href="#Referencias">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">5</span>
# <span>Referencias</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Referencias-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Enlaces_externos">
# <a class="vector-toc-link" href="#Enlaces_externos">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6</span>
# <span>Enlaces externos</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Enlaces_externos-sublist">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="mw-content-container">
# <main class="mw-body" id="content">
# <header class="mw-body-header vector-page-titlebar">
# <nav aria-label="Contenidos" class="vector-toc-landmark">
# <div class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left" id="vector-page-titlebar-toc">
# <input aria-haspopup="true" aria-label="Cambiar a la tabla de contenidos" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-titlebar-toc" id="vector-page-titlebar-toc-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-page-titlebar-toc-checkbox" id="vector-page-titlebar-toc-label"><span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet"></span>
# <span class="vector-dropdown-label-text">Cambiar a la tabla de contenidos</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-page-titlebar-toc-unpinned-container">
# </div>
# </div>
# </div>
# </nav>
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-namespace">Anexo</span><span class="mw-page-title-separator">:</span><span class="mw-page-title-main">Medallero de los Juegos Olímpicos de Tokio 2020</span></h1>
# <div class="vector-dropdown mw-portlet mw-portlet-lang" id="p-lang-btn">
# <input aria-haspopup="true" aria-label="Ir a un artículo en otro idioma. Disponible en 43 idiomas" class="vector-dropdown-checkbox mw-interlanguage-selector" data-event-name="ui.dropdown-p-lang-btn" id="p-lang-btn-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressive mw-portlet-lang-heading-43" for="p-lang-btn-checkbox" id="p-lang-btn-label"><span class="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-language-progressive"></span>
# <span class="vector-dropdown-label-text">43 idiomas</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="interlanguage-link interwiki-ar mw-list-item"><a class="interlanguage-link-target" data-language-autonym="العربية" data-language-local-name
span></a></li><li class="interlanguage-link interwiki-ca mw-list-item"><a class="interlanguage-link-target" data-language-autonym="Català" data-language-local-name="catalán" data-title="Medaller dels Jocs Olímpics d'estiu de 2020" href="https://ca.wikipedia.org/wiki/Medaller_dels_Jocs_Ol%C3%ADmpics_d%27estiu_de_2020" hreflang="ca" lang="ca" title="Medaller dels Jocs Olímpics d'estiu de 2020 (catalán)"><span>Català</span></a></li><li class="interlanguage-link interwiki-ckb mw-list-item"><a class="interlanguage-link-target" data-language-autonym="کوردی" data-language-local-name="kurdo sorani" data-title="پێرستی مەدالیاکانی ئۆڵۆمپیادی ھاوینەی ٢٠٢٠" href="https://ckb.wikipedia.org/wiki/%D9%BE% ...
# </ul>
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q61440363#sitelinks-wikipedia" title="Editar enlaces interlingüísticos">Editar enlaces</a></span></div>
# </div>
# </div>
# </div>
# </header>
# <div class="vector-page-toolbar">
# <div class="vector-page-toolbar-container">
# <div id="left-navigation">
# <nav aria-label="Espacios de nombres">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages" id="p-associated-pages">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-tab-noicon mw-list-item" id="ca-nstab-anexo"><a accesskey="c" href="/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Ver la página de contenido [c]"><span>Anexo</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-talk"><a accesskey="t" href="/wiki/Anexo_discusi%C3%B3n:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" rel="discussion" title="Discusión acerca de la página [t]"><span>Discusión</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-dropdown emptyPortlet" id="vector-variants-dropdown">
# <input aria-haspopup="true" aria-label="Cambiar variante de idioma" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-variants-dropdown" id="vector-variants-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" for="vector-variants-dropdown-checkbox" id="vector-variants-dropdown-label"><span class="vector-dropdown-label-text">español</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu mw-portlet mw-portlet-variants emptyPortlet" id="p-variants">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="vector-collapsible" id="right-navigation">
# <nav aria-label="Vistas">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-views" id="p-views">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-tab-noicon mw-list-item" id="ca-view"><a href="/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020"><span>Leer</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-edit"><a accesskey="e" href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=edit" title="Editar esta página [e]"><span>Editar</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-history"><a accesskey="h" href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=history" title="Versiones anteriores de esta página [h]"><span>Ver historial</span></a></li>
# </ul>
# </div>
# </div>
# </nav>
# <nav aria-label="Página de herramientas" class="vector-page-tools-landmark">
# <div class="vector-dropdown vector-page-tools-dropdown" id="vector-page-tools-dropdown">
# <input aria-haspopup="true" aria-label="Herramientas" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-tools-dropdown" id="vector-page-tools-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" for="vector-page-tools-dropdown-checkbox" id="vector-page-tools-dropdown-label"><span class="vector-dropdown-label-text">Herramientas</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-page-tools-unpinned-container">
# <div class="vector-page-tools vector-pinnable-element" id="vector-page-tools">
# <div class="vector-pinnable-header vector-page-tools-pinnable-header vector-pinnable-header-unpinned" data-feature-name="page-tools-pinned" data-pinnable-element-id="vector-page-tools" data-pinned-container-id="vector-page-tools-pinned-container" data-unpinned-container-id="vector-page-tools-unpinned-container">
# <div class="vector-pinnable-header-label">Herramientas</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-page-tools.pin">mover a la barra lateral</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-page-tools.unpin">ocultar</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-cactions emptyPortlet vector-has-collapsible-items" id="p-cactions" title="Más opciones">
# <div class="vector-menu-heading">
# 		Acciones
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-more-collapsible-item mw-list-item" id="ca-more-view"><a href="/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020"><span>Leer</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-edit"><a accesskey="e" href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=edit" title="Editar esta página [e]"><span>Editar</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-history"><a href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=history"><span>Ver historial</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-tb" id="p-tb">
# <div class="vector-menu-heading">
# 		General
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="t-whatlinkshere"><a accesskey="j" href="/wiki/Especial:LoQueEnlazaAqu%C3%AD/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Lista de todas las páginas de la wiki que enlazan aquí [j]"><span>Lo que enlaza aquí</span></a></li><li class="mw-list-item" id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Especial:CambiosEnEnlazadas/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" rel="nofollow" title="Cambios recientes en las páginas que enlazan con esta [k]"><span>Cambios en enlazadas</span></a></li><li class="mw-list-item" id="t-upload"><a accesskey="u" href="//commons.wikimedia.org/wiki/Special:UploadWizard?uselang=es" title="Subir archivos [u]"><span>Subir archivo</span></a></li><li class="mw-list-item" id="t-specialpages"><a accesskey="q" href="/wiki/Especial:P%C3%A1ginasEspeciales" title="Lista de todas las páginas especiales [q]"><span>Páginas especiales</span></a></li><li class="mw-list-item" id="t-permalink"><a href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;oldid=161824722" title="Enlace permanente a esta versión de la página"><span>Enlace permanente</span></a></li><li class="mw-list-item" id="t-info"><a href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=info" title="Más información sobre esta página"><span>Información de la página</span></a></li><li class="mw-list-item" id="t-cite"><a href="/w/index.php?title=Especial:Citar&amp;page=Anexo%3AMedallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;id=161824722&amp;wpFormIdentifier=titleform" title="Información sobre cómo citar esta página"><span>Citar esta página</span></a></li><li class="mw-list-item" id="t-urlshortener"><a href="/w/index.php?title=Especial:Acortador_de_URL&amp;url=https%3A%2F%2Fes.wikipedia.org%2Fwiki%2FAnexo%3AMedallero_de_los_Juegos_Ol%25C3%25ADmpicos_de_Tokio_2020"><span>Obtener URL acortado</span></a></li><li class="mw-list-item" id="t-urlshortener-qrcode"><a href="/w/index.php?title=Especial:QrCode&amp;url=https%3A%2F%2Fes.wikipedia.org%2Fwiki%2FAnexo%3AMedallero_de_los_Juegos_Ol%25C3%25ADmpicos_de_Tokio_2020"><span>Descargar código QR</span></a></li><li class="mw-list-item" id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q61440363" title="Enlace al elemento conectado del repositorio de datos [g]"><span>Elemento de Wikidata</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-coll-print_export" id="p-coll-print_export">
# <div class="vector-menu-heading">
# 		Imprimir/exportar
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="coll-create_a_book"><a href="/w/index.php?title=Especial:Libro&amp;bookcmd=book_creator&amp;referer=Anexo%3AMedallero+de+los+Juegos+Ol%C3%ADmpicos+de+Tokio+2020"><span>Crear un libro</span></a></li><li class="mw-list-item" id="coll-download-as-rl"><a href="/w/index.php?title=Especial:DownloadAsPdf&amp;page=Anexo%3AMedallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=show-download-screen"><span>Descargar como PDF</span></a></li><li class="mw-list-item" id="t-print"><a accesskey="p" href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;printable=yes" title="Versión imprimible de esta página [p]"><span>Versión para imprimir</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </div>
# <div class="vector-column-end">
# <div class="vector-sticky-pinned-container">
# <nav aria-label="Página de herramientas" class="vector-page-tools-landmark">
# <div class="vector-pinned-container" id="vector-page-tools-pinned-container">
# </div>
# </nav>
# <nav aria-label="Apariencia" class="vector-appearance-landmark">
# <div class="vector-pinned-container" id="vector-appearance-pinned-container">
# <div class="vector-appearance vector-pinnable-element" id="vector-appearance">
# <div class="vector-pinnable-header vector-appearance-pinnable-header vector-pinnable-header-pinned" data-feature-name="appearance-pinned" data-pinnable-element-id="vector-appearance" data-pinned-container-id="vector-appearance-pinned-container" data-unpinned-container-id="vector-appearance-unpinned-container">
# <div class="vector-pinnable-header-label">Apariencia</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-appearance.pin">mover a la barra lateral</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-appearance.unpin">ocultar</button>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div aria-labelledby="firstHeading" class="vector-body" data-mw-ve-target-container="" id="bodyContent">
# <div class="vector-body-before-content">
# <div class="mw-indicators">
# </div>
# <div class="noprint" id="siteSub">De Wikipedia, la enciclopedia libre</div>
# </div>
# <div id="contentSub"><div id="mw-content-subtitle"></div></div>
# <div class="mw-body-content" id="mw-content-text"><div class="mw-content-ltr mw-parser-output" dir="ltr" lang="es"><figure typeof="mw:File/Thumb"><a class="mw-file-description" href="/wiki/Archivo:2020_Summer_Olympics_medal_map.svg"><img class="mw-file-element" data-file-height="376" data-file-width="852" decoding="async" height="132" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/2020_Summer_Olympics_medal_map.svg/300px-2020_Summer_Olympics_medal_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/2020_Summer_Olympics_medal_map.svg/450px-2020_Summer_Olympics_medal_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/17/2020_Summer_Olympics_medal_map.svg/600px-2020_Summer_Olympics_medal_map.svg.png 2x" width="300"/></a><figcaption>Mapa mundial que muestra los logros de medallas de cada país durante los Juegos Olímpicos de 2020.<br/> <b>Leyenda:</b><br/> <span style="margin:0px; padding-bottom:1px; font-size:90%; display:block;"><span style="border: 1px solid; border-color: black; background-color:#FFD700; color:white">    </span> <b>Oro</b> para los países que consiguieron, al menos, una medalla de oro.</span> <span style="margin:0px; padding-bottom:1px; font-size:90%; display:block;"><span style="border: 1px solid; border-color: black; background-color:#C0C0C0; color:white">    </span> <b>Plata</b> para los países que no consiguieron ninguna medalla de oro, pero sí, al menos, una medalla de plata.</span> <span style="margin:0px; padding-bottom:1px; font-size:90%; display:block;"><span style="border: 1px solid; border-color: black; background-color:#CC9966; color:white">    </span> <b>Bronce</b> para los países que no consiguieron ninguna medalla de oro o plata, pero sí, al menos, una medalla de bronce.</span> <span style="margin:0px; padding-bottom:1px; font-size:90%; display:block;"><span style="border: 1px solid; border-color: black; background-color:#99D9EA; color:white">    </span> <b>Azul</b> para los países que no consiguieron ninguna medalla.</span> <span style="margin:0px; padding-bottom:1px; font-size:90%; display:block;"><span style="border: 1px solid; border-color: black; background-color:#ED1C24; color:white">    </span> <b>Rojo</b> para las entidades que no participaron.</span></figcaption></figure>
# <figure typeof="mw:File/Thumb"><a class="mw-file-description" href="/wiki/Archivo:Countries_by_medals_2020_Summer_Olympics.svg"><img class="mw-file-element" data-file-height="376" data-file-width="852" decoding="async" height="132" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/39/Countries_by_medals_2020_Summer_Olympics.svg/300px-Countries_by_medals_2020_Summer_Olympics.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/39/Countries_by_medals_2020_Summer_Olympics.svg/450px-Countries_by_medals_2020_Summer_Olympics.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/39/Countries_by_medals_2020_Summer_Olympics.svg/600px-Countries_by_medals_2020_Summer_Olympics.svg.png 2x" width="300"/></a><figcaption>Número total de medallas de cada país durante los Juegos Olímpicos de Tokio 2020.</figcaption></figure>
# <p>El siguiente medallero es una lista de los <a class="mw-redirect" href="/wiki/Comit%C3%A9s_Ol%C3%ADmpicos_Nacionales" title="Comités Olímpicos Nacionales">Comités Olímpicos Nacionales</a> (CON) y un equipo que no pertenece a un CON, clasificado por el número de medallas de oro ganadas por sus atletas durante los <a href="/wiki/Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Juegos Olímpicos de Tokio 2020">Juegos Olímpicos de Tokio 2020</a>, del 23 de julio al 8 de agosto de 2021. <a href="/wiki/Bermudas_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Bermudas en los Juegos Olímpicos de Tokio 2020">Bermudas</a>, <a href="/wiki/Catar_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Catar en los Juegos Olímpicos de Tokio 2020">Catar</a> y <a href="/wiki/Filipinas_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Filipinas en los Juegos Olímpicos de Tokio 2020">Filipinas</a> ganaron sus primeras medallas de oro olímpicas,<sup class="reference separada" id="cite_ref-1"><a href="#cite_note-1"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a></sup>​<sup class="reference separada" id="cite_ref-2"><a href="#cite_note-2"><span class="corchete-llamada">[</span>2<span class="corchete-llamada">]</span></a></sup>​
# <sup class="reference separada" id="cite_ref-3"><a href="#cite_note-3"><span class="corchete-llamada">[</span>3<span class="corchete-llamada">]</span></a></sup>​ mientras que <a href="/wiki/San_Marino_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="San Marino en los Juegos Olímpicos de Tokio 2020">San Marino</a>, <a href="/wiki/Burkina_Faso_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Burkina Faso en los Juegos Olímpicos de Tokio 2020">Burkina Faso</a> y <a href="/wiki/Turkmenist%C3%A1n_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Turkmenistán en los Juegos Olímpicos de Tokio 2020">Turkmenistán</a> obtuvieron su primera medalla.<sup class="reference separada" id="cite_ref-4"><a href="#cite_note-4"><span class="corchete-llamada">[</span>4<span class="corchete-llamada">]</span></a></sup>​<sup class="reference separada" id="cite_ref-5"><a href="#cite_note-5"><span class="corchete-llamada">[</span>5<span class="corchete-llamada">]</span></a></sup>​
# </p>
# <meta property="mw:PageProp/toc">
# <div class="mw-heading mw-heading2"><h2 id="Medallas">Medallas</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=edit&amp;section=1" title="Editar sección: Medallas"><span>editar</span></a><span class="mw-editsection-bracket">]</span></span></div>
# <div class="VT rellink"><span style="font-size:88%">Véase también:</span> <i><a href="/wiki/Medalla_Ol%C3%ADmpica" title="Medalla Olímpica">Medalla Olímpica</a></i></div>
# <p>El diseño de las medallas olímpicas para los Juegos Olímpicos de verano de 2020 fue creado por Junichi Kawanishi. Las medallas se fabricaron con metal reciclado extraído de pequeños <a href="/wiki/Electr%C3%B3nica" title="Electrónica">dispositivos electrónicos</a> donados por el público. La cinta de la medalla empleó los <a href="/wiki/Motivo_(artes_visuales)" title="Motivo (artes visuales)">motivo</a>s de diseño japoneses tradicionales que se encuentran en «ichimatsu moyo», un patrón de <a href="/wiki/Damas" title="Damas">cuadros</a> armonizados, y «kasane no irome», una técnica tradicional de capas de <a href="/wiki/Kimono" title="Kimono">kimono</a>, en una presentación moderna. La caja de la medalla está fabricada con madera de <a href="/wiki/Fraxinus" title="Fraxinus">fresno</a> japonés teñida con el mismo color que el emblema olímpico. La tapa circular y el cuerpo de la caja se pueden abrir como un anillo conectado por un imán.<sup class="reference separada" id="cite_ref-6"><a href="#cite_note-6"><span class="corchete-llamada">[</span>6<span class="corchete-llamada">]</span></a></sup>​ El anverso de las medallas presenta a <a href="/wiki/Nike_(mitolog%C3%ADa)" title="Nike (mitología)">Nike</a>, la diosa griega de la victoria, frente al <a href="/wiki/Estadio_Panathinaik%C3%B3" title="Estadio Panathinaikó">Estadio Panathinaikó</a> y los <a href="/wiki/S%C3%ADmbolos_ol%C3%ADmpicos" title="Símbolos olímpicos">aros olímpicos</a>.<sup class="reference separada" id="cite_ref-7"><a href="#cite_note-7"><span class="corchete-llamada">[</span>7<span class="corchete-llamada">]</span></a></sup>​
# </p><p>Debido a la <a href="/wiki/Pandemia_de_COVID-19" title="Pandemia de COVID-19">pandemia de COVID-19</a>, los atletas recibieron sus medallas en bandejas y se les pidió que se las pusieran ellos mismos, en lugar de que un dignatario las colocara alrededor del cuello.<sup class="reference separada" id="cite_ref-8"><a href="#cite_note-8"><span class="corchete-llamada">[</span>8<span class="corchete-llamada">]</span></a></sup>​
# </p>
# ...
# </li>
# </ol></div><p>
# </p><div class="mw-heading mw-heading2"><h2 id="Enlaces_externos">Enlaces externos</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;action=edit&amp;section=6" title="Editar sección: Enlaces externos"><span>editar</span></a><span class="mw-editsection-bracket">]</span></span></div>
# <ul><li><a class="external text" href="https://web.archive.org/web/20220221222647/https://olympics.com/en/olympic-games/tokyo-2020/medals" rel="nofollow">Medallero olímpico oficial</a> (versión archivada en Archive.org a 21 de febrero de 2022)</li></ul>
# <style data-mw-deduplicate="TemplateStyles:r161257576">.mw-parser-output .mw-authority-control{margin-top:1.5em}.mw-parser-output .mw-authority-control .navbox table{margin:0}.mw-parser-output .mw-authority-control .navbox hr:last-child{display:none}.mw-parser-output .mw-authority-control .navbox+.mw-mf-linked-projects{display:none}.mw-parser-output .mw-authority-control .mw-mf-linked-projects{display:flex;padding:0.5em;border:1px solid var(--border-color-base,#a2a9b1);background-color:var(--background-color-neutral,#eaecf0);color:var(--color-base,#202122)}.mw-parser-output .mw-authority-control .mw-mf-linked-projects ul li{margin-bottom:0}.mw-parser-output .mw-authority-control .navbox{border:1px solid var(--border-color-base,#a2a9b1);background-color:var(--background-color-neutral-subtle,#f8f9fa)}.mw-parser-output .mw-authority-control .navbox-list{border-color:#f8f9fa}.mw-parser-output .mw-authority-control .navbox th{background-color:#eeeeff}html.skin-theme-clientpref-night .mw-parser-output .mw-authority-control .mw-mf-linked-projects{border:1px solid var(--border-color-base,#72777d);background-color:var(--background-color-neutral,#27292d);color:var(--color-base,#eaecf0)}html.skin-theme-clientpref-night .mw-parser-output .mw-authority-control .navbox{border:1px solid var(--border-color-base,#72777d)!important;background-color:var(--background-color-neutral-subtle,#202122)!important}html.skin-theme-clientpref-night .mw-parser-output .mw-authority-control .navbox-list{border-color:#202122!important}html.skin-theme-clientpref-night .mw-parser-output .mw-authority-control .navbox th{background-color:#27292d!important}@media(prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .mw-authority-control .mw-mf-linked-projects{border:1px solid var(--border-color-base,#72777d)!important;background-color:var(--background-color-neutral,#27292d)!important;color:var(--color-base,#eaecf0)!important}html.skin-theme-clientpref-os .mw-parser-output .mw-authority-control .navbox{border:1px solid var(--border-color-base,#72777d)!important;background-color:var(--background-color-neutral-subtle,#202122)!important}html.skin-theme-clientpref-os .mw-parser-output .mw-authority-control .navbox-list{border-color:#202122!important}html.skin-theme-clientpref-os .mw-parser-output .mw-authority-control .navbox th{background-color:#27292d!important}}</style><div class="mw-authority-control"><div aria-label="Navbox" class="navbox" role="navigation" style="width: inherit;padding:3px"><table class="hlist navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th class="navbox-group" scope="row" style="width: 12%; text-align:center;"><a href="/wiki/Control_de_autoridades" title="Control de autoridades">Control de autoridades</a></th><td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
# <ul><li><b>Proyectos Wikimedia</b></li>
# <li><span style="white-space:nowrap;"><span typeof="mw:File"><a href="/wiki/Wikidata" title="Wikidata"><img alt="Wd" class="mw-file-element" data-file-height="590" data-file-width="1050" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/20px-Wikidata-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/40px-Wikidata-logo.svg.png 2x" width="20"/></a></span> Datos:</span> <span class="uid"><a class="extiw" href="https://www.wikidata.org/wiki/Q61440363" title="wikidata:Q61440363">Q61440363</a></span></li></ul>
# </div></td></tr></tbody></table></div><div class="mw-mf-linked-projects hlist">
# <ul><li><span style="white-space:nowrap;"><span typeof="mw:File"><a href="/wiki/Wikidata" title="Wikidata"><img alt="Wd" class="mw-file-element" data-file-height="590" data-file-width="1050" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/20px-Wikidata-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/40px-Wikidata-logo.svg.png 2x" width="20"/></a></span> Datos:</span> <span class="uid"><a class="extiw" href="https://www.wikidata.org/wiki/Q61440363" title="wikidata:Q61440363">Q61440363</a></span></li></ul>
# </div></div>
# <p><br clear="all"/>
# </p>
# <table border="1" cellpadding="5" cellspacing="0" class="wikitable" style="border-collapse: collapse; margin:0 auto;">
# <tbody><tr style="text-align: center;">
# <td width="30%">Predecesor:<br/><b><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Flag_of_Brazil.svg" title="Bandera de Brasil"><img alt="Bandera de Brasil" class="mw-file-element" data-file-height="700" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Flag_of_Brazil.svg/20px-Flag_of_Brazil.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Flag_of_Brazil.svg/30px-Flag_of_Brazil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/05/Flag_of_Brazil.svg/40px-Flag_of_Brazil.svg.png 2x" width="20"/></a></span></span> <a href="/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_R%C3%ADo_de_Janeiro_2016" title="Anexo:Medallero de los Juegos Olímpicos de Río de Janeiro 2016">Río de Janeiro 2016</a></b>
# </td>
# <td width="40%"><b>Medallero de los Juegos Olímpicos</b><br/><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Flag_of_Japan.svg" title="Bandera de Japón"><img alt="Bandera de Japón" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Japan.svg/20px-Flag_of_Japan.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Japan.svg/30px-Flag_of_Japan.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Flag_of_Japan.svg/40px-Flag_of_Japan.svg.png 2x" width="20"/></a></span></span> <a href="/wiki/Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Juegos Olímpicos de Tokio 2020">Tokio 2020</a>
# </td>
# <td width="30%">Sucesor:<br/><b><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Flag_of_France_(1794%E2%80%931815,_1830%E2%80%931974).svg" title="Bandera de Francia"><img alt="Bandera de Francia" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/93/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931974%29.svg/20px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931974%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/93/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931974%29.svg/30px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931974%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/93/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931974%29.svg/40px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931974%29.svg.png 2x" width="20"/></a></span></span> <a href="/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Par%C3%ADs_2024" title="Anexo:Medallero de los Juegos Olímpicos de París 2024">París 2024</a></b>
# </td></tr></tbody></table>
# <!--
# NewPP limit report
# Parsed by mw‐web.eqiad.main‐6b768bc658‐bxrwk
# Cached time: 20240822162507
# Cache expiry: 2592000
# Reduced expiry: false
# Complications: [show‐toc]
# CPU time usage: 0.488 seconds
# Real time usage: 0.828 seconds
# Preprocessor visited node count: 9795/1000000
# Post‐expand include size: 85457/2097152 bytes
# Template argument size: 13915/2097152 bytes
# Highest expansion depth: 14/100
# Expensive parser function count: 93/500
# Unstrip recursion depth: 0/20
# Unstrip post‐expand size: 17863/5000000 bytes
# Lua time usage: 0.112/10.000 seconds
# Lua memory usage: 2412263/52428800 bytes
# Number of Wikibase entities loaded: 1/400
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  616.663      1 -total
#  51.41%  316.998     93 Plantilla:BanderaOL
#  38.23%  235.780     96 Plantilla:Bandera
#  28.07%  173.094      1 Plantilla:Control_de_autoridades
#   9.51%   58.616      1 Plantilla:Listaref
#   6.30%   38.880      7 Plantilla:Cita_web
#   4.60%   28.355     93 Plantilla:Bandera_icono-nodesc
#   4.46%   27.484      1 Plantilla:Imagen_múltiple
#   2.65%   16.350      1 Plantilla:Sucesión
#   2.64%   16.261      1 Plantilla:Geodatos_Burkina_Faso
# -->
# <!-- Saved in parser cache with key eswiki:pcache:idhash:9977470-0!canonical and timestamp 20240822162507 and revision id 161824722. Rendering was triggered because: page-view
#  -->
# </meta></div><!--esi <esi:include src="/esitest-fa8a495983347898/content" /> --><noscript><img alt="" height="1" src="https://login.wikimedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" width="1"/></noscript>
# <div class="printfooter" data-nosnippet="">Obtenido de «<a dir="ltr" href="https://es.wikipedia.org/w/index.php?title=Anexo:Medallero_de_los_Juegos_Olímpicos_de_Tokio_2020&amp;oldid=161824722">https://es.wikipedia.org/w/index.php?title=Anexo:Medallero_de_los_Juegos_Olímpicos_de_Tokio_2020&amp;oldid=161824722</a>»</div></div>
# <div class="catlinks" data-mw="interface" id="catlinks"><div class="mw-normal-catlinks" id="mw-normal-catlinks"><a href="/wiki/Especial:Categor%C3%ADas" title="Especial:Categorías">Categorías</a>: <ul><li><a href="/wiki/Categor%C3%ADa:Anexos:Medalleros_de_los_Juegos_Ol%C3%ADmpicos_de_Verano" title="Categoría:Anexos:Medalleros de los Juegos Olímpicos de Verano">Anexos:Medalleros de los Juegos Olímpicos de Verano</a></li><li><a href="/wiki/Categor%C3%ADa:Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Categoría:Juegos Olímpicos de Tokio 2020">Juegos Olímpicos de Tokio 2020</a></li><li><a href="/wiki/Categor%C3%ADa:Anexos:2021" title="Categoría:Anexos:2021">Anexos:2021</a></li></ul></div></div>
# </div>
# </main>
# </div>
# <div class="mw-footer-container">
# <footer class="mw-footer" id="footer">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> Esta página se editó por última vez el 12 ago 2024 a las 13:11.</li>
# <li id="footer-info-copyright">El texto está disponible bajo la <a href="https://es.wikipedia.org/wiki/Wikipedia:Texto_de_la_Licencia_Creative_Commons_Atribuci%C3%B3n-CompartirIgual_4.0_Internacional" rel="license">Licencia Creative Commons Atribución-CompartirIgual 4.0</a><a href="https://creativecommons.org/licenses/by-sa/4.0/deed.es" rel="license" style="display:none;"></a>; pueden aplicarse cláusulas adicionales. Al usar este sitio aceptas nuestros <a href="https://foundation.wikimedia.org/wiki/Policy:Terms_of_Use/es">términos de uso</a> y nuestra <a href="https://foundation.wikimedia.org/wiki/Policy:Privacy_policy/es">política de privacidad</a>.<br/>Wikipedia® es una marca registrada de la <a href="https://wikimediafoundation.org/es/">Fundación Wikimedia</a>, una organización sin ánimo de lucro.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy/es">Política de privacidad</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:Acerca_de">Acerca de Wikipedia</a></li>
# <li id="footer-places-disclaimers"><a href="/wiki/Wikipedia:Limitaci%C3%B3n_general_de_responsabilidad">Limitación de responsabilidad</a></li>
# <li id="footer-places-wm-codeofconduct"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">Código de conducta</a></li>
# <li id="footer-places-developers"><a href="https://developer.wikimedia.org">Desarrolladores</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/es.wikipedia.org">Estadísticas</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement/es">Declaración de cookies</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//es.m.wikipedia.org/w/index.php?title=Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020&amp;mobileaction=toggle_view_mobile">Versión para móviles</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled" href="https://wikimediafoundation.org/" style="padding-left: 8px; padding-right: 8px;" target="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="29" src="/static/images/footer/wikimedia-button.svg" width="84"/></a></li>
# <li id="footer-poweredbyico"><a class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled" href="https://www.mediawiki.org" style="padding-left: 8px; padding-right: 8px;" target="https://www.mediawiki.org"><img alt="Powered by MediaWiki" height="29" src="/static/images/footer/poweredby_mediawiki.svg" width="84"/></a></li>
# </ul>
# </footer>
# </div>
# </div>
# </div>
# <div class="vector-settings" id="p-dock-bottom">
# <ul>
# <li>
# </li>
# </ul>
# </div>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw-web.eqiad.main-6b768bc658-jkrxk","wgBackendResponseTime":113,"wgPageParseReport":{"limitreport":{"cputime":"0.488","walltime":"0.828","ppvisitednodes":{"value":9795,"limit":1000000},"postexpandincludesize":{"value":85457,"limit":2097152},"templateargumentsize":{"value":13915,"limit":2097152},"expansiondepth":{"value":14,"limit":100},"expensivefunctioncount":{"value":93,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":17863,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  616.663      1 -total"," 51.41%  316.998     93 Plantilla:BanderaOL"," 38.23%  235.780     96 Plantilla:Bandera"," 28.07%  173.094      1 Plantilla:Control_de_autoridades","  9.51%   58.616      1 Plantilla:Listaref","  6.30%   38.880      7 Plantilla:Cita_web","  4.60%   28.355     93 Plantilla:Bandera_icono-nodesc","  4.46%   27.484      1 Plantilla:Imagen_múltiple","  2.65%   16.350      1 Plantilla:Sucesión","  2.64%   16.261      1 Plantilla:Geodatos_Burkina_Faso"]},"scribunto":{"limitreport-timeusage":{"value":"0.112","limit":"10.000"},"limitreport-memusage":{"value":2412263,"limit":52428800}},"cachereport":{"origin":"mw-web.eqiad.main-6b768bc658-bxrwk","timestamp":"20240822162507","ttl":2592000,"transientcontent":false}}});});</script>
# </body>
# </html>

# %%
tabla_medallas = sopa_medallas.find('table', {'class': 'wikitable'})

tabla_medallas

#Encuentra la primera tabla con la clase wikitable, que es la que contiene el medallero.
# Out:
# <table class="wikitable striped sortable col1cen col2izq col3der col4der col5der col6der">
# <tbody><tr>
# <th>Núm.
# </th>
# <th>País
# </th>
# <th><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Gold_medal_olympic.svg" title="Oro"><img alt="Oro" class="mw-file-element" data-file-height="300" data-file-width="300" decoding="async" height="18" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Gold_medal_olympic.svg/18px-Gold_medal_olympic.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Gold_medal_olympic.svg/27px-Gold_medal_olympic.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Gold_medal_olympic.svg/36px-Gold_medal_olympic.svg.png 2x" width="18"/></a></span>
# </th>
# <th><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Silver_medal_olympic.svg" title="Plata"><img alt="Plata" class="mw-file-element" data-file-height="300" data-file-width="300" decoding="async" height="18" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/67/Silver_medal_olympic.svg/18px-Silver_medal_olympic.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/67/Silver_medal_olympic.svg/27px-Silver_medal_olympic.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/67/Silver_medal_olympic.svg/36px-Silver_medal_olympic.svg.png 2x" width="18"/></a></span>
# </th>
# <th><span typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Bronze_medal_olympic.svg" title="Bronce"><img alt="Bronce" class="mw-file-element" data-file-height="300" data-file-width="300" decoding="async" height="18" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Bronze_medal_olympic.svg/18px-Bronze_medal_olympic.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/
svg"><img class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Flag_of_Grenada.svg/20px-Flag_of_Grenada.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Flag_of_Grenada.svg/30px-Flag_of_Grenada.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Flag_of_Grenada.svg/40px-Flag_of_Grenada.svg.png 2x" width="20"/></a></span></span> <a href="/wiki/Granada_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Granada en los Juegos Olímpicos de Tokio 2020">Granada</a> <small>(GRN)</small></td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>1
# </td></tr>
# <tr>
# <td><b>86</b></td>
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Flag_of_Kuwait.svg"><img class="mw-file-element" data-file-height="600" data-file-width="1200" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Flag_of_Kuwait.svg/20px-Flag_of_Kuwait.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Flag_of_Kuwait.svg/30px-Flag_of_Kuwait.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Flag_of_Kuwait.svg/40px-Flag_of_Kuwait.svg.png 2x" width="20"/></a></span></span> <a href="/wiki/Kuwait_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Kuwait en los Juegos Olímpicos de Tokio 2020">Kuwait</a> <small>(KUW)</small></td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>1
# </td></tr>
# <tr>
# <td><b>86</b></td>
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Flag_of_Moldova.svg"><img class="mw-file-element" data-file-height="900" data-file-width="1800" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/20px-Flag_of_Moldova.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/30px-Flag_of_Moldova.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/40px-Flag_of_Moldova.svg.png 2x" width="20"/></a></span></span> <a href="/wiki/Moldavia_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Moldavia en los Juegos Olímpicos de Tokio 2020">Moldavia</a> <small>(MDA)</small></td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>1
# </td></tr>
# <tr>
# <td><b>86</b></td>
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a class="mw-file-description" href="/wiki/Archivo:Flag_of_Syria.svg"><img class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Flag_of_Syria.svg/20px-Flag_of_Syria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Flag_of_Syria.svg/30px-Flag_of_Syria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/53/Flag_of_Syria.svg/40px-Flag_of_Syria.svg.png 2x" width="20"/></a></span></span> <a href="/wiki/Siria_en_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020" title="Siria en los Juegos Olímpicos de Tokio 2020">Siria</a> <small>(SYR)</small></td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>1
# </td></tr>
# <tr align="right">
# <td><b>Total</b></td>
# <td align="left"><b>93 países</b></td>
# <td><b>340</b></td>
# <td><b>338</b></td>
# <td><b>402</b></td>
# <td><b>1080</b>
# </td></tr></tbody></table>

# %%
encabezados_medallas = [th.text.strip() for th in tabla_medallas.find_all('th')]
encabezados_medallas
#Obtiene los títulos de las columnas de la tabla.
# Out:
# ['Núm.', 'País', '', '', '', 'Total']

# %%
filas_medallas = []
for fila in tabla_medallas.find_all('tr')[1:-1]:
    celdas_medallas = fila.find_all(['td', 'th'])
    filas_medallas.append([celda.text.strip() for celda in celdas_medallas])

    #dividir_fila = fila.text.split("\n")[1:-1]

filas_medallas
#Recorre cada fila de la tabla (excepto la primera y la última) y extrae el texto de cada celda.
#Se crea un DataFrame de pandas con las filas extraídas y los encabezados.
# Out:
# [['1', 'Estados Unidos\xa0(USA)', '39', '41', '33', '113'],
#  ['2', 'China\xa0(CHN)', '38', '32', '19', '89'],
#  ['3', 'Japón\xa0(JPN)', '27', '14', '17', '58'],
#  ['4', 'Reino Unido\xa0(GBR)', '22', '20', '22', '64'],
#  ['5', 'Rusia\xa0(RUS)', '20', '28', '23', '71'],
#  ['6', 'Australia\xa0(AUS)', '17', '7', '22', '46'],
#  ['7', 'Países Bajos\xa0(NED)', '10', '12', '14', '36'],
#  ['8', 'Francia\xa0(FRA)', '10', '12', '11', '33'],
#  ['9', 'Alemania\xa0(GER)', '10', '11', '16', '37'],
#  ['10', 'Italia\xa0(ITA)', '10', '10', '20', '40'],
#  ['11', 'Canadá\xa0(CAN)', '7', '7', '10', '24'],
#  ['12', 'Brasil\xa0(BRA)', '7', '6', '8', '21'],
#  ['13', 'Nueva Zelanda\xa0(NZL)', '7', '6', '7', '20'],
#  ['14', 'Cuba\xa0(CUB)', '7', '3', '5', '15'],
#  ['15', 'Hungría\xa0(HUN)', '6', '7', '7', '20'],
#  ['16', 'Corea del Sur\xa0(KOR)', '6', '4', '10', '20'],
#  ['17', 'Polonia\xa0(POL)', '4', '5', '5', '14'],
#  ['18', 'República Checa\xa0(CZE)', '4', '4', '3', '11'],
#  ['19', 'Kenia\xa0(KEN)', '4', '4', '2', '10'],
#  ['20', 'Noruega\xa0(NOR)', '4', '2', '2', '8'],
#  ['21', 'Jamaica\xa0(JAM)', '4', '1', '4', '9'],
#  ['22', 'España\xa0(ESP)', '3', '8', '6', '17'],
#  ['23', 'Suecia\xa0(SWE)', '3', '6', '0', '9'],
#  ['24', 'Suiza\xa0(SUI)', '3', '4', '6', '13'],
#  ['25', 'Dinamarca\xa0(DEN)', '3', '4', '4', '11'],
#  ['26', 'Croacia\xa0(CRO)', '3', '3', '2', '8'],
#  ['27', 'Irán\xa0(IRI)', '3', '2', '2', '7'],
#  ['28', 'Serbia\xa0(SRB)', '3', '1', '5', '9'],
#  ['29', 'Bélgica\xa0(BEL)', '3', '1', '3', '7'],
#  ['30', 'Bulgaria\xa0(BUL)', '3', '1', '2', '6'],
#  ['31', 'Eslovenia\xa0(SLO)', '3', '1', '1', '5'],
#  ['32', 'Uzbekistán\xa0(UZB)', '3', '0', '2', '5'],
#  ['33', 'Georgia\xa0(GEO)', '2', '5', '1', '8'],
#  ['34', 'China Taipéi\xa0(TPE)', '2', '4', '6', '12'],
#  ['35', 'Turquía\xa0(TUR)', '2', '2', '9', '13'],
#  ['36', 'Grecia\xa0(GRE)', '2', '1', '1', '4'],
#  ['36', 'Uganda\xa0(UGA)', '2', '1', '1', '4'],
#  ['38', 'Ecuador\xa0(ECU)', '2', '1', '0', '3'],
#  ['39', 'Irlanda\xa0(IRL)', '2', '0', '2', '4'],
#  ['39', 'Israel\xa0(ISR)', '2', '0', '2', '4'],
#  ['41', 'Catar\xa0(QAT)', '2', '0', '1', '3'],
#  ['42', 'Bahamas\xa0(BAH)', '2', '0', '0', '2'],
#  ['42', 'Kosovo\xa0(KOS)', '2', '0', '0', '2'],
#  ['44', 'Ucrania\xa0(UKR)', '1', '6', '12', '19'],
#  ['45', 'Bielorrusia\xa0(BLR)', '1', '3', '3', '7'],
#  ['46', 'Rumania\xa0(ROU)', '1', '3', '0', '4'],
#  ['46', 'Venezuela\xa0(VEN)', '1', '3', '0', '4'],
#  ['48', 'India\xa0(IND)', '1', '2', '4', '7'],
#  ['49', 'Hong Kong\xa0(HKG)', '1', '2', '3', '6'],
#  ['50', 'Filipinas\xa0(PHI)', '1', '2', '1', '4'],
#  ['50', 'Eslovaquia\xa0(SVK)', '1', '2', '1', '4'],
#  ['52', 'Sudáfrica\xa0(RSA)', '1', '2', '0', '3'],
#  ['53', 'Austria\xa0(AUT)', '1', '1', '5', '7'],
#  ['54', 'Egipto\xa0(EGY)', '1', '1', '4', '6'],
#  ['55', 'Indonesia\xa0(INA)', '1', '1', '3', '5'],
#  ['56', 'Etiopía\xa0(ETH)', '1', '1', '2', '4'],
#  ['56', 'Portugal\xa0(POR)', '1', '1', '2', '4'],
#  ['58', 'Túnez\xa0(TUN)', '1', '1', '0', '2'],
#  ['59', 'Estonia\xa0(EST)', '1', '0', '1', '2'],
#  ['59', 'Fiyi\xa0(FIY)', '1', '0', '1', '2'],
#  ['59', 'Letonia\xa0(LAT)', '1', '0', '1', '2'],
#  ['59', 'Tailandia\xa0(THA)', '1', '0', '1', '2'],
#  ['63', 'Bermudas\xa0(BER)', '1', '0', '0', '1'],
#  ['63', 'Marruecos\xa0(MAR)', '1', '0', '0', '1'],
#  ['63', 'Puerto Rico\xa0(PUR)', '1', '0', '0', '1'],
#  ['66', 'Colombia\xa0(COL)', '0', '4', '1', '5'],
#  ['67', 'Azerbaiyán\xa0(AZE)', '0', '3', '4', '7'],
#  ['68', 'República Dominicana\xa0(DOM)', '0', '3', '2', '5'],
#  ['69', 'Armenia\xa0(ARM)', '0', '2', '2', '4'],
#  ['70', 'Kirguistán\xa0(KGZ)', '0', '2', '1', '3'],
#  ['71', 'Mongolia\xa0(MGL)', '0', '1', '3', '4'],
#  ['72', 'Argentina\xa0(ARG)', '0', '1', '2', '3'],
#  ['72', 'San Marino\xa0(SMR)', '0', '1', '2', '3'],
#  ['74', 'Jordania\xa0(JOR)', '0', '1', '1', '2'],
#  ['74', 'Malasia\xa0(MAL)', '0', '1', '1', '2'],
#  ['74', 'Nigeria\xa0(NGR)', '0', '1', '1', '2'],
#  ['77', 'Arabia Saudita\xa0(KSA)', '0', '1', '0', '1'],
#  ['77', 'Baréin\xa0(BRN)', '0', '1', '0', '1'],
#  ['77', 'Lituania\xa0(LTU)', '0', '1', '0', '1'],
#  ['77', 'Macedonia del Norte\xa0(MKD)', '0', '1', '0', '1'],
#  ['77', 'Namibia\xa0(NAM)', '0', '1', '0', '1'],
#  ['77', 'Turkmenistán\xa0(TKM)', '0', '1', '0', '1'],
#  ['83', 'Kazajistán\xa0(KAZ)', '0', '0', '8', '8'],
#  ['84', 'México\xa0(MEX)', '0', '0', '4', '4'],
#  ['85', 'Finlandia\xa0(FIN)', '0', '0', '2', '2'],
#  ['86', 'Botsuana\xa0(BOT)', '0', '0', '1', '1'],
#  ['86', 'Burkina Faso\xa0(BFA)', '0', '0', '1', '1'],
#  ['86', 'Costa de Marfil\xa0(CIV)', '0', '0', '1', '1'],
#  ['86', 'Ghana\xa0(GHA)', '0', '0', '1', '1'],
#  ['86', 'Granada\xa0(GRN)', '0', '0', '1', '1'],
#  ['86', 'Kuwait\xa0(KUW)', '0', '0', '1', '1'],
#  ['86', 'Moldavia\xa0(MDA)', '0', '0', '1', '1'],
#  ['86', 'Siria\xa0(SYR)', '0', '0', '1', '1']]

# %%
df_medallas = pd.DataFrame(filas_medallas, columns=encabezados_medallas)
df_medallas.head()

#convertir el diccionario en DataFrame
#usar el método pd.DataFrame(), método que más usaremos más a menudo durante estas lecciones.
# Out:
#   Núm.                  País             Total
# 0    1  Estados Unidos (USA)  39  41  33   113
# 1    2           China (CHN)  38  32  19    89
# 2    3           Japón (JPN)  27  14  17    58
# 3    4     Reino Unido (GBR)  22  20  22    64
# 4    5           Rusia (RUS)  20  28  23    71
